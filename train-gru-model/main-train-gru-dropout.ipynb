# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Multiply, Add, Layer, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
from tensorflow.keras.optimizers import Adam
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Custom Layer to subtract from 1
class SubtractFromOne(Layer):
    def call(self, inputs):
        return 1.0 - inputs

# Custom Layer to extract a specific feature (replacing Lambda layers that slice inputs)
class ExtractFeature(Layer):
    def __init__(self, index, **kwargs):
        super(ExtractFeature, self).__init__(**kwargs)
        self.index = index

    def call(self, inputs):
        return inputs[:, :, self.index]

# Custom R2 score metric
def r2_score_metric(y_true, y_pred):
    SS_res = tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return 1 - SS_res / (SS_tot + tf.keras.backend.epsilon())

def train_and_evaluate_gru_model(target_variable, flag_train=True, _epochs=100, _batch_size=10):
    mgh_data = pd.read_excel("gru-datasets.xlsx")
    features = ['timesteps', f'{target_variable} (Predicted GL)', f'{target_variable} (Predicted NN)']
    
    X = mgh_data[features]
    y = mgh_data[f'{target_variable} (Actual)']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01, random_state=42)
    X_train_reshaped = X_train.values.reshape((X_train.shape[0], -1, X_train.shape[1]))
    X_test_reshaped = X_test.values.reshape((X_test.shape[0], -1, X_test.shape[1]))

    if flag_train:
        time_steps = X_train_reshaped.shape[1]
        features_count = X_train_reshaped.shape[2]

        # Define the input layer with the appropriate shape
        input_layer = Input(shape=(time_steps, features_count), name='input_layer')

        # First GRU layer with 64 units and dropout
        gru_output_1 = GRU(units=64, return_sequences=True)(input_layer)
        dropout_1 = Dropout(0.2)(gru_output_1)

        # Second GRU layer with 32 units and dropout
        gru_output_2 = GRU(units=32, return_sequences=True)(dropout_1)
        dropout_2 = Dropout(0.2)(gru_output_2)

        # Third GRU layer with 16 units and dropout
        gru_output_3 = GRU(units=16, return_sequences=False)(dropout_2)
        dropout_3 = Dropout(0.2)(gru_output_3)

        # Dense layer followed by dropout
        w_physics = Dense(1, activation='sigmoid')(dropout_3)
        # w_physics_dropout = Dropout(0.2)(w_physics)

        # Custom layer to subtract from 1
        w_nn = SubtractFromOne()(w_physics)

        # Extract specific features
        q_physics_input = ExtractFeature(index=1, name='q_physics_input')(input_layer)
        q_nn_input = ExtractFeature(index=2, name='q_nn_input')(input_layer)

        # Calculate the final output
        y_hat_physics = Multiply()([q_physics_input, w_physics])
        y_hat_nn = Multiply()([q_nn_input, w_nn])
        y_hat = Add()([y_hat_physics, y_hat_nn])

        # Create the model
        model = Model(inputs=input_layer, outputs=y_hat)
        
        adam = Adam(learning_rate=0.001, use_ema=True, ema_momentum=0.9)
        
        model.compile(optimizer=adam, loss='mse', metrics=['mae', r2_score_metric])

        history = model.fit(X_train_reshaped, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)

        # Save model architecture and weights
        model_json = model.to_json()
        with open(f"gru-dropout-models/{target_variable.replace(' ', '_')}_gru_model.json", "w") as json_file:
            json_file.write(model_json)
        model.save_weights(f"gru-dropout-models/{target_variable.replace(' ', '_')}_gru_model.weights.h5")

        # Predict the test set after training
        y_hat_test = model.predict(X_test_reshaped)

    else:
        # Load model architecture and weights
        with open(f"gru-dropout-models/{target_variable.replace(' ', '_')}_gru_model.json", "r") as json_file:
            loaded_model_json = json_file.read()
            loaded_model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={'r2_score_metric': r2_score_metric, 'SubtractFromOne': SubtractFromOne, 'ExtractFeature': ExtractFeature})

        loaded_model.load_weights(f"gru-dropout-models/{target_variable.replace(' ', '_')}_gru_model.weights.h5")
        loaded_model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_metric])

        # Predict the test set using the loaded model
        y_hat_test = loaded_model.predict(X_test_reshaped)

    # Evaluate the model
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)

    if flag_train:
        # Plot training history
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')
        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    # Scatter plot of actual vs. predicted values
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()

    # Plot of actual vs. predicted over time
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
target_variable = ['Temperature In', 'RH In', 'PAR In', 'CO2 In']

for i in target_variable:
    train_and_evaluate_gru_model(i, flag_train=True, _epochs=100, _batch_size=4)
# Out:
# Epoch 1/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0939 - mae: 0.2349 - r2_score_metric: 0.5031 - val_loss: 0.0902 - val_mae: 0.2352 - val_r2_score_metric: 0.5617
# Epoch 2/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1039 - mae: 0.2413 - r2_score_metric: -0.6959 - val_loss: 0.0884 - val_mae: 0.2293 - val_r2_score_metric: 0.5755
# Epoch 3/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0889 - mae: 0.2181 - r2_score_metric: 0.2825 - val_loss: 0.0883 - val_mae: 0.2267 - val_r2_score_metric: 0.5812
# Epoch 4/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0955 - mae: 0.2337 - r2_score_metric: 0.3127 - val_loss: 0.0892 - val_mae: 0.2253 - val_r2_score_metric: 0.5771
# Epoch 5/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0913 - mae: 0.2297 - r2_score_metric: 0.4319 - val_loss: 0.0874 - val_mae: 0.2252 - val_r2_score_metric: 0.5755
# Epoch 6/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0873 - mae: 0.2260 - r2_score_metric: 0.6084 - val_loss: 0.0880 - val_mae: 0.2240 - val_r2_score_metric: 0.5889
# Epoch 7/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0872 - mae: 0.2245 - r2_score_metric: 0.4958 - val_loss: 0.0863 - val_mae: 0.2251 - val_r2_score_metric: 0.5928
# Epoch 8/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0794 - mae: 0.2215 - r2_score_metric: 0.2099 - val_loss: 0.0867 - val_mae: 0.2248 - val_r2_score_metric: 0.5816
# Epoch 9/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0808 - mae: 0.2186 - r2_score_metric: 0.6995 - val_loss: 0.0863 - val_mae: 0.2244 - val_r2_score_metric: 0.5929
# Epoch 10/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0823 - mae: 0.2200 - r2_score_metric: 0.5506 - val_loss: 0.0872 - val_mae: 0.2250 - val_r2_score_metric: 0.5645
# Epoch 11/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0760 - mae: 0.2145 - r2_score_metric: 0.6263 - val_loss: 0.0864 - val_mae: 0.2242 - val_r2_score_metric: 0.6033
# Epoch 12/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0846 - mae: 0.2184 - r2_score_metric: 0.5053 - val_loss: 0.0865 - val_mae: 0.2252 - val_r2_score_metric: 0.5851
# Epoch 13/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0839 - mae: 0.2218 - r2_score_metric: 0.3199 - val_loss: 0.0864 - val_mae: 0.2240 - val_r2_score_metric: 0.6008
# Epoch 14/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0911 - mae: 0.2331 - r2_score_metric: 0.4221 - val_loss: 0.0858 - val_mae: 0.2260 - val_r2_score_metric: 0.5966
# Epoch 15/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0799 - mae: 0.2219 - r2_score_metric: 0.5520 - val_loss: 0.0871 - val_mae: 0.2259 - val_r2_score_metric: 0.5664
# Epoch 16/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0820 - mae: 0.2180 - r2_score_metric: 0.3066 - val_loss: 0.0858 - val_mae: 0.2245 - val_r2_score_metric: 0.6041
# Epoch 17/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0861 - mae: 0.2304 - r2_score_metric: 0.4419 - val_loss: 0.0865 - val_mae: 0.2236 - val_r2_score_metric: 0.6033
# Epoch 18/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0748 - mae: 0.2097 - r2_score_metric: 0.5549 - val_loss: 0.0864 - val_mae: 0.2235 - val_r2_score_metric: 0.6026
# Epoch 19/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0782 - mae: 0.2139 - r2_score_metric: 0.4281 - val_loss: 0.0860 - val_mae: 0.2250 - val_r2_score_metric: 0.5956
# Epoch 20/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0914 - mae: 0.2333 - r2_score_metric: 0.5934 - val_loss: 0.0879 - val_mae: 0.2239 - val_r2_score_metric: 0.5993
# Epoch 21/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0804 - mae: 0.2117 - r2_score_metric: 0.5679 - val_loss: 0.0855 - val_mae: 0.2263 - val_r2_score_metric: 0.5985
# Epoch 22/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0848 - mae: 0.2234 - r2_score_metric: 0.3508 - val_loss: 0.0875 - val_mae: 0.2245 - val_r2_score_metric: 0.6027
# Epoch 23/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0828 - mae: 0.2149 - r2_score_metric: 0.4428 - val_loss: 0.0861 - val_mae: 0.2234 - val_r2_score_metric: 0.6053
# Epoch 24/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0801 - mae: 0.2164 - r2_score_metric: 0.6306 - val_loss: 0.0855 - val_mae: 0.2235 - val_r2_score_metric: 0.6100
# Epoch 25/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0868 - mae: 0.2239 - r2_score_metric: 0.5442 - val_loss: 0.0854 - val_mae: 0.2253 - val_r2_score_metric: 0.6054
# Epoch 26/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0877 - mae: 0.2252 - r2_score_metric: 0.5342 - val_loss: 0.0854 - val_mae: 0.2239 - val_r2_score_metric: 0.6073
# Epoch 27/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0848 - mae: 0.2236 - r2_score_metric: 0.0736 - val_loss: 0.0853 - val_mae: 0.2227 - val_r2_score_metric: 0.6132
# Epoch 28/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0880 - mae: 0.2311 - r2_score_metric: 0.4357 - val_loss: 0.0871 - val_mae: 0.2228 - val_r2_score_metric: 0.6071
# Epoch 29/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0874 - mae: 0.2251 - r2_score_metric: 0.3305 - val_loss: 0.0879 - val_mae: 0.2234 - val_r2_score_metric: 0.6002
# Epoch 30/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0807 - mae: 0.2129 - r2_score_metric: 0.5956 - val_loss: 0.0866 - val_mae: 0.2233 - val_r2_score_metric: 0.5898
# Epoch 31/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0879 - mae: 0.2229 - r2_score_metric: 0.6090 - val_loss: 0.0856 - val_mae: 0.2252 - val_r2_score_metric: 0.6041
# Epoch 32/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0737 - mae: 0.2074 - r2_score_metric: 0.5735 - val_loss: 0.0854 - val_mae: 0.2242 - val_r2_score_metric: 0.6076
# Epoch 33/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0805 - mae: 0.2237 - r2_score_metric: 0.4827 - val_loss: 0.0869 - val_mae: 0.2237 - val_r2_score_metric: 0.6072
# Epoch 34/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0853 - mae: 0.2248 - r2_score_metric: 0.3383 - val_loss: 0.0876 - val_mae: 0.2236 - val_r2_score_metric: 0.6052
# Epoch 35/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0828 - mae: 0.2162 - r2_score_metric: 0.2277 - val_loss: 0.0859 - val_mae: 0.2226 - val_r2_score_metric: 0.6078
# Epoch 36/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0881 - mae: 0.2199 - r2_score_metric: 0.5681 - val_loss: 0.0855 - val_mae: 0.2254 - val_r2_score_metric: 0.6067
# Epoch 37/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0852 - mae: 0.2283 - r2_score_metric: 0.5037 - val_loss: 0.0858 - val_mae: 0.2234 - val_r2_score_metric: 0.6074
# Epoch 38/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0820 - mae: 0.2189 - r2_score_metric: 0.4727 - val_loss: 0.0863 - val_mae: 0.2227 - val_r2_score_metric: 0.6043
# Epoch 39/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0810 - mae: 0.2146 - r2_score_metric: 0.4600 - val_loss: 0.0854 - val_mae: 0.2240 - val_r2_score_metric: 0.6038
# Epoch 40/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0797 - mae: 0.2174 - r2_score_metric: 0.6062 - val_loss: 0.0860 - val_mae: 0.2253 - val_r2_score_metric: 0.5839
# Epoch 41/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0806 - mae: 0.2188 - r2_score_metric: 0.2520 - val_loss: 0.0864 - val_mae: 0.2222 - val_r2_score_metric: 0.6047
# Epoch 42/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0887 - mae: 0.2263 - r2_score_metric: 0.6223 - val_loss: 0.0868 - val_mae: 0.2241 - val_r2_score_metric: 0.6050
# Epoch 43/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0820 - mae: 0.2191 - r2_score_metric: 0.6139 - val_loss: 0.0854 - val_mae: 0.2233 - val_r2_score_metric: 0.6097
# Epoch 44/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0845 - mae: 0.2247 - r2_score_metric: 0.4776 - val_loss: 0.0853 - val_mae: 0.2247 - val_r2_score_metric: 0.6053
# Epoch 45/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0802 - mae: 0.2154 - r2_score_metric: -2.1368 - val_loss: 0.0859 - val_mae: 0.2255 - val_r2_score_metric: 0.6113
# Epoch 46/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0830 - mae: 0.2190 - r2_score_metric: 0.3188 - val_loss: 0.0858 - val_mae: 0.2238 - val_r2_score_metric: 0.6079
# Epoch 47/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0818 - mae: 0.2189 - r2_score_metric: 0.5114 - val_loss: 0.0860 - val_mae: 0.2254 - val_r2_score_metric: 0.6078
# Epoch 48/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0797 - mae: 0.2208 - r2_score_metric: 0.3394 - val_loss: 0.0867 - val_mae: 0.2226 - val_r2_score_metric: 0.6104
# Epoch 49/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0802 - mae: 0.2182 - r2_score_metric: 0.5140 - val_loss: 0.0849 - val_mae: 0.2237 - val_r2_score_metric: 0.6160
# Epoch 50/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0833 - mae: 0.2190 - r2_score_metric: -0.0447 - val_loss: 0.0853 - val_mae: 0.2244 - val_r2_score_metric: 0.6065
# Epoch 51/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0804 - mae: 0.2219 - r2_score_metric: 0.5139 - val_loss: 0.0861 - val_mae: 0.2222 - val_r2_score_metric: 0.6086
# Epoch 52/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0860 - mae: 0.2224 - r2_score_metric: 0.3427 - val_loss: 0.0857 - val_mae: 0.2225 - val_r2_score_metric: 0.6112
# Epoch 53/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0786 - mae: 0.2131 - r2_score_metric: -0.7473 - val_loss: 0.0853 - val_mae: 0.2232 - val_r2_score_metric: 0.6160
# Epoch 54/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0878 - mae: 0.2256 - r2_score_metric: 0.3365 - val_loss: 0.0856 - val_mae: 0.2247 - val_r2_score_metric: 0.6159
# Epoch 55/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0787 - mae: 0.2171 - r2_score_metric: -0.2168 - val_loss: 0.0854 - val_mae: 0.2241 - val_r2_score_metric: 0.6127
# Epoch 56/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0817 - mae: 0.2238 - r2_score_metric: 0.5880 - val_loss: 0.0851 - val_mae: 0.2234 - val_r2_score_metric: 0.6121
# Epoch 57/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0819 - mae: 0.2156 - r2_score_metric: 0.3173 - val_loss: 0.0851 - val_mae: 0.2239 - val_r2_score_metric: 0.6138
# Epoch 58/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0813 - mae: 0.2175 - r2_score_metric: 0.2955 - val_loss: 0.0855 - val_mae: 0.2227 - val_r2_score_metric: 0.6126
# Epoch 59/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0964 - mae: 0.2338 - r2_score_metric: 0.5321 - val_loss: 0.0853 - val_mae: 0.2229 - val_r2_score_metric: 0.6119
# Epoch 60/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0854 - mae: 0.2234 - r2_score_metric: -0.1744 - val_loss: 0.0851 - val_mae: 0.2240 - val_r2_score_metric: 0.6166
# Epoch 61/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0875 - mae: 0.2254 - r2_score_metric: 0.3880 - val_loss: 0.0856 - val_mae: 0.2226 - val_r2_score_metric: 0.6214
# Epoch 62/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0834 - mae: 0.2195 - r2_score_metric: 0.6763 - val_loss: 0.0857 - val_mae: 0.2231 - val_r2_score_metric: 0.6172
# Epoch 63/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0774 - mae: 0.2135 - r2_score_metric: 0.5989 - val_loss: 0.0855 - val_mae: 0.2231 - val_r2_score_metric: 0.6074
# Epoch 64/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0895 - mae: 0.2185 - r2_score_metric: 0.4023 - val_loss: 0.0849 - val_mae: 0.2232 - val_r2_score_metric: 0.6186
# Epoch 65/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0905 - mae: 0.2273 - r2_score_metric: 0.5218 - val_loss: 0.0853 - val_mae: 0.2240 - val_r2_score_metric: 0.6160
# Epoch 66/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0897 - mae: 0.2243 - r2_score_metric: 0.4627 - val_loss: 0.0849 - val_mae: 0.2249 - val_r2_score_metric: 0.6145
# Epoch 67/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1103 - mae: 0.2389 - r2_score_metric: 0.3475 - val_loss: 0.0857 - val_mae: 0.2248 - val_r2_score_metric: 0.6113
# Epoch 68/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0804 - mae: 0.2188 - r2_score_metric: 0.1410 - val_loss: 0.0849 - val_mae: 0.2245 - val_r2_score_metric: 0.6152
# Epoch 69/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0787 - mae: 0.2228 - r2_score_metric: 0.3972 - val_loss: 0.0855 - val_mae: 0.2222 - val_r2_score_metric: 0.6198
# Epoch 70/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0821 - mae: 0.2195 - r2_score_metric: 0.3555 - val_loss: 0.0857 - val_mae: 0.2230 - val_r2_score_metric: 0.6146
# Epoch 71/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0777 - mae: 0.2142 - r2_score_metric: 0.5439 - val_loss: 0.0855 - val_mae: 0.2228 - val_r2_score_metric: 0.6107
# Epoch 72/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - mae: 0.2350 - r2_score_metric: 0.3824 - val_loss: 0.0855 - val_mae: 0.2225 - val_r2_score_metric: 0.6140
# Epoch 73/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0758 - mae: 0.2117 - r2_score_metric: 0.2916 - val_loss: 0.0868 - val_mae: 0.2230 - val_r2_score_metric: 0.6082
# Epoch 74/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0802 - mae: 0.2189 - r2_score_metric: 0.5986 - val_loss: 0.0850 - val_mae: 0.2231 - val_r2_score_metric: 0.6180
# Epoch 75/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0880 - mae: 0.2234 - r2_score_metric: 0.2891 - val_loss: 0.0858 - val_mae: 0.2232 - val_r2_score_metric: 0.6077
# Epoch 76/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0785 - mae: 0.2157 - r2_score_metric: 0.4022 - val_loss: 0.0862 - val_mae: 0.2218 - val_r2_score_metric: 0.6106
# Epoch 77/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0850 - mae: 0.2229 - r2_score_metric: 0.1504 - val_loss: 0.0859 - val_mae: 0.2233 - val_r2_score_metric: 0.6115
# Epoch 78/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0822 - mae: 0.2182 - r2_score_metric: 0.2739 - val_loss: 0.0857 - val_mae: 0.2232 - val_r2_score_metric: 0.6120
# Epoch 79/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0812 - mae: 0.2204 - r2_score_metric: -0.1783 - val_loss: 0.0854 - val_mae: 0.2233 - val_r2_score_metric: 0.6058
# Epoch 80/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0816 - mae: 0.2179 - r2_score_metric: 0.5266 - val_loss: 0.0849 - val_mae: 0.2238 - val_r2_score_metric: 0.6181
# Epoch 81/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0820 - mae: 0.2211 - r2_score_metric: 0.6619 - val_loss: 0.0856 - val_mae: 0.2223 - val_r2_score_metric: 0.6146
# Epoch 82/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0781 - mae: 0.2137 - r2_score_metric: -0.0681 - val_loss: 0.0856 - val_mae: 0.2229 - val_r2_score_metric: 0.6108
# Epoch 83/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0822 - mae: 0.2224 - r2_score_metric: -0.5018 - val_loss: 0.0855 - val_mae: 0.2240 - val_r2_score_metric: 0.6121
# Epoch 84/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0746 - mae: 0.2128 - r2_score_metric: 0.6794 - val_loss: 0.0849 - val_mae: 0.2237 - val_r2_score_metric: 0.6139
# Epoch 85/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0833 - mae: 0.2208 - r2_score_metric: 0.4136 - val_loss: 0.0852 - val_mae: 0.2230 - val_r2_score_metric: 0.6168
# Epoch 86/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0842 - mae: 0.2226 - r2_score_metric: 0.4751 - val_loss: 0.0848 - val_mae: 0.2230 - val_r2_score_metric: 0.6156
# Epoch 87/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0796 - mae: 0.2166 - r2_score_metric: 0.3637 - val_loss: 0.0852 - val_mae: 0.2220 - val_r2_score_metric: 0.6155
# Epoch 88/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0850 - mae: 0.2193 - r2_score_metric: -0.0384 - val_loss: 0.0857 - val_mae: 0.2232 - val_r2_score_metric: 0.6120
# Epoch 89/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0861 - mae: 0.2181 - r2_score_metric: 0.0165 - val_loss: 0.0853 - val_mae: 0.2244 - val_r2_score_metric: 0.6112
# Epoch 90/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0863 - mae: 0.2255 - r2_score_metric: 0.5243 - val_loss: 0.0853 - val_mae: 0.2235 - val_r2_score_metric: 0.6119
# Epoch 91/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0834 - mae: 0.2242 - r2_score_metric: 0.6403 - val_loss: 0.0853 - val_mae: 0.2232 - val_r2_score_metric: 0.6113
# Epoch 92/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0798 - mae: 0.2145 - r2_score_metric: 0.5066 - val_loss: 0.0853 - val_mae: 0.2231 - val_r2_score_metric: 0.6100
# Epoch 93/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0811 - mae: 0.2187 - r2_score_metric: 0.4003 - val_loss: 0.0857 - val_mae: 0.2227 - val_r2_score_metric: 0.6123
# Epoch 94/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0746 - mae: 0.2120 - r2_score_metric: 0.5825 - val_loss: 0.0856 - val_mae: 0.2225 - val_r2_score_metric: 0.6122
# Epoch 95/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0841 - mae: 0.2206 - r2_score_metric: 0.3472 - val_loss: 0.0850 - val_mae: 0.2239 - val_r2_score_metric: 0.6119
# Epoch 96/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0820 - mae: 0.2195 - r2_score_metric: 0.2591 - val_loss: 0.0857 - val_mae: 0.2233 - val_r2_score_metric: 0.6126
# Epoch 97/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0779 - mae: 0.2109 - r2_score_metric: 0.5990 - val_loss: 0.0854 - val_mae: 0.2241 - val_r2_score_metric: 0.6119
# Epoch 98/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0783 - mae: 0.2172 - r2_score_metric: 0.0787 - val_loss: 0.0849 - val_mae: 0.2232 - val_r2_score_metric: 0.6129
# Epoch 99/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0793 - mae: 0.2142 - r2_score_metric: 0.5843 - val_loss: 0.0852 - val_mae: 0.2245 - val_r2_score_metric: 0.6047
# Epoch 100/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0756 - mae: 0.2125 - r2_score_metric: 0.6181 - val_loss: 0.0848 - val_mae: 0.2235 - val_r2_score_metric: 0.6149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
#
# Target Variable: Temperature In
# MAE: 0.31
# R²: 0.76
# Epoch 1/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 116.7761 - mae: 8.8950 - r2_score_metric: -29.0989 - val_loss: 16.5528 - val_mae: 3.6717 - val_r2_score_metric: -2.4427
# Epoch 2/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.7708 - mae: 3.5872 - r2_score_metric: -2.4536 - val_loss: 15.4636 - val_mae: 3.5265 - val_r2_score_metric: -2.1961
# Epoch 3/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.1686 - mae: 3.4920 - r2_score_metric: -3.4520 - val_loss: 15.1677 - val_mae: 3.4860 - val_r2_score_metric: -2.1293
# Epoch 4/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.2327 - mae: 3.5035 - r2_score_metric: -3.4560 - val_loss: 15.0150 - val_mae: 3.4649 - val_r2_score_metric: -2.0948
# Epoch 5/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.6043 - mae: 3.4160 - r2_score_metric: -3.5790 - val_loss: 14.9386 - val_mae: 3.4543 - val_r2_score_metric: -2.0775
# Epoch 6/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.5534 - mae: 3.3133 - r2_score_metric: -2.0659 - val_loss: 14.8858 - val_mae: 3.4470 - val_r2_score_metric: -2.0656
# Epoch 7/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.8770 - mae: 3.4639 - r2_score_metric: -4.6138 - val_loss: 14.8509 - val_mae: 3.4421 - val_r2_score_metric: -2.0577
# Epoch 8/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.4075 - mae: 3.4116 - r2_score_metric: -3.4570 - val_loss: 14.8274 - val_mae: 3.4389 - val_r2_score_metric: -2.0524
# Epoch 9/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.0582 - mae: 3.3737 - r2_score_metric: -2.6240 - val_loss: 14.8121 - val_mae: 3.4367 - val_r2_score_metric: -2.0489
# Epoch 10/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2109 - mae: 3.3596 - r2_score_metric: -7.2231 - val_loss: 14.8001 - val_mae: 3.4350 - val_r2_score_metric: -2.0462
# Epoch 11/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.8067 - mae: 3.4353 - r2_score_metric: -3.8026 - val_loss: 14.7897 - val_mae: 3.4336 - val_r2_score_metric: -2.0438
# Epoch 12/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.1079 - mae: 3.3665 - r2_score_metric: -5.5327 - val_loss: 14.7822 - val_mae: 3.4325 - val_r2_score_metric: -2.0422
# Epoch 13/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2792 - mae: 3.3845 - r2_score_metric: -3.5847 - val_loss: 14.7768 - val_mae: 3.4318 - val_r2_score_metric: -2.0409
# Epoch 14/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 13.5664 - mae: 3.2918 - r2_score_metric: -2.4532 - val_loss: 14.7726 - val_mae: 3.4312 - val_r2_score_metric: -2.0400
# Epoch 15/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.3553 - mae: 3.2881 - r2_score_metric: -2.5430 - val_loss: 14.7687 - val_mae: 3.4307 - val_r2_score_metric: -2.0391
# Epoch 16/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 13.2994 - mae: 3.2559 - r2_score_metric: -7.1793 - val_loss: 14.7657 - val_mae: 3.4302 - val_r2_score_metric: -2.0384
# Epoch 17/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.9222 - mae: 3.3278 - r2_score_metric: -3.7367 - val_loss: 14.7629 - val_mae: 3.4298 - val_r2_score_metric: -2.0378
# Epoch 18/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.1224 - mae: 3.3554 - r2_score_metric: -2.4125 - val_loss: 14.7611 - val_mae: 3.4296 - val_r2_score_metric: -2.0374
# Epoch 19/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.1598 - mae: 3.5176 - r2_score_metric: -4.4984 - val_loss: 14.7596 - val_mae: 3.4294 - val_r2_score_metric: -2.0370
# Epoch 20/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2076 - mae: 3.3792 - r2_score_metric: -2.2772 - val_loss: 14.7583 - val_mae: 3.4292 - val_r2_score_metric: -2.0368
# Epoch 21/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2574 - mae: 3.4054 - r2_score_metric: -3.8658 - val_loss: 14.7573 - val_mae: 3.4291 - val_r2_score_metric: -2.0365
# Epoch 22/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.3824 - mae: 3.3637 - r2_score_metric: -2.2811 - val_loss: 14.7565 - val_mae: 3.4289 - val_r2_score_metric: -2.0363
# Epoch 23/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.3750 - mae: 3.3959 - r2_score_metric: -20.7893 - val_loss: 14.7557 - val_mae: 3.4288 - val_r2_score_metric: -2.0362
# Epoch 24/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.8697 - mae: 3.3350 - r2_score_metric: -5.0172 - val_loss: 14.7551 - val_mae: 3.4288 - val_r2_score_metric: -2.0360
# Epoch 25/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.1081 - mae: 3.3613 - r2_score_metric: -3.1531 - val_loss: 14.7546 - val_mae: 3.4287 - val_r2_score_metric: -2.0359
# Epoch 26/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.5055 - mae: 3.2846 - r2_score_metric: -1.7044 - val_loss: 14.7542 - val_mae: 3.4286 - val_r2_score_metric: -2.0358
# Epoch 27/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.2866 - mae: 3.2679 - r2_score_metric: -7.2104 - val_loss: 14.7538 - val_mae: 3.4286 - val_r2_score_metric: -2.0357
# Epoch 28/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.3572 - mae: 3.4276 - r2_score_metric: -2.5589 - val_loss: 14.7534 - val_mae: 3.4285 - val_r2_score_metric: -2.0356
# Epoch 29/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.9207 - mae: 3.3562 - r2_score_metric: -2.0376 - val_loss: 14.7531 - val_mae: 3.4285 - val_r2_score_metric: -2.0356
# Epoch 30/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.4806 - mae: 3.2933 - r2_score_metric: -2.1218 - val_loss: 14.7529 - val_mae: 3.4284 - val_r2_score_metric: -2.0355
# Epoch 31/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.4174 - mae: 3.3962 - r2_score_metric: -2.6440 - val_loss: 14.7527 - val_mae: 3.4284 - val_r2_score_metric: -2.0355
# Epoch 32/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.9300 - mae: 3.3072 - r2_score_metric: -2.8880 - val_loss: 14.7525 - val_mae: 3.4284 - val_r2_score_metric: -2.0354
# Epoch 33/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.5167 - mae: 3.4446 - r2_score_metric: -2.8856 - val_loss: 14.7524 - val_mae: 3.4284 - val_r2_score_metric: -2.0354
# Epoch 34/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.2826 - mae: 3.4304 - r2_score_metric: -3.8456 - val_loss: 14.7522 - val_mae: 3.4284 - val_r2_score_metric: -2.0354
# Epoch 35/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.3249 - mae: 3.4047 - r2_score_metric: -3.5631 - val_loss: 14.7521 - val_mae: 3.4283 - val_r2_score_metric: -2.0354
# Epoch 36/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 13.7282 - mae: 3.3176 - r2_score_metric: -3.3781 - val_loss: 14.7520 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 37/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.6444 - mae: 3.3293 - r2_score_metric: -5.1209 - val_loss: 14.7519 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 38/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.1391 - mae: 3.3982 - r2_score_metric: -2.5820 - val_loss: 14.7519 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 39/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 13.1019 - mae: 3.2348 - r2_score_metric: -2.0859 - val_loss: 14.7519 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 40/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.3277 - mae: 3.3746 - r2_score_metric: -2.4749 - val_loss: 14.7518 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 41/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7594 - mae: 3.3122 - r2_score_metric: -2.3073 - val_loss: 14.7518 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 42/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.3021 - mae: 3.3878 - r2_score_metric: -4.4164 - val_loss: 14.7518 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 43/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.9988 - mae: 3.3440 - r2_score_metric: -3.2042 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 44/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.0407 - mae: 3.3430 - r2_score_metric: -2.3897 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 45/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.6394 - mae: 3.3035 - r2_score_metric: -3.6352 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 46/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.0282 - mae: 3.3453 - r2_score_metric: -2.6952 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0353
# Epoch 47/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.0622 - mae: 3.3552 - r2_score_metric: -3.1490 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 48/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.2567 - mae: 3.2916 - r2_score_metric: -1.9921 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 49/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.7202 - mae: 3.3346 - r2_score_metric: -5.4158 - val_loss: 14.7517 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 50/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.7803 - mae: 3.4303 - r2_score_metric: -2.6014 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 51/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 13.8041 - mae: 3.3154 - r2_score_metric: -2.5985 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 52/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 14.3101 - mae: 3.3897 - r2_score_metric: -3.2003 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 53/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 13.9314 - mae: 3.3287 - r2_score_metric: -2.9310 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 54/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 14.8025 - mae: 3.4472 - r2_score_metric: -3.0596 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 55/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 14.0805 - mae: 3.3487 - r2_score_metric: -3.1758 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 56/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 13.7709 - mae: 3.3466 - r2_score_metric: -2.2779 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 57/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.7276 - mae: 3.3204 - r2_score_metric: -3.6487 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 58/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.4590 - mae: 3.2561 - r2_score_metric: -2.3665 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 59/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.6586 - mae: 3.4425 - r2_score_metric: -4.8459 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 60/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.7629 - mae: 3.2739 - r2_score_metric: -2.5290 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 61/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7867 - mae: 3.3142 - r2_score_metric: -1.9922 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 62/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.7324 - mae: 3.4247 - r2_score_metric: -5.4754 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 63/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.2571 - mae: 3.2661 - r2_score_metric: -2.2114 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 64/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.0845 - mae: 3.3698 - r2_score_metric: -2.9708 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 65/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.3461 - mae: 3.3924 - r2_score_metric: -2.2837 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 66/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.8225 - mae: 3.3005 - r2_score_metric: -2.0013 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 67/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.2158 - mae: 3.3815 - r2_score_metric: -2.9184 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 68/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.7238 - mae: 3.4477 - r2_score_metric: -3.5111 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 69/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.3848 - mae: 3.2802 - r2_score_metric: -5.4787 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 70/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.1381 - mae: 3.3851 - r2_score_metric: -6.1043 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 71/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 14.6485 - mae: 3.4179 - r2_score_metric: -15.7755 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 72/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.4387 - mae: 3.2941 - r2_score_metric: -2.3510 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 73/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.9748 - mae: 3.3684 - r2_score_metric: -3.2469 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 74/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.6983 - mae: 3.3233 - r2_score_metric: -3.0556 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 75/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 15.0558 - mae: 3.4827 - r2_score_metric: -4.0116 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 76/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7345 - mae: 3.3271 - r2_score_metric: -3.7951 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 77/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.2991 - mae: 3.2417 - r2_score_metric: -1.4400 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 78/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.2417 - mae: 3.2694 - r2_score_metric: -8.5349 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 79/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.8350 - mae: 3.3227 - r2_score_metric: -1.9938 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 80/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.5651 - mae: 3.2556 - r2_score_metric: -1.6609 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 81/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7458 - mae: 3.2959 - r2_score_metric: -2.0196 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 82/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2919 - mae: 3.3970 - r2_score_metric: -2.7583 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 83/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.0929 - mae: 3.3584 - r2_score_metric: -4.0396 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 84/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.9919 - mae: 3.3541 - r2_score_metric: -3.2843 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 85/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2140 - mae: 3.3700 - r2_score_metric: -3.1631 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 86/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.5253 - mae: 3.4027 - r2_score_metric: -3.2208 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 87/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.3927 - mae: 3.2466 - r2_score_metric: -2.0425 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 88/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.4850 - mae: 3.4063 - r2_score_metric: -4.2129 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 89/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.9989 - mae: 3.3649 - r2_score_metric: -2.5456 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 90/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7251 - mae: 3.4479 - r2_score_metric: -4.6277 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 91/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.9378 - mae: 3.3497 - r2_score_metric: -2.6219 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 92/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.3530 - mae: 3.3806 - r2_score_metric: -16.4097 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 93/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.7510 - mae: 3.3294 - r2_score_metric: -27.8105 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 94/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.3878 - mae: 3.3962 - r2_score_metric: -4.1920 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 95/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.2074 - mae: 3.3737 - r2_score_metric: -2.5881 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 96/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.8320 - mae: 3.3252 - r2_score_metric: -3.9189 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 97/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.1472 - mae: 3.2638 - r2_score_metric: -2.9369 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 98/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.4924 - mae: 3.4158 - r2_score_metric: -3.1444 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 99/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.5201 - mae: 3.2867 - r2_score_metric: -2.5820 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# Epoch 100/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7525 - mae: 3.3237 - r2_score_metric: -2.7108 - val_loss: 14.7516 - val_mae: 3.4283 - val_r2_score_metric: -2.0352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step
#
# Target Variable: RH In
# MAE: 2.80
# R²: 0.11
# Epoch 1/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.9415 - mae: 0.7380 - r2_score_metric: -1.6867 - val_loss: 0.4003 - val_mae: 0.3733 - val_r2_score_metric: -0.2959
# Epoch 2/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2630 - mae: 0.3506 - r2_score_metric: 0.6485 - val_loss: 0.3972 - val_mae: 0.3644 - val_r2_score_metric: -0.3012
# Epoch 3/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2540 - mae: 0.3445 - r2_score_metric: -0.5262 - val_loss: 0.3966 - val_mae: 0.3621 - val_r2_score_metric: -0.3028
# Epoch 4/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2766 - mae: 0.3489 - r2_score_metric: -0.0044 - val_loss: 0.3963 - val_mae: 0.3611 - val_r2_score_metric: -0.3038
# Epoch 5/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2580 - mae: 0.3442 - r2_score_metric: 0.6860 - val_loss: 0.3961 - val_mae: 0.3604 - val_r2_score_metric: -0.3043
# Epoch 6/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2613 - mae: 0.3461 - r2_score_metric: -0.2054 - val_loss: 0.3960 - val_mae: 0.3599 - val_r2_score_metric: -0.3048
# Epoch 7/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2802 - mae: 0.3546 - r2_score_metric: -15.3623 - val_loss: 0.3959 - val_mae: 0.3597 - val_r2_score_metric: -0.3050
# Epoch 8/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2535 - mae: 0.3352 - r2_score_metric: 0.3162 - val_loss: 0.3958 - val_mae: 0.3595 - val_r2_score_metric: -0.3052
# Epoch 9/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2590 - mae: 0.3310 - r2_score_metric: 0.4324 - val_loss: 0.3958 - val_mae: 0.3593 - val_r2_score_metric: -0.3053
# Epoch 10/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2653 - mae: 0.3474 - r2_score_metric: -6.9580 - val_loss: 0.3958 - val_mae: 0.3592 - val_r2_score_metric: -0.3054
# Epoch 11/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2720 - mae: 0.3521 - r2_score_metric: 0.8089 - val_loss: 0.3957 - val_mae: 0.3591 - val_r2_score_metric: -0.3055
# Epoch 12/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2772 - mae: 0.3382 - r2_score_metric: -659.6021 - val_loss: 0.3957 - val_mae: 0.3591 - val_r2_score_metric: -0.3056
# Epoch 13/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2702 - mae: 0.3421 - r2_score_metric: 0.0772 - val_loss: 0.3957 - val_mae: 0.3590 - val_r2_score_metric: -0.3056
# Epoch 14/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2297 - mae: 0.3257 - r2_score_metric: -1787.9119 - val_loss: 0.3957 - val_mae: 0.3590 - val_r2_score_metric: -0.3057
# Epoch 15/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2170 - mae: 0.3188 - r2_score_metric: 0.7530 - val_loss: 0.3957 - val_mae: 0.3589 - val_r2_score_metric: -0.3057
# Epoch 16/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2440 - mae: 0.3316 - r2_score_metric: -3.9958 - val_loss: 0.3957 - val_mae: 0.3589 - val_r2_score_metric: -0.3058
# Epoch 17/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2288 - mae: 0.3233 - r2_score_metric: 0.4944 - val_loss: 0.3957 - val_mae: 0.3588 - val_r2_score_metric: -0.3058
# Epoch 18/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2457 - mae: 0.3397 - r2_score_metric: 0.2321 - val_loss: 0.3957 - val_mae: 0.3588 - val_r2_score_metric: -0.3058
# Epoch 19/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2503 - mae: 0.3271 - r2_score_metric: 0.4375 - val_loss: 0.3957 - val_mae: 0.3588 - val_r2_score_metric: -0.3058
# Epoch 20/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2916 - mae: 0.3503 - r2_score_metric: -43.9180 - val_loss: 0.3957 - val_mae: 0.3588 - val_r2_score_metric: -0.3058
# Epoch 21/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2770 - mae: 0.3515 - r2_score_metric: -2.4211 - val_loss: 0.3957 - val_mae: 0.3588 - val_r2_score_metric: -0.3059
# Epoch 22/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2611 - mae: 0.3445 - r2_score_metric: 0.3379 - val_loss: 0.3957 - val_mae: 0.3588 - val_r2_score_metric: -0.3059
# Epoch 23/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2626 - mae: 0.3447 - r2_score_metric: -1.2770 - val_loss: 0.3956 - val_mae: 0.3588 - val_r2_score_metric: -0.3059
# Epoch 24/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2458 - mae: 0.3413 - r2_score_metric: 0.4348 - val_loss: 0.3956 - val_mae: 0.3588 - val_r2_score_metric: -0.3059
# Epoch 25/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - mae: 0.3531 - r2_score_metric: 0.3956 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 26/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3116 - mae: 0.3734 - r2_score_metric: -0.7398 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 27/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2428 - mae: 0.3404 - r2_score_metric: -2.1153 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 28/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2736 - mae: 0.3467 - r2_score_metric: 0.7678 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 29/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2442 - mae: 0.3274 - r2_score_metric: -4.1233 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 30/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3064 - mae: 0.3391 - r2_score_metric: -1.1886 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 31/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2408 - mae: 0.3319 - r2_score_metric: 0.7873 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 32/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2355 - mae: 0.3289 - r2_score_metric: -715.2584 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 33/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2870 - mae: 0.3584 - r2_score_metric: -0.5240 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 34/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2512 - mae: 0.3361 - r2_score_metric: -7.5739 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 35/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2581 - mae: 0.3460 - r2_score_metric: -2.9581 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 36/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2857 - mae: 0.3514 - r2_score_metric: 0.7444 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 37/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2728 - mae: 0.3455 - r2_score_metric: 0.3963 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 38/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2833 - mae: 0.3570 - r2_score_metric: 0.2637 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 39/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2425 - mae: 0.3418 - r2_score_metric: -405.5423 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 40/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2774 - mae: 0.3520 - r2_score_metric: -0.8053 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 41/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2773 - mae: 0.3466 - r2_score_metric: -2899.1924 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 42/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2464 - mae: 0.3354 - r2_score_metric: -0.0670 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 43/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2465 - mae: 0.3422 - r2_score_metric: 0.7067 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 44/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2803 - mae: 0.3437 - r2_score_metric: 0.2078 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 45/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2718 - mae: 0.3387 - r2_score_metric: -9.9147 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 46/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2574 - mae: 0.3357 - r2_score_metric: -7.2973 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 47/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2616 - mae: 0.3453 - r2_score_metric: 0.0357 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 48/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2170 - mae: 0.3206 - r2_score_metric: -6.7793 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 49/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2773 - mae: 0.3493 - r2_score_metric: -2.0448 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 50/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2306 - mae: 0.3329 - r2_score_metric: 0.4599 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 51/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2367 - mae: 0.3265 - r2_score_metric: -10.3768 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 52/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2682 - mae: 0.3534 - r2_score_metric: -1.3662 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 53/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2690 - mae: 0.3475 - r2_score_metric: -3.8626 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 54/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2386 - mae: 0.3389 - r2_score_metric: -1.4330 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 55/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2737 - mae: 0.3452 - r2_score_metric: -0.1475 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 56/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2535 - mae: 0.3392 - r2_score_metric: 0.8176 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 57/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2462 - mae: 0.3422 - r2_score_metric: -8.0569 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 58/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2207 - mae: 0.3258 - r2_score_metric: 0.8146 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 59/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2495 - mae: 0.3388 - r2_score_metric: 0.4980 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 60/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2609 - mae: 0.3452 - r2_score_metric: -0.2696 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 61/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2381 - mae: 0.3320 - r2_score_metric: -7.1894 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 62/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2443 - mae: 0.3243 - r2_score_metric: 0.6311 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 63/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2529 - mae: 0.3390 - r2_score_metric: -5.5777 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 64/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2349 - mae: 0.3346 - r2_score_metric: -2.9482 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 65/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2814 - mae: 0.3619 - r2_score_metric: 0.6816 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 66/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2592 - mae: 0.3402 - r2_score_metric: -0.1520 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 67/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2571 - mae: 0.3300 - r2_score_metric: 0.7253 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 68/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2458 - mae: 0.3363 - r2_score_metric: 0.6516 - val_loss: 0.3956 - val_mae: 0.3587 - val_r2_score_metric: -0.3059
# Epoch 69/100
# ...
# Epoch 20/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.7565 - mae: 2.9557 - r2_score_metric: -396040992.0000 - val_loss: 16.1819 - val_mae: 2.8096 - val_r2_score_metric: -286673600.0000
# Epoch 21/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.3485 - mae: 2.7612 - r2_score_metric: -316124544.0000 - val_loss: 15.9323 - val_mae: 2.7481 - val_r2_score_metric: -283570464.0000
# Epoch 22/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.2420 - mae: 2.6153 - r2_score_metric: -279969536.0000 - val_loss: 16.2781 - val_mae: 2.7668 - val_r2_score_metric: -285440064.0000
# Epoch 23/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.2731 - mae: 2.6734 - r2_score_metric: -323481248.0000 - val_loss: 16.7865 - val_mae: 2.8351 - val_r2_score_metric: -289030496.0000
# Epoch 24/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.1499 - mae: 2.9030 - r2_score_metric: -317699840.0000 - val_loss: 16.1426 - val_mae: 2.8008 - val_r2_score_metric: -287166368.0000
# Epoch 25/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.6403 - mae: 2.8315 - r2_score_metric: -289957088.0000 - val_loss: 16.4109 - val_mae: 2.7649 - val_r2_score_metric: -284196064.0000
# Epoch 26/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 16.0200 - mae: 2.8768 - r2_score_metric: -292700128.0000 - val_loss: 15.9819 - val_mae: 2.7528 - val_r2_score_metric: -283677664.0000
# Epoch 27/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.9585 - mae: 2.8601 - r2_score_metric: -378340192.0000 - val_loss: 15.8746 - val_mae: 2.7356 - val_r2_score_metric: -282473760.0000
# Epoch 28/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.4919 - mae: 2.7064 - r2_score_metric: -305835328.0000 - val_loss: 16.0600 - val_mae: 2.7610 - val_r2_score_metric: -284006592.0000
# Epoch 29/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 16.0968 - mae: 2.8691 - r2_score_metric: -332110592.0000 - val_loss: 15.8025 - val_mae: 2.7507 - val_r2_score_metric: -283963680.0000
# Epoch 30/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 15.6521 - mae: 2.8405 - r2_score_metric: -367820064.0000 - val_loss: 15.8458 - val_mae: 2.7639 - val_r2_score_metric: -284438944.0000
# Epoch 31/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.7813 - mae: 2.7643 - r2_score_metric: -285417920.0000 - val_loss: 16.4702 - val_mae: 2.8045 - val_r2_score_metric: -288840928.0000
# Epoch 32/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.4586 - mae: 2.6766 - r2_score_metric: -256276976.0000 - val_loss: 16.6693 - val_mae: 2.8465 - val_r2_score_metric: -289957760.0000
# Epoch 33/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.6371 - mae: 2.8531 - r2_score_metric: -336870432.0000 - val_loss: 16.4193 - val_mae: 2.8235 - val_r2_score_metric: -289079808.0000
# Epoch 34/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.4205 - mae: 2.7683 - r2_score_metric: -285333184.0000 - val_loss: 16.1910 - val_mae: 2.7905 - val_r2_score_metric: -286870528.0000
# Epoch 35/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.6960 - mae: 2.7511 - r2_score_metric: -299113696.0000 - val_loss: 16.4055 - val_mae: 2.8429 - val_r2_score_metric: -288590720.0000
# Epoch 36/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.1815 - mae: 2.6948 - r2_score_metric: -233258048.0000 - val_loss: 16.1894 - val_mae: 2.7862 - val_r2_score_metric: -287923520.0000
# Epoch 37/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7535 - mae: 2.7638 - r2_score_metric: -309045472.0000 - val_loss: 16.0609 - val_mae: 2.7514 - val_r2_score_metric: -285271872.0000
# Epoch 38/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.9486 - mae: 2.6749 - r2_score_metric: -305565792.0000 - val_loss: 15.8550 - val_mae: 2.7048 - val_r2_score_metric: -278107200.0000
# Epoch 39/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.5716 - mae: 2.8562 - r2_score_metric: -310078752.0000 - val_loss: 15.5513 - val_mae: 2.7066 - val_r2_score_metric: -280909952.0000
# Epoch 40/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.2445 - mae: 2.7403 - r2_score_metric: -288450080.0000 - val_loss: 16.1071 - val_mae: 2.7398 - val_r2_score_metric: -292318688.0000
# Epoch 41/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.5798 - mae: 2.7084 - r2_score_metric: -266064048.0000 - val_loss: 15.8944 - val_mae: 2.7302 - val_r2_score_metric: -283967168.0000
# Epoch 42/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.4733 - mae: 2.7841 - r2_score_metric: -257724592.0000 - val_loss: 15.7602 - val_mae: 2.6878 - val_r2_score_metric: -279782304.0000
# Epoch 43/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.7227 - mae: 2.6113 - r2_score_metric: -300485472.0000 - val_loss: 15.4879 - val_mae: 2.6932 - val_r2_score_metric: -279885984.0000
# Epoch 44/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.6266 - mae: 2.8108 - r2_score_metric: -305871424.0000 - val_loss: 15.5459 - val_mae: 2.7101 - val_r2_score_metric: -280879840.0000
# Epoch 45/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.9067 - mae: 2.6407 - r2_score_metric: -304347648.0000 - val_loss: 16.3445 - val_mae: 2.7920 - val_r2_score_metric: -285791456.0000
# Epoch 46/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.2491 - mae: 2.7253 - r2_score_metric: -340321504.0000 - val_loss: 16.1404 - val_mae: 2.7968 - val_r2_score_metric: -286769120.0000
# Epoch 47/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.1403 - mae: 2.7705 - r2_score_metric: -270302752.0000 - val_loss: 16.1465 - val_mae: 2.8205 - val_r2_score_metric: -288296640.0000
# Epoch 48/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.8101 - mae: 2.7089 - r2_score_metric: -329504096.0000 - val_loss: 16.1818 - val_mae: 2.7743 - val_r2_score_metric: -285384384.0000
# Epoch 49/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.8546 - mae: 2.8405 - r2_score_metric: -283032672.0000 - val_loss: 15.8093 - val_mae: 2.7085 - val_r2_score_metric: -280530432.0000
# Epoch 50/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.9468 - mae: 2.8195 - r2_score_metric: -291828864.0000 - val_loss: 15.9972 - val_mae: 2.7659 - val_r2_score_metric: -284179808.0000
# Epoch 51/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.4593 - mae: 2.8678 - r2_score_metric: -339632224.0000 - val_loss: 16.4428 - val_mae: 2.8051 - val_r2_score_metric: -286750144.0000
# Epoch 52/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.6263 - mae: 2.7252 - r2_score_metric: -278823552.0000 - val_loss: 16.1526 - val_mae: 2.7956 - val_r2_score_metric: -286336480.0000
# Epoch 53/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.6547 - mae: 2.7240 - r2_score_metric: -324229568.0000 - val_loss: 15.9909 - val_mae: 2.7510 - val_r2_score_metric: -284008096.0000
# Epoch 54/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.8481 - mae: 2.7796 - r2_score_metric: -284999712.0000 - val_loss: 16.0922 - val_mae: 2.8112 - val_r2_score_metric: -287258048.0000
# Epoch 55/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7029 - mae: 2.7814 - r2_score_metric: -295856160.0000 - val_loss: 16.0893 - val_mae: 2.7589 - val_r2_score_metric: -283558944.0000
# Epoch 56/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.6616 - mae: 2.6368 - r2_score_metric: -293555680.0000 - val_loss: 16.1298 - val_mae: 2.8132 - val_r2_score_metric: -287705696.0000
# Epoch 57/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.7977 - mae: 2.8390 - r2_score_metric: -294626464.0000 - val_loss: 15.9487 - val_mae: 2.7582 - val_r2_score_metric: -285026144.0000
# Epoch 58/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.9687 - mae: 2.7345 - r2_score_metric: -286142080.0000 - val_loss: 15.9400 - val_mae: 2.7531 - val_r2_score_metric: -283590976.0000
# Epoch 59/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.0428 - mae: 2.7600 - r2_score_metric: -279878528.0000 - val_loss: 16.0784 - val_mae: 2.7907 - val_r2_score_metric: -286318496.0000
# Epoch 60/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.0469 - mae: 2.7445 - r2_score_metric: -359163904.0000 - val_loss: 16.2477 - val_mae: 2.7957 - val_r2_score_metric: -286266496.0000
# Epoch 61/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.3888 - mae: 2.7430 - r2_score_metric: -282371168.0000 - val_loss: 16.3663 - val_mae: 2.8395 - val_r2_score_metric: -288103200.0000
# Epoch 62/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.3466 - mae: 2.7873 - r2_score_metric: -360897344.0000 - val_loss: 15.5922 - val_mae: 2.7331 - val_r2_score_metric: -282553664.0000
# Epoch 63/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.2835 - mae: 2.7166 - r2_score_metric: -290186272.0000 - val_loss: 15.8383 - val_mae: 2.7483 - val_r2_score_metric: -284619584.0000
# Epoch 64/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.0486 - mae: 2.6683 - r2_score_metric: -315627392.0000 - val_loss: 16.0698 - val_mae: 2.7249 - val_r2_score_metric: -282721376.0000
# Epoch 65/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.1537 - mae: 2.7036 - r2_score_metric: -322129856.0000 - val_loss: 15.6157 - val_mae: 2.7064 - val_r2_score_metric: -280480672.0000
# Epoch 66/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7641 - mae: 2.7593 - r2_score_metric: -331035968.0000 - val_loss: 15.5931 - val_mae: 2.7361 - val_r2_score_metric: -284062848.0000
# Epoch 67/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.8374 - mae: 2.6818 - r2_score_metric: -315205728.0000 - val_loss: 15.9040 - val_mae: 2.7536 - val_r2_score_metric: -293374592.0000
# Epoch 68/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.6820 - mae: 2.8270 - r2_score_metric: -271294816.0000 - val_loss: 16.3356 - val_mae: 2.8114 - val_r2_score_metric: -285905376.0000
# Epoch 69/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.9685 - mae: 2.8370 - r2_score_metric: -322378752.0000 - val_loss: 15.5339 - val_mae: 2.7112 - val_r2_score_metric: -281390848.0000
# Epoch 70/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7714 - mae: 2.7032 - r2_score_metric: -346460096.0000 - val_loss: 15.7744 - val_mae: 2.7162 - val_r2_score_metric: -281536448.0000
# Epoch 71/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.1529 - mae: 2.6508 - r2_score_metric: -280444352.0000 - val_loss: 15.5097 - val_mae: 2.6685 - val_r2_score_metric: -277750432.0000
# Epoch 72/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.0883 - mae: 2.6438 - r2_score_metric: -294116640.0000 - val_loss: 15.8755 - val_mae: 2.7182 - val_r2_score_metric: -280739232.0000
# Epoch 73/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.6111 - mae: 2.8501 - r2_score_metric: -304716384.0000 - val_loss: 15.7731 - val_mae: 2.6858 - val_r2_score_metric: -277933152.0000
# Epoch 74/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.5952 - mae: 2.6930 - r2_score_metric: -295952128.0000 - val_loss: 16.0193 - val_mae: 2.7203 - val_r2_score_metric: -278848800.0000
# Epoch 75/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.9805 - mae: 2.6982 - r2_score_metric: -321565728.0000 - val_loss: 16.4417 - val_mae: 2.8038 - val_r2_score_metric: -283999232.0000
# Epoch 76/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.8278 - mae: 2.8605 - r2_score_metric: -338506592.0000 - val_loss: 15.3724 - val_mae: 2.6355 - val_r2_score_metric: -276357376.0000
# Epoch 77/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7843 - mae: 2.7238 - r2_score_metric: -290427136.0000 - val_loss: 15.7471 - val_mae: 2.7547 - val_r2_score_metric: -282565056.0000
# Epoch 78/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.3913 - mae: 2.6422 - r2_score_metric: -279053216.0000 - val_loss: 15.9478 - val_mae: 2.7239 - val_r2_score_metric: -284257056.0000
# Epoch 79/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.3764 - mae: 2.6660 - r2_score_metric: -248421904.0000 - val_loss: 15.8519 - val_mae: 2.7459 - val_r2_score_metric: -282289024.0000
# Epoch 80/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.5672 - mae: 2.6431 - r2_score_metric: -261632672.0000 - val_loss: 15.6736 - val_mae: 2.7314 - val_r2_score_metric: -281729152.0000
# Epoch 81/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.5263 - mae: 2.7904 - r2_score_metric: -346737152.0000 - val_loss: 16.2666 - val_mae: 2.7525 - val_r2_score_metric: -294868608.0000
# Epoch 82/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.4652 - mae: 2.7681 - r2_score_metric: -360822432.0000 - val_loss: 15.6064 - val_mae: 2.7366 - val_r2_score_metric: -283521120.0000
# Epoch 83/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.6745 - mae: 2.7657 - r2_score_metric: -307639616.0000 - val_loss: 15.9107 - val_mae: 2.7596 - val_r2_score_metric: -284566432.0000
# Epoch 84/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.4335 - mae: 2.9986 - r2_score_metric: -387254560.0000 - val_loss: 16.0179 - val_mae: 2.7445 - val_r2_score_metric: -284657760.0000
# Epoch 85/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.7013 - mae: 2.6890 - r2_score_metric: -316336448.0000 - val_loss: 15.9467 - val_mae: 2.7596 - val_r2_score_metric: -285220800.0000
# Epoch 86/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.0520 - mae: 2.7363 - r2_score_metric: -319681920.0000 - val_loss: 15.9933 - val_mae: 2.7751 - val_r2_score_metric: -285101728.0000
# Epoch 87/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.8998 - mae: 2.8302 - r2_score_metric: -272914496.0000 - val_loss: 17.1224 - val_mae: 2.8768 - val_r2_score_metric: -291355200.0000
# Epoch 88/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.3272 - mae: 2.7672 - r2_score_metric: -259243728.0000 - val_loss: 16.2029 - val_mae: 2.7887 - val_r2_score_metric: -286408256.0000
# Epoch 89/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.8026 - mae: 2.7795 - r2_score_metric: -256475616.0000 - val_loss: 16.2000 - val_mae: 2.7982 - val_r2_score_metric: -286766784.0000
# Epoch 90/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.6377 - mae: 2.6853 - r2_score_metric: -272464288.0000 - val_loss: 16.3664 - val_mae: 2.8118 - val_r2_score_metric: -286846112.0000
# Epoch 91/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.2995 - mae: 2.7847 - r2_score_metric: -257427264.0000 - val_loss: 15.9535 - val_mae: 2.7844 - val_r2_score_metric: -283675008.0000
# Epoch 92/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.8130 - mae: 2.6741 - r2_score_metric: -295213280.0000 - val_loss: 16.1721 - val_mae: 2.7634 - val_r2_score_metric: -284483904.0000
# Epoch 93/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.6301 - mae: 2.7415 - r2_score_metric: -281544544.0000 - val_loss: 15.5981 - val_mae: 2.6749 - val_r2_score_metric: -277608960.0000
# Epoch 94/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.8712 - mae: 2.7972 - r2_score_metric: -271784544.0000 - val_loss: 16.4893 - val_mae: 2.7907 - val_r2_score_metric: -285282560.0000
# Epoch 95/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.3699 - mae: 2.7904 - r2_score_metric: -306300992.0000 - val_loss: 16.1861 - val_mae: 2.7968 - val_r2_score_metric: -286912608.0000
# Epoch 96/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.7097 - mae: 2.6518 - r2_score_metric: -294177152.0000 - val_loss: 16.4030 - val_mae: 2.8344 - val_r2_score_metric: -291982144.0000
# Epoch 97/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.4259 - mae: 2.8471 - r2_score_metric: -278454720.0000 - val_loss: 16.1522 - val_mae: 2.7919 - val_r2_score_metric: -285795424.0000
# Epoch 98/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.1305 - mae: 2.7015 - r2_score_metric: -339329376.0000 - val_loss: 16.1194 - val_mae: 2.7884 - val_r2_score_metric: -286109568.0000
# Epoch 99/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.2517 - mae: 2.6312 - r2_score_metric: -289195840.0000 - val_loss: 15.9746 - val_mae: 2.7726 - val_r2_score_metric: -285756768.0000
# Epoch 100/100
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.8765 - mae: 2.6743 - r2_score_metric: -268856512.0000 - val_loss: 16.1518 - val_mae: 2.8042 - val_r2_score_metric: -287508800.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
#
# Target Variable: CO2 In
# MAE: 1.47
# R²: 0.00

# %%
train_and_evaluate_gru_model('Temperature In', flag_train=False)

# %%
train_and_evaluate_gru_model('RH In', flag_train=False)
