# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Multiply, Add, Layer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Custom Layer to subtract from 1
class SubtractFromOne(Layer):
    def call(self, inputs):
        return 1.0 - inputs

# Custom Layer to extract a specific feature (replacing Lambda layers that slice inputs)
class ExtractFeature(Layer):
    def __init__(self, index, **kwargs):
        super(ExtractFeature, self).__init__(**kwargs)
        self.index = index

    def call(self, inputs):
        return inputs[:, :, self.index]

# Custom R2 score metric
def r2_score_metric(y_true, y_pred):
    SS_res = tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return 1 - SS_res / (SS_tot + tf.keras.backend.epsilon())

def train_and_evaluate_gru_model(target_variable, flag_train=True, _epochs=100, _batch_size=10):
    mgh_data = pd.read_excel("gru-datasets.xlsx")
    features = ['timesteps', f'{target_variable} (Predicted GL)', f'{target_variable} (Predicted NN)']
    
    X = mgh_data[features]
    y = mgh_data[f'{target_variable} (Actual)']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01, random_state=42)
    X_train_reshaped = X_train.values.reshape((X_train.shape[0], -1, X_train.shape[1]))
    X_test_reshaped = X_test.values.reshape((X_test.shape[0], -1, X_test.shape[1]))

    if flag_train:
        time_steps = X_train_reshaped.shape[1]
        features_count = X_train_reshaped.shape[2]

        input_layer = Input(shape=(time_steps, features_count), name='input_layer')
        gru_output = GRU(units=64, return_sequences=False)(input_layer)
        w_physics = Dense(1, activation='sigmoid')(gru_output)
        w_nn = SubtractFromOne()(w_physics)

        q_physics_input = ExtractFeature(index=1, name='q_physics_input')(input_layer)
        q_nn_input = ExtractFeature(index=2, name='q_nn_input')(input_layer)

        y_hat_physics = Multiply()([q_physics_input, w_physics])
        y_hat_nn = Multiply()([q_nn_input, w_nn])
        y_hat = Add()([y_hat_physics, y_hat_nn])

        model = Model(inputs=input_layer, outputs=y_hat)
        model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_metric])

        history = model.fit(X_train_reshaped, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)

        # Save model architecture and weights
        model_json = model.to_json()
        with open(f"gru-models/{target_variable.replace(' ', '_')}_gru_model.json", "w") as json_file:
            json_file.write(model_json)
        model.save_weights(f"gru-models/{target_variable.replace(' ', '_')}_gru_model.weights.h5")

        # Predict the test set after training
        y_hat_test = model.predict(X_test_reshaped)

    else:
        # Load model architecture and weights
        with open(f"gru-models/{target_variable.replace(' ', '_')}_gru_model.json", "r") as json_file:
            loaded_model_json = json_file.read()
            loaded_model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={'r2_score_metric': r2_score_metric, 'SubtractFromOne': SubtractFromOne, 'ExtractFeature': ExtractFeature})

        loaded_model.load_weights(f"gru-models/{target_variable.replace(' ', '_')}_gru_model.weights.h5")
        loaded_model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_metric])

        # Predict the test set using the loaded model
        y_hat_test = loaded_model.predict(X_test_reshaped)

    # Evaluate the model
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)

    if flag_train:
        # Plot training history
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')
        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    # Scatter plot of actual vs. predicted values
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()

    # Plot of actual vs. predicted over time
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
target_variable = ['Temperature In', 'RH In', 'PAR In', 'CO2 In']

for i in target_variable:
    train_and_evaluate_gru_model(i, flag_train=True, _epochs=200, _batch_size=4)
# Out:
# Epoch 1/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3000 - mae: 0.4177 - r2_score_metric: -0.6841 - val_loss: 0.0920 - val_mae: 0.2382 - val_r2_score_metric: 0.5411
# Epoch 2/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0881 - mae: 0.2328 - r2_score_metric: 0.4844 - val_loss: 0.0890 - val_mae: 0.2280 - val_r2_score_metric: 0.5609
# Epoch 3/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0875 - mae: 0.2260 - r2_score_metric: 0.5557 - val_loss: 0.0868 - val_mae: 0.2287 - val_r2_score_metric: 0.5692
# Epoch 4/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0845 - mae: 0.2241 - r2_score_metric: 0.3026 - val_loss: 0.0888 - val_mae: 0.2262 - val_r2_score_metric: 0.5837
# Epoch 5/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0772 - mae: 0.2170 - r2_score_metric: -1.4564 - val_loss: 0.0966 - val_mae: 0.2457 - val_r2_score_metric: 0.5543
# Epoch 6/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0841 - mae: 0.2250 - r2_score_metric: -1.3245 - val_loss: 0.0879 - val_mae: 0.2331 - val_r2_score_metric: 0.5668
# Epoch 7/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0851 - mae: 0.2195 - r2_score_metric: 0.4581 - val_loss: 0.0878 - val_mae: 0.2319 - val_r2_score_metric: 0.5636
# Epoch 8/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0840 - mae: 0.2161 - r2_score_metric: 0.5111 - val_loss: 0.0852 - val_mae: 0.2264 - val_r2_score_metric: 0.6036
# Epoch 9/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0836 - mae: 0.2203 - r2_score_metric: 0.4846 - val_loss: 0.0870 - val_mae: 0.2241 - val_r2_score_metric: 0.5795
# Epoch 10/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0842 - mae: 0.2198 - r2_score_metric: 0.3885 - val_loss: 0.0859 - val_mae: 0.2260 - val_r2_score_metric: 0.5850
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#
# Target Variable: Temperature In
# MAE: 0.32
# R²: 0.76
# Epoch 1/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 359.6364 - mae: 15.6412 - r2_score_metric: -83.0670 - val_loss: 16.7220 - val_mae: 3.6933 - val_r2_score_metric: -2.4479
# Epoch 2/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.1273 - mae: 3.5193 - r2_score_metric: -3.0057 - val_loss: 15.1022 - val_mae: 3.4772 - val_r2_score_metric: -2.1102
# Epoch 3/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.6355 - mae: 3.4386 - r2_score_metric: -2.9731 - val_loss: 14.9512 - val_mae: 3.4562 - val_r2_score_metric: -2.0779
# Epoch 4/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.0551 - mae: 3.3423 - r2_score_metric: -2.7404 - val_loss: 14.8821 - val_mae: 3.4466 - val_r2_score_metric: -2.0631
# Epoch 5/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.8699 - mae: 3.3401 - r2_score_metric: -2.9451 - val_loss: 14.8436 - val_mae: 3.4412 - val_r2_score_metric: -2.0548
# Epoch 6/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.0430 - mae: 3.3737 - r2_score_metric: -2.4168 - val_loss: 14.8197 - val_mae: 3.4378 - val_r2_score_metric: -2.0497
# Epoch 7/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.6663 - mae: 3.4382 - r2_score_metric: -3.4517 - val_loss: 14.8037 - val_mae: 3.4356 - val_r2_score_metric: -2.0463
# Epoch 8/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.2876 - mae: 3.2736 - r2_score_metric: -2.0174 - val_loss: 14.7924 - val_mae: 3.4340 - val_r2_score_metric: -2.0438
# Epoch 9/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.4873 - mae: 3.3979 - r2_score_metric: -2.4884 - val_loss: 14.7840 - val_mae: 3.4328 - val_r2_score_metric: -2.0421
# Epoch 10/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.0510 - mae: 3.3616 - r2_score_metric: -4.3293 - val_loss: 14.7763 - val_mae: 3.4318 - val_r2_score_metric: -2.0405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
#
# Target Variable: RH In
# MAE: 2.81
# R²: 0.11
# Epoch 1/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3411 - mae: 0.4282 - r2_score_metric: -0.2093 - val_loss: 0.3970 - val_mae: 0.3617 - val_r2_score_metric: -0.3031
# Epoch 2/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2623 - mae: 0.3460 - r2_score_metric: 0.7739 - val_loss: 0.3963 - val_mae: 0.3602 - val_r2_score_metric: -0.3044
# Epoch 3/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2898 - mae: 0.3517 - r2_score_metric: -35.8628 - val_loss: 0.3960 - val_mae: 0.3597 - val_r2_score_metric: -0.3049
# Epoch 4/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2850 - mae: 0.3484 - r2_score_metric: -0.3979 - val_loss: 0.3959 - val_mae: 0.3594 - val_r2_score_metric: -0.3051
# Epoch 5/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2533 - mae: 0.3442 - r2_score_metric: 0.6551 - val_loss: 0.3958 - val_mae: 0.3592 - val_r2_score_metric: -0.3052
# Epoch 6/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2400 - mae: 0.3322 - r2_score_metric: -0.1867 - val_loss: 0.3958 - val_mae: 0.3590 - val_r2_score_metric: -0.3052
# Epoch 7/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2368 - mae: 0.3327 - r2_score_metric: -11.6704 - val_loss: 0.3957 - val_mae: 0.3589 - val_r2_score_metric: -0.3051
# Epoch 8/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2429 - mae: 0.3377 - r2_score_metric: -1.5660 - val_loss: 0.3957 - val_mae: 0.3587 - val_r2_score_metric: -0.3049
# Epoch 9/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2325 - mae: 0.3314 - r2_score_metric: 0.7106 - val_loss: 0.3956 - val_mae: 0.3584 - val_r2_score_metric: -0.3043
# Epoch 10/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3186 - mae: 0.3695 - r2_score_metric: -0.0228 - val_loss: 0.3956 - val_mae: 0.3574 - val_r2_score_metric: -0.3034
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000029F59D05000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#
# Target Variable: PAR In
# MAE: 0.35
# R²: 0.97
# Epoch 1/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 31.0819 - mae: 4.0366 - r2_score_metric: -817985472.0000 - val_loss: 16.9692 - val_mae: 2.8926 - val_r2_score_metric: -309728928.0000
# Epoch 2/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.4189 - mae: 2.8433 - r2_score_metric: -326024384.0000 - val_loss: 16.5460 - val_mae: 2.8160 - val_r2_score_metric: -299206880.0000
# Epoch 3/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.8051 - mae: 2.7614 - r2_score_metric: -338806624.0000 - val_loss: 15.9982 - val_mae: 2.7564 - val_r2_score_metric: -291366464.0000
# Epoch 4/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.6437 - mae: 2.7313 - r2_score_metric: -326963488.0000 - val_loss: 15.9988 - val_mae: 2.7594 - val_r2_score_metric: -290184960.0000
# Epoch 5/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7854 - mae: 2.7366 - r2_score_metric: -265058912.0000 - val_loss: 16.1016 - val_mae: 2.7587 - val_r2_score_metric: -294181280.0000
# Epoch 6/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.2347 - mae: 2.7883 - r2_score_metric: -312177632.0000 - val_loss: 16.0353 - val_mae: 2.8118 - val_r2_score_metric: -291826528.0000
# Epoch 7/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.6449 - mae: 2.6691 - r2_score_metric: -320205696.0000 - val_loss: 16.0622 - val_mae: 2.7846 - val_r2_score_metric: -288553760.0000
# Epoch 8/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.5320 - mae: 2.6382 - r2_score_metric: -298751168.0000 - val_loss: 16.1218 - val_mae: 2.7892 - val_r2_score_metric: -287944000.0000
# Epoch 9/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.3070 - mae: 2.6266 - r2_score_metric: -319587776.0000 - val_loss: 15.7828 - val_mae: 2.7486 - val_r2_score_metric: -285556672.0000
# Epoch 10/10
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.5572 - mae: 2.7823 - r2_score_metric: -261015440.0000 - val_loss: 15.9614 - val_mae: 2.7817 - val_r2_score_metric: -287180736.0000
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000029F5C3C35B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
#
# Target Variable: CO2 In
# MAE: 1.73
# R²: 0.00

# %%
train_and_evaluate_gru_model('Temperature In', flag_train=False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
#
# Target Variable: Temperature In
# MAE: 0.32
# R²: 0.76

# %%
train_and_evaluate_gru_model('RH In', flag_train=False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
#
# Target Variable: RH In
# MAE: 2.81
# R²: 0.11
