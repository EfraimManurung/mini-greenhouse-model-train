# %% [markdown]
# # Main Program for LSTM with Dropout
#
# Main program to train the leaf temperature.
#
# Author: Efraim Manurung
#
# MSc Thesis in Information Technology Group, Wageningen University
#
# efraim.manurung@gmail.com

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Multiply, Add, Layer, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
from tensorflow.keras.optimizers import Adam
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Custom Layer to subtract from 1
class SubtractFromOne(Layer):
    def call(self, inputs):
        return 1.0 - inputs

# Custom Layer to extract a specific feature (replacing Lambda layers that slice inputs)
class ExtractFeature(Layer):
    def __init__(self, index, **kwargs):
        super(ExtractFeature, self).__init__(**kwargs)
        self.index = index

    def call(self, inputs):
        return inputs[:, :, self.index]

# Custom R2 score metric
def r2_score_metric(y_true, y_pred):
    SS_res = tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return 1 - SS_res / (SS_tot + tf.keras.backend.epsilon())

def train_and_evaluate_lstm_model(target_variable, flag_train=True, _epochs=100, _batch_size=10):
    mgh_data = pd.read_excel("lstm-datasets-leaf-5-days.xlsx")
    features = ['Timesteps [5 minutes]', f'{target_variable} (Predicted GL)', f'{target_variable} (Predicted DNN)']
    
    X = mgh_data[features]
    y = mgh_data[f'{target_variable} (Actual)']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01, random_state=42)
    X_train_reshaped = X_train.values.reshape((X_train.shape[0], -1, X_train.shape[1]))
    X_test_reshaped = X_test.values.reshape((X_test.shape[0], -1, X_test.shape[1]))

    if flag_train:
        time_steps = X_train_reshaped.shape[1]
        features_count = X_train_reshaped.shape[2]

        # Define the input layer with the appropriate shape
        input_layer = Input(shape=(time_steps, features_count), name='input_layer')

        # First LSTM layer with 64 units and dropout
        lstm_output_1 = LSTM(units=64, return_sequences=True)(input_layer)
        dropout_1 = Dropout(0.2)(lstm_output_1)

        # Second LSTM layer with 32 units and dropout
        lstm_output_2 = LSTM(units=32, return_sequences=True)(dropout_1)
        dropout_2 = Dropout(0.2)(lstm_output_2)

        # Third LSTM layer with 16 units and dropout
        lstm_output_3 = LSTM(units=16, return_sequences=False)(dropout_2)
        dropout_3 = Dropout(0.2)(lstm_output_3)

        # Dense layer followed by dropout
        w_physics = Dense(1, activation='sigmoid')(dropout_3)

        # Custom layer to subtract from 1
        w_DNN = SubtractFromOne()(w_physics)

        # Extract specific features
        q_physics_input = ExtractFeature(index=1, name='q_physics_input')(input_layer)
        q_DNN_input = ExtractFeature(index=2, name='q_DNN_input')(input_layer)

        # Calculate the final output
        y_hat_physics = Multiply()([q_physics_input, w_physics])
        y_hat_DNN = Multiply()([q_DNN_input, w_DNN])
        y_hat = Add()([y_hat_physics, y_hat_DNN])

        # Create the model
        model = Model(inputs=input_layer, outputs=y_hat)
        
        adam = Adam(learning_rate=0.001, use_ema=True, ema_momentum=0.9)
        
        model.compile(optimizer=adam, loss='mse', metrics=['mae', r2_score_metric])

        history = model.fit(X_train_reshaped, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)

        # Save model architecture and weights
        model_json = model.to_json()
        with open(f"lstm-dropout-models/{target_variable.replace(' ', '_')}_lstm_model.json", "w") as json_file:
            json_file.write(model_json)
        model.save_weights(f"lstm-dropout-models/{target_variable.replace(' ', '_')}_lstm_model.weights.h5")

        # Predict the test set after training
        y_hat_test = model.predict(X_test_reshaped)

    else:
        # Load model architecture and weights
        with open(f"lstm-dropout-models/{target_variable.replace(' ', '_')}_lstm_model.json", "r") as json_file:
            loaded_model_json = json_file.read()
            loaded_model = tf.keras.models.model_from_json(loaded_model_json, custom_objects={'r2_score_metric': r2_score_metric, 'SubtractFromOne': SubtractFromOne, 'ExtractFeature': ExtractFeature})

        loaded_model.load_weights(f"lstm-dropout-models/{target_variable.replace(' ', '_')}_lstm_model.weights.h5")
        loaded_model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_metric])

        # Predict the test set using the loaded model
        y_hat_test = loaded_model.predict(X_test_reshaped)

    # Evaluate the model
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)

    if flag_train:
        # Plot training history
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')
        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    # Scatter plot of actual vs. predicted values
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()

    # Plot of actual vs. predicted over time
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
train_and_evaluate_lstm_model('Leaf Temp', flag_train=True, _epochs=200, _batch_size=4)
# Out:
# WARNING:tensorflow:From c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.9076 - mae: 0.7753 - r2_score_metric: -0.4574 - val_loss: 0.2021 - val_mae: 0.3237 - val_r2_score_metric: 0.7777
# Epoch 2/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1820 - mae: 0.3087 - r2_score_metric: 0.8134 - val_loss: 0.2011 - val_mae: 0.3207 - val_r2_score_metric: 0.7772
# Epoch 3/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1693 - mae: 0.3067 - r2_score_metric: 0.7601 - val_loss: 0.2010 - val_mae: 0.3205 - val_r2_score_metric: 0.7773
# Epoch 4/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1776 - mae: 0.3044 - r2_score_metric: 0.7887 - val_loss: 0.2011 - val_mae: 0.3203 - val_r2_score_metric: 0.7772
# Epoch 5/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1633 - mae: 0.2989 - r2_score_metric: 0.7649 - val_loss: 0.2014 - val_mae: 0.3202 - val_r2_score_metric: 0.7766
# Epoch 6/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1782 - mae: 0.3043 - r2_score_metric: 0.8106 - val_loss: 0.2013 - val_mae: 0.3202 - val_r2_score_metric: 0.7768
# Epoch 7/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1786 - mae: 0.3096 - r2_score_metric: 0.8171 - val_loss: 0.2011 - val_mae: 0.3202 - val_r2_score_metric: 0.7771
# Epoch 8/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1855 - mae: 0.3182 - r2_score_metric: 0.7664 - val_loss: 0.2013 - val_mae: 0.3201 - val_r2_score_metric: 0.7768
# Epoch 9/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1849 - mae: 0.3103 - r2_score_metric: 0.7139 - val_loss: 0.2014 - val_mae: 0.3202 - val_r2_score_metric: 0.7766
# Epoch 10/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1720 - mae: 0.3053 - r2_score_metric: 0.7974 - val_loss: 0.2008 - val_mae: 0.3202 - val_r2_score_metric: 0.7778
# Epoch 11/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1635 - mae: 0.2908 - r2_score_metric: 0.5683 - val_loss: 0.2008 - val_mae: 0.3201 - val_r2_score_metric: 0.7777
# Epoch 12/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1800 - mae: 0.3060 - r2_score_metric: 0.8246 - val_loss: 0.2017 - val_mae: 0.3202 - val_r2_score_metric: 0.7761
# Epoch 13/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1738 - mae: 0.3046 - r2_score_metric: 0.7695 - val_loss: 0.2009 - val_mae: 0.3199 - val_r2_score_metric: 0.7774
# Epoch 14/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1605 - mae: 0.2882 - r2_score_metric: 0.8265 - val_loss: 0.2018 - val_mae: 0.3203 - val_r2_score_metric: 0.7760
# Epoch 15/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1875 - mae: 0.3100 - r2_score_metric: 0.8088 - val_loss: 0.2017 - val_mae: 0.3202 - val_r2_score_metric: 0.7762
# Epoch 16/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2307 - mae: 0.3356 - r2_score_metric: 0.7896 - val_loss: 0.2009 - val_mae: 0.3199 - val_r2_score_metric: 0.7775
# Epoch 17/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1830 - mae: 0.3095 - r2_score_metric: 0.7469 - val_loss: 0.2008 - val_mae: 0.3199 - val_r2_score_metric: 0.7777
# Epoch 18/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1778 - mae: 0.3061 - r2_score_metric: 0.7778 - val_loss: 0.2009 - val_mae: 0.3198 - val_r2_score_metric: 0.7774
# Epoch 19/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1832 - mae: 0.3141 - r2_score_metric: 0.7976 - val_loss: 0.2015 - val_mae: 0.3201 - val_r2_score_metric: 0.7765
# Epoch 20/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1915 - mae: 0.3093 - r2_score_metric: 0.8531 - val_loss: 0.2006 - val_mae: 0.3198 - val_r2_score_metric: 0.7781
# Epoch 21/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1741 - mae: 0.3050 - r2_score_metric: 0.8311 - val_loss: 0.2009 - val_mae: 0.3199 - val_r2_score_metric: 0.7775
# Epoch 22/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1798 - mae: 0.3117 - r2_score_metric: 0.7533 - val_loss: 0.2008 - val_mae: 0.3198 - val_r2_score_metric: 0.7778
# Epoch 23/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1816 - mae: 0.3099 - r2_score_metric: 0.7922 - val_loss: 0.2005 - val_mae: 0.3198 - val_r2_score_metric: 0.7785
# Epoch 24/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1828 - mae: 0.3077 - r2_score_metric: 0.7709 - val_loss: 0.2010 - val_mae: 0.3199 - val_r2_score_metric: 0.7774
# Epoch 25/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2025 - mae: 0.3169 - r2_score_metric: 0.8265 - val_loss: 0.2014 - val_mae: 0.3200 - val_r2_score_metric: 0.7767
# Epoch 26/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1944 - mae: 0.3177 - r2_score_metric: 0.8100 - val_loss: 0.2013 - val_mae: 0.3199 - val_r2_score_metric: 0.7769
# Epoch 27/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1819 - mae: 0.3071 - r2_score_metric: 0.2252 - val_loss: 0.2015 - val_mae: 0.3201 - val_r2_score_metric: 0.7764
# Epoch 28/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2024 - mae: 0.3224 - r2_score_metric: 0.7356 - val_loss: 0.2011 - val_mae: 0.3199 - val_r2_score_metric: 0.7772
# Epoch 29/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1911 - mae: 0.3181 - r2_score_metric: 0.7945 - val_loss: 0.2006 - val_mae: 0.3200 - val_r2_score_metric: 0.7783
# Epoch 30/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2178 - mae: 0.3333 - r2_score_metric: 0.8079 - val_loss: 0.2005 - val_mae: 0.3197 - val_r2_score_metric: 0.7784
# Epoch 31/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2033 - mae: 0.3228 - r2_score_metric: 0.7407 - val_loss: 0.2006 - val_mae: 0.3197 - val_r2_score_metric: 0.7782
# Epoch 32/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1821 - mae: 0.3102 - r2_score_metric: 0.8156 - val_loss: 0.2009 - val_mae: 0.3198 - val_r2_score_metric: 0.7776
# Epoch 33/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1825 - mae: 0.3084 - r2_score_metric: 0.8378 - val_loss: 0.2010 - val_mae: 0.3198 - val_r2_score_metric: 0.7774
# Epoch 34/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1768 - mae: 0.3039 - r2_score_metric: 0.8195 - val_loss: 0.2009 - val_mae: 0.3198 - val_r2_score_metric: 0.7775
# Epoch 35/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1710 - mae: 0.3024 - r2_score_metric: 0.8182 - val_loss: 0.2009 - val_mae: 0.3198 - val_r2_score_metric: 0.7775
# Epoch 36/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1914 - mae: 0.3088 - r2_score_metric: 0.8464 - val_loss: 0.2012 - val_mae: 0.3199 - val_r2_score_metric: 0.7771
# Epoch 37/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1702 - mae: 0.3022 - r2_score_metric: 0.8180 - val_loss: 0.2009 - val_mae: 0.3197 - val_r2_score_metric: 0.7776
# Epoch 38/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1955 - mae: 0.3201 - r2_score_metric: 0.8226 - val_loss: 0.2006 - val_mae: 0.3196 - val_r2_score_metric: 0.7782
# Epoch 39/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1965 - mae: 0.3217 - r2_score_metric: 0.7800 - val_loss: 0.2013 - val_mae: 0.3200 - val_r2_score_metric: 0.7769
# Epoch 40/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1956 - mae: 0.3213 - r2_score_metric: 0.6924 - val_loss: 0.2013 - val_mae: 0.3200 - val_r2_score_metric: 0.7769
# Epoch 41/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1887 - mae: 0.3155 - r2_score_metric: -135880.1250 - val_loss: 0.2009 - val_mae: 0.3198 - val_r2_score_metric: 0.7776
# Epoch 42/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1810 - mae: 0.3090 - r2_score_metric: 0.6958 - val_loss: 0.2016 - val_mae: 0.3203 - val_r2_score_metric: 0.7763
# Epoch 43/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1925 - mae: 0.3133 - r2_score_metric: 0.8112 - val_loss: 0.2010 - val_mae: 0.3200 - val_r2_score_metric: 0.7772
# Epoch 44/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2171 - mae: 0.3346 - r2_score_metric: 0.7886 - val_loss: 0.2003 - val_mae: 0.3195 - val_r2_score_metric: 0.7788
# Epoch 45/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2018 - mae: 0.3273 - r2_score_metric: 0.8164 - val_loss: 0.2001 - val_mae: 0.3194 - val_r2_score_metric: 0.7795
# Epoch 46/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1805 - mae: 0.3033 - r2_score_metric: 0.7890 - val_loss: 0.2003 - val_mae: 0.3194 - val_r2_score_metric: 0.7790
# Epoch 47/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2052 - mae: 0.3208 - r2_score_metric: 0.8266 - val_loss: 0.2006 - val_mae: 0.3195 - val_r2_score_metric: 0.7782
# Epoch 48/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1776 - mae: 0.3012 - r2_score_metric: 0.7936 - val_loss: 0.2008 - val_mae: 0.3196 - val_r2_score_metric: 0.7779
# Epoch 49/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1786 - mae: 0.3022 - r2_score_metric: 0.7920 - val_loss: 0.2004 - val_mae: 0.3194 - val_r2_score_metric: 0.7786
# Epoch 50/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2039 - mae: 0.3229 - r2_score_metric: 0.8104 - val_loss: 0.1999 - val_mae: 0.3192 - val_r2_score_metric: 0.7801
# Epoch 51/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1702 - mae: 0.3070 - r2_score_metric: 0.7921 - val_loss: 0.1999 - val_mae: 0.3193 - val_r2_score_metric: 0.7807
# Epoch 52/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1717 - mae: 0.3045 - r2_score_metric: 0.7704 - val_loss: 0.1999 - val_mae: 0.3191 - val_r2_score_metric: 0.7800
# Epoch 53/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1648 - mae: 0.2949 - r2_score_metric: 0.8150 - val_loss: 0.2010 - val_mae: 0.3199 - val_r2_score_metric: 0.7774
# Epoch 54/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1824 - mae: 0.3097 - r2_score_metric: 0.7978 - val_loss: 0.2006 - val_mae: 0.3195 - val_r2_score_metric: 0.7781
# Epoch 55/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2052 - mae: 0.3249 - r2_score_metric: 0.7751 - val_loss: 0.2013 - val_mae: 0.3199 - val_r2_score_metric: 0.7769
# Epoch 56/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1941 - mae: 0.3179 - r2_score_metric: 0.7945 - val_loss: 0.2006 - val_mae: 0.3196 - val_r2_score_metric: 0.7775
# Epoch 57/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1866 - mae: 0.3085 - r2_score_metric: 0.8053 - val_loss: 0.2008 - val_mae: 0.3195 - val_r2_score_metric: 0.7779
# Epoch 58/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1611 - mae: 0.2961 - r2_score_metric: 0.7922 - val_loss: 0.2006 - val_mae: 0.3194 - val_r2_score_metric: 0.7782
# Epoch 59/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1651 - mae: 0.2954 - r2_score_metric: 0.7655 - val_loss: 0.2002 - val_mae: 0.3189 - val_r2_score_metric: 0.7791
# Epoch 60/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2184 - mae: 0.3356 - r2_score_metric: 0.7196 - val_loss: 0.2006 - val_mae: 0.3194 - val_r2_score_metric: 0.7781
# Epoch 61/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1945 - mae: 0.3205 - r2_score_metric: 0.7978 - val_loss: 0.2001 - val_mae: 0.3189 - val_r2_score_metric: 0.7792
# Epoch 62/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1898 - mae: 0.3249 - r2_score_metric: 0.8285 - val_loss: 0.2001 - val_mae: 0.3187 - val_r2_score_metric: 0.7793
# Epoch 63/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1933 - mae: 0.3153 - r2_score_metric: 0.7431 - val_loss: 0.1999 - val_mae: 0.3186 - val_r2_score_metric: 0.7798
# Epoch 64/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1724 - mae: 0.2989 - r2_score_metric: 0.8363 - val_loss: 0.1999 - val_mae: 0.3188 - val_r2_score_metric: 0.7802
# Epoch 65/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1716 - mae: 0.2963 - r2_score_metric: 0.8255 - val_loss: 0.1999 - val_mae: 0.3187 - val_r2_score_metric: 0.7795
# Epoch 66/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1941 - mae: 0.3138 - r2_score_metric: 0.7619 - val_loss: 0.2000 - val_mae: 0.3189 - val_r2_score_metric: 0.7793
# Epoch 67/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1791 - mae: 0.3039 - r2_score_metric: 0.8257 - val_loss: 0.1997 - val_mae: 0.3187 - val_r2_score_metric: 0.7802
# Epoch 68/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2120 - mae: 0.3238 - r2_score_metric: 0.8335 - val_loss: 0.1998 - val_mae: 0.3186 - val_r2_score_metric: 0.7801
# Epoch 69/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1806 - mae: 0.3073 - r2_score_metric: 0.8208 - val_loss: 0.2006 - val_mae: 0.3192 - val_r2_score_metric: 0.7783
# Epoch 70/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1900 - mae: 0.3158 - r2_score_metric: 0.5221 - val_loss: 0.2000 - val_mae: 0.3186 - val_r2_score_metric: 0.7800
# Epoch 71/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1904 - mae: 0.3114 - r2_score_metric: 0.7764 - val_loss: 0.2002 - val_mae: 0.3188 - val_r2_score_metric: 0.7793
# Epoch 72/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2113 - mae: 0.3246 - r2_score_metric: 0.7565 - val_loss: 0.2005 - val_mae: 0.3189 - val_r2_score_metric: 0.7786
# Epoch 73/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1786 - mae: 0.3053 - r2_score_metric: 0.8018 - val_loss: 0.2005 - val_mae: 0.3194 - val_r2_score_metric: 0.7786
# Epoch 74/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1910 - mae: 0.3106 - r2_score_metric: 0.7615 - val_loss: 0.1997 - val_mae: 0.3183 - val_r2_score_metric: 0.7803
# Epoch 75/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1911 - mae: 0.3049 - r2_score_metric: 0.7941 - val_loss: 0.1999 - val_mae: 0.3185 - val_r2_score_metric: 0.7799
# Epoch 76/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1887 - mae: 0.3132 - r2_score_metric: 0.8236 - val_loss: 0.1999 - val_mae: 0.3183 - val_r2_score_metric: 0.7800
# Epoch 77/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1816 - mae: 0.3037 - r2_score_metric: 0.7767 - val_loss: 0.1998 - val_mae: 0.3185 - val_r2_score_metric: 0.7805
# Epoch 78/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1709 - mae: 0.2992 - r2_score_metric: 0.7926 - val_loss: 0.1997 - val_mae: 0.3185 - val_r2_score_metric: 0.7814
# Epoch 79/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1655 - mae: 0.3003 - r2_score_metric: 0.7153 - val_loss: 0.1998 - val_mae: 0.3184 - val_r2_score_metric: 0.7801
# Epoch 80/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1884 - mae: 0.3101 - r2_score_metric: 0.6739 - val_loss: 0.1999 - val_mae: 0.3185 - val_r2_score_metric: 0.7801
# Epoch 81/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1733 - mae: 0.2988 - r2_score_metric: 0.7551 - val_loss: 0.2010 - val_mae: 0.3197 - val_r2_score_metric: 0.7775
# Epoch 82/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1865 - mae: 0.3144 - r2_score_metric: 0.7955 - val_loss: 0.2005 - val_mae: 0.3192 - val_r2_score_metric: 0.7786
# Epoch 83/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1941 - mae: 0.3118 - r2_score_metric: 0.7776 - val_loss: 0.2003 - val_mae: 0.3190 - val_r2_score_metric: 0.7791
# Epoch 84/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1893 - mae: 0.3073 - r2_score_metric: 0.8094 - val_loss: 0.2003 - val_mae: 0.3189 - val_r2_score_metric: 0.7790
# Epoch 85/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1823 - mae: 0.3086 - r2_score_metric: 0.8342 - val_loss: 0.2005 - val_mae: 0.3191 - val_r2_score_metric: 0.7786
# Epoch 86/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1857 - mae: 0.3065 - r2_score_metric: 0.8231 - val_loss: 0.2003 - val_mae: 0.3188 - val_r2_score_metric: 0.7791
# Epoch 87/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1985 - mae: 0.3212 - r2_score_metric: 0.7397 - val_loss: 0.1999 - val_mae: 0.3185 - val_r2_score_metric: 0.7802
# Epoch 88/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1724 - mae: 0.3032 - r2_score_metric: 0.7910 - val_loss: 0.1998 - val_mae: 0.3185 - val_r2_score_metric: 0.7804
# Epoch 89/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1622 - mae: 0.2902 - r2_score_metric: 0.7753 - val_loss: 0.1999 - val_mae: 0.3185 - val_r2_score_metric: 0.7803
# Epoch 90/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1747 - mae: 0.2946 - r2_score_metric: 0.8223 - val_loss: 0.2000 - val_mae: 0.3185 - val_r2_score_metric: 0.7799
# Epoch 91/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1971 - mae: 0.3110 - r2_score_metric: 0.8084 - val_loss: 0.1997 - val_mae: 0.3183 - val_r2_score_metric: 0.7805
# Epoch 92/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1638 - mae: 0.3000 - r2_score_metric: 0.8191 - val_loss: 0.1997 - val_mae: 0.3184 - val_r2_score_metric: 0.7807
# Epoch 93/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2036 - mae: 0.3233 - r2_score_metric: 0.8140 - val_loss: 0.2002 - val_mae: 0.3187 - val_r2_score_metric: 0.7794
# Epoch 94/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1882 - mae: 0.3086 - r2_score_metric: 0.7149 - val_loss: 0.2003 - val_mae: 0.3185 - val_r2_score_metric: 0.7793
# Epoch 95/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2064 - mae: 0.3135 - r2_score_metric: 0.8297 - val_loss: 0.1998 - val_mae: 0.3183 - val_r2_score_metric: 0.7805
# Epoch 96/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1780 - mae: 0.3018 - r2_score_metric: 0.7212 - val_loss: 0.1993 - val_mae: 0.3183 - val_r2_score_metric: 0.7812
# Epoch 97/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2053 - mae: 0.3215 - r2_score_metric: 0.7715 - val_loss: 0.2003 - val_mae: 0.3195 - val_r2_score_metric: 0.7803
# Epoch 98/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1697 - mae: 0.2952 - r2_score_metric: 0.5144 - val_loss: 0.1995 - val_mae: 0.3186 - val_r2_score_metric: 0.7800
# Epoch 99/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1811 - mae: 0.3092 - r2_score_metric: 0.4528 - val_loss: 0.1993 - val_mae: 0.3185 - val_r2_score_metric: 0.7815
# Epoch 100/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1687 - mae: 0.3018 - r2_score_metric: 0.6750 - val_loss: 0.1993 - val_mae: 0.3184 - val_r2_score_metric: 0.7806
# Epoch 101/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1765 - mae: 0.2994 - r2_score_metric: 0.8074 - val_loss: 0.1996 - val_mae: 0.3186 - val_r2_score_metric: 0.7798
# Epoch 102/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1824 - mae: 0.3048 - r2_score_metric: 0.8074 - val_loss: 0.1996 - val_mae: 0.3186 - val_r2_score_metric: 0.7797
# Epoch 103/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1880 - mae: 0.3072 - r2_score_metric: 0.7706 - val_loss: 0.1996 - val_mae: 0.3185 - val_r2_score_metric: 0.7794
# Epoch 104/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1855 - mae: 0.3109 - r2_score_metric: 0.7730 - val_loss: 0.1996 - val_mae: 0.3186 - val_r2_score_metric: 0.7797
# Epoch 105/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2032 - mae: 0.3197 - r2_score_metric: 0.7726 - val_loss: 0.1992 - val_mae: 0.3179 - val_r2_score_metric: 0.7803
# Epoch 106/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1736 - mae: 0.3047 - r2_score_metric: -73317.4375 - val_loss: 0.1994 - val_mae: 0.3188 - val_r2_score_metric: 0.7797
# Epoch 107/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1817 - mae: 0.3025 - r2_score_metric: 0.7521 - val_loss: 0.1993 - val_mae: 0.3174 - val_r2_score_metric: 0.7805
# Epoch 108/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1937 - mae: 0.3226 - r2_score_metric: 0.7206 - val_loss: 0.1988 - val_mae: 0.3176 - val_r2_score_metric: 0.7809
# Epoch 109/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1848 - mae: 0.3131 - r2_score_metric: 0.8120 - val_loss: 0.1989 - val_mae: 0.3171 - val_r2_score_metric: 0.7832
# Epoch 110/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1838 - mae: 0.3089 - r2_score_metric: 0.7934 - val_loss: 0.1990 - val_mae: 0.3170 - val_r2_score_metric: 0.7822
# Epoch 111/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1779 - mae: 0.3082 - r2_score_metric: 0.8069 - val_loss: 0.1983 - val_mae: 0.3163 - val_r2_score_metric: 0.7820
# Epoch 112/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1782 - mae: 0.3049 - r2_score_metric: 0.7649 - val_loss: 0.1987 - val_mae: 0.3179 - val_r2_score_metric: 0.7810
# Epoch 113/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1737 - mae: 0.3032 - r2_score_metric: 0.8451 - val_loss: 0.1991 - val_mae: 0.3183 - val_r2_score_metric: 0.7803
# Epoch 114/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2087 - mae: 0.3199 - r2_score_metric: 0.7900 - val_loss: 0.1985 - val_mae: 0.3176 - val_r2_score_metric: 0.7816
# Epoch 115/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1865 - mae: 0.3135 - r2_score_metric: 0.7609 - val_loss: 0.1995 - val_mae: 0.3169 - val_r2_score_metric: 0.7822
# Epoch 116/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1686 - mae: 0.3043 - r2_score_metric: 0.8077 - val_loss: 0.1987 - val_mae: 0.3181 - val_r2_score_metric: 0.7827
# Epoch 117/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1879 - mae: 0.3165 - r2_score_metric: 0.7879 - val_loss: 0.1981 - val_mae: 0.3175 - val_r2_score_metric: 0.7824
# Epoch 118/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1862 - mae: 0.3114 - r2_score_metric: 0.7620 - val_loss: 0.1984 - val_mae: 0.3175 - val_r2_score_metric: 0.7836
# Epoch 119/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1978 - mae: 0.3260 - r2_score_metric: 0.6257 - val_loss: 0.1983 - val_mae: 0.3176 - val_r2_score_metric: 0.7816
# Epoch 120/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1862 - mae: 0.2991 - r2_score_metric: 0.8358 - val_loss: 0.1982 - val_mae: 0.3175 - val_r2_score_metric: 0.7819
# Epoch 121/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1981 - mae: 0.3112 - r2_score_metric: 0.8387 - val_loss: 0.1985 - val_mae: 0.3180 - val_r2_score_metric: 0.7815
# Epoch 122/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1668 - mae: 0.2927 - r2_score_metric: 0.8218 - val_loss: 0.1990 - val_mae: 0.3182 - val_r2_score_metric: 0.7803
# Epoch 123/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1711 - mae: 0.2977 - r2_score_metric: 0.7706 - val_loss: 0.1985 - val_mae: 0.3176 - val_r2_score_metric: 0.7830
# Epoch 124/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1835 - mae: 0.3052 - r2_score_metric: 0.5806 - val_loss: 0.1984 - val_mae: 0.3178 - val_r2_score_metric: 0.7816
# Epoch 125/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1850 - mae: 0.3057 - r2_score_metric: 0.7848 - val_loss: 0.1982 - val_mae: 0.3177 - val_r2_score_metric: 0.7823
# Epoch 126/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1604 - mae: 0.2992 - r2_score_metric: 0.7506 - val_loss: 0.1985 - val_mae: 0.3178 - val_r2_score_metric: 0.7812
# Epoch 127/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1709 - mae: 0.3005 - r2_score_metric: 0.8225 - val_loss: 0.1997 - val_mae: 0.3169 - val_r2_score_metric: 0.7819
# Epoch 128/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1656 - mae: 0.2979 - r2_score_metric: 0.8102 - val_loss: 0.1973 - val_mae: 0.3162 - val_r2_score_metric: 0.7833
# Epoch 129/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1805 - mae: 0.3065 - r2_score_metric: 0.6839 - val_loss: 0.1963 - val_mae: 0.3143 - val_r2_score_metric: 0.7866
# Epoch 130/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1872 - mae: 0.3052 - r2_score_metric: 0.8471 - val_loss: 0.1987 - val_mae: 0.3152 - val_r2_score_metric: 0.7865
# Epoch 131/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1933 - mae: 0.3141 - r2_score_metric: 0.7753 - val_loss: 0.1965 - val_mae: 0.3145 - val_r2_score_metric: 0.7859
# Epoch 132/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1795 - mae: 0.3076 - r2_score_metric: 0.7629 - val_loss: 0.1970 - val_mae: 0.3147 - val_r2_score_metric: 0.7847
# Epoch 133/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1762 - mae: 0.2941 - r2_score_metric: 0.7497 - val_loss: 0.1971 - val_mae: 0.3148 - val_r2_score_metric: 0.7845
# Epoch 134/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1846 - mae: 0.3024 - r2_score_metric: 0.8227 - val_loss: 0.1978 - val_mae: 0.3171 - val_r2_score_metric: 0.7827
# Epoch 135/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2011 - mae: 0.3165 - r2_score_metric: 0.7467 - val_loss: 0.1990 - val_mae: 0.3180 - val_r2_score_metric: 0.7803
# Epoch 136/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2067 - mae: 0.3221 - r2_score_metric: 0.7345 - val_loss: 0.1977 - val_mae: 0.3172 - val_r2_score_metric: 0.7827
# Epoch 137/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1894 - mae: 0.3067 - r2_score_metric: 0.8360 - val_loss: 0.1984 - val_mae: 0.3174 - val_r2_score_metric: 0.7814
# Epoch 138/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2114 - mae: 0.3215 - r2_score_metric: 0.5667 - val_loss: 0.1977 - val_mae: 0.3173 - val_r2_score_metric: 0.7830
# Epoch 139/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1839 - mae: 0.3031 - r2_score_metric: 0.7587 - val_loss: 0.1981 - val_mae: 0.3174 - val_r2_score_metric: 0.7822
# Epoch 140/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1689 - mae: 0.2970 - r2_score_metric: 0.8346 - val_loss: 0.1979 - val_mae: 0.3176 - val_r2_score_metric: 0.7823
# Epoch 141/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1947 - mae: 0.3126 - r2_score_metric: 0.7963 - val_loss: 0.1977 - val_mae: 0.3170 - val_r2_score_metric: 0.7832
# Epoch 142/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2021 - mae: 0.3096 - r2_score_metric: 0.8168 - val_loss: 0.1981 - val_mae: 0.3171 - val_r2_score_metric: 0.7821
# Epoch 143/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1908 - mae: 0.3150 - r2_score_metric: 0.7709 - val_loss: 0.1978 - val_mae: 0.3170 - val_r2_score_metric: 0.7832
# Epoch 144/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1651 - mae: 0.2929 - r2_score_metric: 0.4603 - val_loss: 0.2008 - val_mae: 0.3183 - val_r2_score_metric: 0.7790
# Epoch 145/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2106 - mae: 0.3180 - r2_score_metric: 0.8088 - val_loss: 0.1991 - val_mae: 0.3168 - val_r2_score_metric: 0.7820
# Epoch 146/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1896 - mae: 0.3033 - r2_score_metric: 0.8147 - val_loss: 0.1988 - val_mae: 0.3167 - val_r2_score_metric: 0.7825
# Epoch 147/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2004 - mae: 0.3131 - r2_score_metric: 0.7186 - val_loss: 0.1987 - val_mae: 0.3168 - val_r2_score_metric: 0.7829
# Epoch 148/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2099 - mae: 0.3225 - r2_score_metric: 0.6991 - val_loss: 0.1995 - val_mae: 0.3181 - val_r2_score_metric: 0.7812
# Epoch 149/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2047 - mae: 0.3278 - r2_score_metric: 0.8378 - val_loss: 0.1993 - val_mae: 0.3178 - val_r2_score_metric: 0.7817
# Epoch 150/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1799 - mae: 0.3098 - r2_score_metric: 0.8074 - val_loss: 0.1998 - val_mae: 0.3181 - val_r2_score_metric: 0.7798
# Epoch 151/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1868 - mae: 0.3087 - r2_score_metric: 0.7954 - val_loss: 0.1992 - val_mae: 0.3176 - val_r2_score_metric: 0.7819
# Epoch 152/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1806 - mae: 0.3015 - r2_score_metric: 0.8187 - val_loss: 0.1996 - val_mae: 0.3179 - val_r2_score_metric: 0.7804
# Epoch 153/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1767 - mae: 0.2999 - r2_score_metric: 0.8516 - val_loss: 0.1991 - val_mae: 0.3175 - val_r2_score_metric: 0.7820
# Epoch 154/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1893 - mae: 0.3122 - r2_score_metric: 0.8045 - val_loss: 0.1987 - val_mae: 0.3172 - val_r2_score_metric: 0.7832
# Epoch 155/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1809 - mae: 0.2997 - r2_score_metric: 0.8254 - val_loss: 0.1987 - val_mae: 0.3170 - val_r2_score_metric: 0.7827
# Epoch 156/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2049 - mae: 0.3165 - r2_score_metric: 0.7677 - val_loss: 0.2003 - val_mae: 0.3188 - val_r2_score_metric: 0.7784
# Epoch 157/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1994 - mae: 0.3215 - r2_score_metric: 0.8124 - val_loss: 0.1992 - val_mae: 0.3174 - val_r2_score_metric: 0.7812
# Epoch 158/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1977 - mae: 0.3150 - r2_score_metric: 0.7923 - val_loss: 0.1999 - val_mae: 0.3184 - val_r2_score_metric: 0.7795
# Epoch 159/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1712 - mae: 0.3036 - r2_score_metric: 0.8256 - val_loss: 0.1989 - val_mae: 0.3172 - val_r2_score_metric: 0.7826
# Epoch 160/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1953 - mae: 0.3176 - r2_score_metric: 0.7967 - val_loss: 0.1987 - val_mae: 0.3171 - val_r2_score_metric: 0.7831
# Epoch 161/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2092 - mae: 0.3252 - r2_score_metric: 0.7763 - val_loss: 0.1988 - val_mae: 0.3172 - val_r2_score_metric: 0.7828
# Epoch 162/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1830 - mae: 0.3046 - r2_score_metric: 0.7093 - val_loss: 0.1977 - val_mae: 0.3159 - val_r2_score_metric: 0.7858
# Epoch 163/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1717 - mae: 0.2958 - r2_score_metric: 0.6181 - val_loss: 0.1977 - val_mae: 0.3160 - val_r2_score_metric: 0.7852
# Epoch 164/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1780 - mae: 0.3063 - r2_score_metric: 0.7849 - val_loss: 0.2001 - val_mae: 0.3184 - val_r2_score_metric: 0.7795
# Epoch 165/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1760 - mae: 0.2999 - r2_score_metric: 0.8427 - val_loss: 0.1987 - val_mae: 0.3172 - val_r2_score_metric: 0.7836
# Epoch 166/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1790 - mae: 0.3069 - r2_score_metric: 0.7148 - val_loss: 0.1987 - val_mae: 0.3171 - val_r2_score_metric: 0.7832
# Epoch 167/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1704 - mae: 0.3019 - r2_score_metric: 0.8451 - val_loss: 0.1986 - val_mae: 0.3168 - val_r2_score_metric: 0.7834
# Epoch 168/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1711 - mae: 0.3069 - r2_score_metric: 0.7073 - val_loss: 0.1977 - val_mae: 0.3158 - val_r2_score_metric: 0.7854
# Epoch 169/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2054 - mae: 0.3150 - r2_score_metric: 0.5614 - val_loss: 0.1970 - val_mae: 0.3149 - val_r2_score_metric: 0.7870
# Epoch 170/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1691 - mae: 0.3070 - r2_score_metric: 0.7781 - val_loss: 0.1990 - val_mae: 0.3168 - val_r2_score_metric: 0.7808
# Epoch 171/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1819 - mae: 0.3020 - r2_score_metric: 0.7765 - val_loss: 0.1971 - val_mae: 0.3148 - val_r2_score_metric: 0.7863
# Epoch 172/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1893 - mae: 0.3062 - r2_score_metric: 0.8573 - val_loss: 0.1976 - val_mae: 0.3155 - val_r2_score_metric: 0.7847
# Epoch 173/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1962 - mae: 0.3138 - r2_score_metric: 0.6754 - val_loss: 0.1975 - val_mae: 0.3155 - val_r2_score_metric: 0.7866
# Epoch 174/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1749 - mae: 0.2964 - r2_score_metric: 0.7766 - val_loss: 0.1981 - val_mae: 0.3157 - val_r2_score_metric: 0.7834
# Epoch 175/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1645 - mae: 0.2994 - r2_score_metric: 0.8446 - val_loss: 0.1981 - val_mae: 0.3158 - val_r2_score_metric: 0.7836
# Epoch 176/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1718 - mae: 0.3016 - r2_score_metric: 0.8201 - val_loss: 0.1974 - val_mae: 0.3152 - val_r2_score_metric: 0.7854
# Epoch 177/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1892 - mae: 0.3160 - r2_score_metric: 0.8068 - val_loss: 0.1970 - val_mae: 0.3140 - val_r2_score_metric: 0.7869
# Epoch 178/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1948 - mae: 0.3092 - r2_score_metric: 0.7346 - val_loss: 0.1979 - val_mae: 0.3163 - val_r2_score_metric: 0.7848
# Epoch 179/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1948 - mae: 0.3138 - r2_score_metric: 0.7833 - val_loss: 0.1973 - val_mae: 0.3151 - val_r2_score_metric: 0.7864
# Epoch 180/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1842 - mae: 0.3053 - r2_score_metric: 0.7728 - val_loss: 0.1994 - val_mae: 0.3164 - val_r2_score_metric: 0.7798
# Epoch 181/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1879 - mae: 0.3117 - r2_score_metric: 0.7780 - val_loss: 0.1968 - val_mae: 0.3140 - val_r2_score_metric: 0.7871
# Epoch 182/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1970 - mae: 0.3084 - r2_score_metric: 0.7964 - val_loss: 0.1976 - val_mae: 0.3158 - val_r2_score_metric: 0.7867
# Epoch 183/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1838 - mae: 0.2965 - r2_score_metric: 0.7915 - val_loss: 0.1979 - val_mae: 0.3155 - val_r2_score_metric: 0.7866
# Epoch 184/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2007 - mae: 0.3180 - r2_score_metric: 0.8389 - val_loss: 0.1974 - val_mae: 0.3155 - val_r2_score_metric: 0.7866
# Epoch 185/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2057 - mae: 0.3174 - r2_score_metric: 0.7638 - val_loss: 0.1972 - val_mae: 0.3148 - val_r2_score_metric: 0.7864
# Epoch 186/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1773 - mae: 0.2986 - r2_score_metric: 0.8376 - val_loss: 0.1961 - val_mae: 0.3145 - val_r2_score_metric: 0.7865
# Epoch 187/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1955 - mae: 0.3109 - r2_score_metric: 0.8406 - val_loss: 0.1963 - val_mae: 0.3150 - val_r2_score_metric: 0.7871
# Epoch 188/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1564 - mae: 0.2875 - r2_score_metric: 0.7847 - val_loss: 0.1979 - val_mae: 0.3170 - val_r2_score_metric: 0.7824
# Epoch 189/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1852 - mae: 0.3151 - r2_score_metric: 0.7794 - val_loss: 0.1964 - val_mae: 0.3157 - val_r2_score_metric: 0.7866
# Epoch 190/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1910 - mae: 0.3161 - r2_score_metric: 0.8407 - val_loss: 0.1983 - val_mae: 0.3165 - val_r2_score_metric: 0.7830
# Epoch 191/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1756 - mae: 0.3021 - r2_score_metric: 0.7780 - val_loss: 0.1976 - val_mae: 0.3158 - val_r2_score_metric: 0.7855
# Epoch 192/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1992 - mae: 0.3148 - r2_score_metric: 0.7337 - val_loss: 0.1984 - val_mae: 0.3158 - val_r2_score_metric: 0.7822
# Epoch 193/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1825 - mae: 0.2965 - r2_score_metric: 0.4653 - val_loss: 0.1973 - val_mae: 0.3150 - val_r2_score_metric: 0.7852
# Epoch 194/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1871 - mae: 0.3025 - r2_score_metric: 0.7347 - val_loss: 0.1976 - val_mae: 0.3156 - val_r2_score_metric: 0.7846
# Epoch 195/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1859 - mae: 0.3103 - r2_score_metric: 0.6822 - val_loss: 0.1973 - val_mae: 0.3154 - val_r2_score_metric: 0.7854
# Epoch 196/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1683 - mae: 0.2899 - r2_score_metric: -885.7526 - val_loss: 0.1969 - val_mae: 0.3147 - val_r2_score_metric: 0.7868
# Epoch 197/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1746 - mae: 0.3022 - r2_score_metric: 0.8379 - val_loss: 0.1969 - val_mae: 0.3147 - val_r2_score_metric: 0.7869
# Epoch 198/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1908 - mae: 0.3114 - r2_score_metric: 0.6326 - val_loss: 0.1968 - val_mae: 0.3140 - val_r2_score_metric: 0.7867
# Epoch 199/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1767 - mae: 0.3016 - r2_score_metric: 0.7557 - val_loss: 0.1981 - val_mae: 0.3155 - val_r2_score_metric: 0.7828
# Epoch 200/200
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1855 - mae: 0.3088 - r2_score_metric: 0.7832 - val_loss: 0.1971 - val_mae: 0.3151 - val_r2_score_metric: 0.7870
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
#
# Target Variable: Leaf Temp
# MAE: 0.24
# R²: 0.95

# %%
train_and_evaluate_lstm_model('Leaf Temp', flag_train=False)
