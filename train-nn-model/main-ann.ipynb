# %% [markdown]
# # COMPLETED AUTOMATE THE PROCESS

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
import joblib

import seaborn as sns

# %%
import pandas as pd

# Load the datasets from separate files
file_path = r"completed-iot-datasets.xlsx"

# Load and clean the training dataset
mgh_data = pd.read_excel(file_path)

# Display the first few rows of the dataframe
mgh_data.head()
# Out:
#    time  global out  global in    temp in   temp out      rh in     rh out  \
# 0     0    0.032943        0.0  19.806459  22.685000  62.243682  52.775000
# 1   300    0.032943        0.0  19.806459  22.685000  62.243682  52.775000
# 2   600    0.032943        0.0  19.889053  22.745000  62.040377  52.510000
# 3   900    0.032943        0.0  20.017409  22.823333  61.694059  52.213333
# 4  1200    0.032943        0.0  20.145762  22.865000  61.322003  52.015000
#
#        co2 in  co2 out  toplights  ventilation  heater Unnamed: 12 Unnamed: 13
# 0  409.000000   1530.5          1          0.0       0    dataset3         May
# 1  409.000000   1530.5          1          0.0       0         NaN         NaN
# 2  409.000000   1506.5          1          0.0       0         NaN         NaN
# 3  408.333333   1455.0          1          0.0       0         NaN         NaN
# 4  408.000000   1413.0          1          0.0       0         NaN         NaN

# %%
def r2_score_metric(y_true, y_pred):
    """Custom R2 score metric"""
    SS_res =  tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return (1 - SS_res/(SS_tot + tf.keras.backend.epsilon()))

def train_and_evaluate_model(target_variable, flag_train, _epochs=100, _batch_size=10):
    features = ['time', 'global out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    X = mgh_data[features]
    y = mgh_data[target_variable]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.001, random_state=42)

    # Initialize and fit the scaler on the training data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    if flag_train:
        # model = Sequential()
        # model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
        # model.add(Dense(32, activation='relu'))
        # model.add(Dense(1))
        
        model = Sequential()
        model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))  # More neurons
        model.add(Dense(64, activation='relu'))  # Additional hidden layer
        model.add(Dense(32, activation='relu'))  # Additional hidden layer
        model.add(Dense(1))

        # changed adam compare to rmsprop
        model.compile(optimizer='adam', 
                      loss='mean_squared_error', 
                      metrics=['mae', r2_score_metric])

        history = model.fit(X_train_scaled, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)
        
        # Save the model in the recommended Keras format
        model.save(f'trained-nn-models/{target_variable}_model.keras')

        # Save the scaler
        joblib.dump(scaler, f'trained-nn-models/{target_variable}_scaler.pkl')

        y_hat_test = model.predict(X_test_scaled)
    else:
        # Load the model using the native Keras format
        loaded_model = load_model(f'trained-nn-models/{target_variable}_model.keras', custom_objects={'r2_score_metric': r2_score_metric})
        
        # Print model summary
        print("\nModel Summary:")
        loaded_model.summary()

        # Count total parameters
        total_params = loaded_model.count_params()
        print(f"Total number of parameters: {total_params}")
        
        # Load the scaler
        scaler = joblib.load(f'trained-nn-models/{target_variable}_scaler.pkl')
        
        # Scale the test data
        X_test_scaled = scaler.transform(X_test)
        
        y_hat_test = loaded_model.predict(X_test_scaled)

    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    if flag_train:
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')

        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
def r2_score_metric(y_true, y_pred):
    """Custom R2 score metric"""
    SS_res =  tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return (1 - SS_res/(SS_tot + tf.keras.backend.epsilon()))

def train_and_evaluate_model(target_variable, flag_train, _epochs=100, _batch_size=10):
    features = ['time', 'global out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    X = mgh_data[features]
    y = mgh_data[target_variable]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.001, random_state=42)

    # Initialize and fit the scaler on the training data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    if flag_train:
        # model = Sequential()
        # model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
        # model.add(Dense(32, activation='relu'))
        # model.add(Dense(1))
        
        model = Sequential()
        model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))  # More neurons
        model.add(Dense(64, activation='relu'))  # Additional hidden layer
        model.add(Dense(32, activation='relu'))  # Additional hidden layer
        model.add(Dense(1))

        # changed adam compare to rmsprop
        model.compile(optimizer='adam', 
                      loss='mean_squared_error', 
                      metrics=['mae', r2_score_metric])

        history = model.fit(X_train_scaled, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)
        
        # Save the model in the recommended Keras format
        model.save(f'trained-nn-models/{target_variable}_model.keras')

        # Save the scaler
        joblib.dump(scaler, f'trained-nn-models/{target_variable}_scaler.pkl')

        y_hat_test = model.predict(X_test_scaled)
    else:
        # Load the model using the native Keras format
        loaded_model = load_model(f'trained-nn-models/{target_variable}_model.keras', custom_objects={'r2_score_metric': r2_score_metric})
        
        # Print model summary
        print("\nModel Summary:")
        loaded_model.summary()

        # Count total parameters
        total_params = loaded_model.count_params()
        print(f"Total number of parameters: {total_params}")
        
        # Load the scaler
        scaler = joblib.load(f'trained-nn-models/{target_variable}_scaler.pkl')
        
        # Scale the test data
        X_test_scaled = scaler.transform(X_test)
        
        y_hat_test = loaded_model.predict(X_test_scaled)

    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    if flag_train:
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')

        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

# Iterate through each target variable and call the function
for target in target_variables:
    train_and_evaluate_model(target, flag_train = True, _epochs = 300, _batch_size= 4)
# Out:
# c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.0724 - mae: 0.4714 - r2_score_metric: -1.1931 - val_loss: 0.6848 - val_mae: 0.3773 - val_r2_score_metric: -1472.1526
# Epoch 2/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4867 - mae: 0.3122 - r2_score_metric: 0.0893 - val_loss: 0.4930 - val_mae: 0.3129 - val_r2_score_metric: -2948.2358
# Epoch 3/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.5645 - mae: 0.2933 - r2_score_metric: -4.3132 - val_loss: 0.5503 - val_mae: 0.3143 - val_r2_score_metric: -168.7624
# Epoch 4/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3948 - mae: 0.2639 - r2_score_metric: 0.4191 - val_loss: 0.4391 - val_mae: 0.2501 - val_r2_score_metric: -447.2302
# Epoch 5/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.3560 - mae: 0.2437 - r2_score_metric: -33.4839 - val_loss: 0.5630 - val_mae: 0.3257 - val_r2_score_metric: -343.3212
# Epoch 6/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3806 - mae: 0.2529 - r2_score_metric: -64.6005 - val_loss: 0.4081 - val_mae: 0.2388 - val_r2_score_metric: -1133.8080
# Epoch 7/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.4080 - mae: 0.2382 - r2_score_metric: 0.6461 - val_loss: 0.4860 - val_mae: 0.3325 - val_r2_score_metric: -148.9416
# Epoch 8/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3082 - mae: 0.2240 - r2_score_metric: 0.7775 - val_loss: 0.4781 - val_mae: 0.2901 - val_r2_score_metric: -362.6397
# Epoch 9/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3461 - mae: 0.2250 - r2_score_metric: 0.4300 - val_loss: 0.5060 - val_mae: 0.2438 - val_r2_score_metric: -546.9470
# Epoch 10/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3577 - mae: 0.2234 - r2_score_metric: 0.0237 - val_loss: 0.4556 - val_mae: 0.2293 - val_r2_score_metric: -70.5676
# Epoch 11/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.3648 - mae: 0.2274 - r2_score_metric: 0.6089 - val_loss: 0.4374 - val_mae: 0.2127 - val_r2_score_metric: -378.7122
# Epoch 12/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3559 - mae: 0.2253 - r2_score_metric: -8384.5820 - val_loss: 0.4219 - val_mae: 0.2269 - val_r2_score_metric: -219.1637
# Epoch 13/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3353 - mae: 0.2140 - r2_score_metric: 0.6084 - val_loss: 0.4073 - val_mae: 0.2169 - val_r2_score_metric: -43.2707
# Epoch 14/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.2966 - mae: 0.2072 - r2_score_metric: 0.8527 - val_loss: 0.3970 - val_mae: 0.2139 - val_r2_score_metric: -151.6051
# Epoch 15/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.3201 - mae: 0.2135 - r2_score_metric: -105.9289 - val_loss: 0.4361 - val_mae: 0.2219 - val_r2_score_metric: -471.3484
# Epoch 16/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3150 - mae: 0.2103 - r2_score_metric: -1.5997 - val_loss: 0.4294 - val_mae: 0.2170 - val_r2_score_metric: -514.6379
# Epoch 17/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3087 - mae: 0.2084 - r2_score_metric: -52.0241 - val_loss: 0.4428 - val_mae: 0.2456 - val_r2_score_metric: -308.6028
# Epoch 18/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2792 - mae: 0.2030 - r2_score_metric: 0.7625 - val_loss: 0.4495 - val_mae: 0.2249 - val_r2_score_metric: -679.7015
# Epoch 19/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.2969 - mae: 0.2046 - r2_score_metric: 0.4586 - val_loss: 0.4017 - val_mae: 0.2113 - val_r2_score_metric: -266.0576
# Epoch 20/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2554 - mae: 0.1903 - r2_score_metric: 0.6008 - val_loss: 0.4561 - val_mae: 0.2372 - val_r2_score_metric: -255.2295
# Epoch 21/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2731 - mae: 0.1946 - r2_score_metric: -0.1668 - val_loss: 0.4207 - val_mae: 0.2217 - val_r2_score_metric: -957.8074
# Epoch 22/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.2707 - mae: 0.1948 - r2_score_metric: -0.8796 - val_loss: 0.4142 - val_mae: 0.2151 - val_r2_score_metric: -869.0442
# Epoch 23/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2974 - mae: 0.1944 - r2_score_metric: 0.8442 - val_loss: 0.3591 - val_mae: 0.1962 - val_r2_score_metric: -975.3199
# Epoch 24/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2948 - mae: 0.1907 - r2_score_metric: 0.3938 - val_loss: 0.4016 - val_mae: 0.2336 - val_r2_score_metric: -701.7844
# Epoch 25/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2963 - mae: 0.1952 - r2_score_metric: 0.8016 - val_loss: 0.3600 - val_mae: 0.2201 - val_r2_score_metric: -481.6882
# Epoch 26/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2573 - mae: 0.1818 - r2_score_metric: 0.8243 - val_loss: 0.3670 - val_mae: 0.2025 - val_r2_score_metric: -699.9218
# Epoch 27/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.3129 - mae: 0.1999 - r2_score_metric: 0.7428 - val_loss: 0.3649 - val_mae: 0.2104 - val_r2_score_metric: -361.2163
# Epoch 28/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2396 - mae: 0.1769 - r2_score_metric: 0.8130 - val_loss: 0.3581 - val_mae: 0.1961 - val_r2_score_metric: -441.0273
# Epoch 29/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.2779 - mae: 0.1884 - r2_score_metric: -0.6249 - val_loss: 0.3899 - val_mae: 0.1985 - val_r2_score_metric: -691.0784
# Epoch 30/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.2478 - mae: 0.1828 - r2_score_metric: 0.8508 - val_loss: 0.4372 - val_mae: 0.2136 - val_r2_score_metric: -566.1307
# Epoch 31/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.2402 - mae: 0.1795 - r2_score_metric: -0.1894 - val_loss: 0.3980 - val_mae: 0.1924 - val_r2_score_metric: -698.8140
# Epoch 32/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2392 - mae: 0.1813 - r2_score_metric: 0.6009 - val_loss: 0.3864 - val_mae: 0.2198 - val_r2_score_metric: -964.5007
# Epoch 33/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.2509 - mae: 0.1776 - r2_score_metric: 0.5774 - val_loss: 0.3553 - val_mae: 0.1899 - val_r2_score_metric: -763.7076
# Epoch 34/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.2602 - mae: 0.1827 - r2_score_metric: 0.6800 - val_loss: 0.3920 - val_mae: 0.1985 - val_r2_score_metric: -627.5275
# Epoch 35/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2559 - mae: 0.1828 - r2_score_metric: -0.1593 - val_loss: 0.3607 - val_mae: 0.1924 - val_r2_score_metric: -577.8412
# Epoch 36/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2115 - mae: 0.1779 - r2_score_metric: 0.8266 - val_loss: 0.3908 - val_mae: 0.2309 - val_r2_score_metric: -352.8220
# Epoch 37/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2259 - mae: 0.1779 - r2_score_metric: 0.7273 - val_loss: 0.3480 - val_mae: 0.2066 - val_r2_score_metric: -104.4129
# Epoch 38/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2460 - mae: 0.1769 - r2_score_metric: -294.5812 - val_loss: 0.3470 - val_mae: 0.1860 - val_r2_score_metric: -986.0339
# Epoch 39/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2217 - mae: 0.1760 - r2_score_metric: -0.2708 - val_loss: 0.4000 - val_mae: 0.1970 - val_r2_score_metric: -601.6182
# Epoch 40/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2241 - mae: 0.1739 - r2_score_metric: -0.7621 - val_loss: 0.3744 - val_mae: 0.2056 - val_r2_score_metric: -303.6371
# Epoch 41/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2316 - mae: 0.1741 - r2_score_metric: -24.2408 - val_loss: 0.3631 - val_mae: 0.1920 - val_r2_score_metric: -557.5988
# Epoch 42/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2838 - mae: 0.1822 - r2_score_metric: 0.6363 - val_loss: 0.4056 - val_mae: 0.2108 - val_r2_score_metric: -507.2621
# Epoch 43/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2082 - mae: 0.1701 - r2_score_metric: 0.8304 - val_loss: 0.3800 - val_mae: 0.2089 - val_r2_score_metric: -484.3256
# Epoch 44/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2383 - mae: 0.1736 - r2_score_metric: 0.7924 - val_loss: 0.3719 - val_mae: 0.1965 - val_r2_score_metric: -698.2338
# Epoch 45/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2351 - mae: 0.1717 - r2_score_metric: -2877.3352 - val_loss: 0.3359 - val_mae: 0.1835 - val_r2_score_metric: -1175.6877
# Epoch 46/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2187 - mae: 0.1723 - r2_score_metric: 0.8801 - val_loss: 0.3616 - val_mae: 0.2415 - val_r2_score_metric: -1281.3004
# Epoch 47/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.2884 - mae: 0.1765 - r2_score_metric: -10682.0957 - val_loss: 0.3464 - val_mae: 0.1913 - val_r2_score_metric: -319.6933
# Epoch 48/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1850 - mae: 0.1698 - r2_score_metric: 0.8065 - val_loss: 0.3547 - val_mae: 0.2153 - val_r2_score_metric: -304.2910
# Epoch 49/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.2357 - mae: 0.1729 - r2_score_metric: 0.5663 - val_loss: 0.3408 - val_mae: 0.1853 - val_r2_score_metric: -550.4691
# Epoch 50/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.2176 - mae: 0.1646 - r2_score_metric: -0.7463 - val_loss: 0.3362 - val_mae: 0.1869 - val_r2_score_metric: -974.6840
# Epoch 51/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1825 - mae: 0.1585 - r2_score_metric: 0.2564 - val_loss: 0.3706 - val_mae: 0.1873 - val_r2_score_metric: -826.3406
# Epoch 52/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2261 - mae: 0.1705 - r2_score_metric: 0.8082 - val_loss: 0.3984 - val_mae: 0.1947 - val_r2_score_metric: -478.7654
# Epoch 53/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.2077 - mae: 0.1657 - r2_score_metric: 0.8472 - val_loss: 0.3994 - val_mae: 0.2114 - val_r2_score_metric: -210.3664
# Epoch 54/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1862 - mae: 0.1651 - r2_score_metric: -3585.6252 - val_loss: 0.3692 - val_mae: 0.1929 - val_r2_score_metric: -556.4768
# Epoch 55/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2170 - mae: 0.1664 - r2_score_metric: 0.8029 - val_loss: 0.3859 - val_mae: 0.1991 - val_r2_score_metric: -664.2596
# Epoch 56/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1854 - mae: 0.1595 - r2_score_metric: -614.9736 - val_loss: 0.3452 - val_mae: 0.1938 - val_r2_score_metric: -600.2956
# Epoch 57/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1997 - mae: 0.1624 - r2_score_metric: 0.8141 - val_loss: 0.3656 - val_mae: 0.1892 - val_r2_score_metric: -545.2922
# Epoch 58/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1836 - mae: 0.1592 - r2_score_metric: 0.7269 - val_loss: 0.3637 - val_mae: 0.1804 - val_r2_score_metric: -524.7310
# Epoch 59/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1772 - mae: 0.1575 - r2_score_metric: 0.6727 - val_loss: 0.3603 - val_mae: 0.1947 - val_r2_score_metric: -914.3136
# Epoch 60/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2013 - mae: 0.1643 - r2_score_metric: 0.8375 - val_loss: 0.3278 - val_mae: 0.2015 - val_r2_score_metric: -464.2659
# Epoch 61/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1845 - mae: 0.1597 - r2_score_metric: 0.8552 - val_loss: 0.3754 - val_mae: 0.2039 - val_r2_score_metric: -956.1572
# Epoch 62/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2034 - mae: 0.1602 - r2_score_metric: 0.4582 - val_loss: 0.3440 - val_mae: 0.1921 - val_r2_score_metric: -382.5381
# Epoch 63/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1780 - mae: 0.1578 - r2_score_metric: 0.1232 - val_loss: 0.4025 - val_mae: 0.2165 - val_r2_score_metric: -382.2571
# Epoch 64/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1912 - mae: 0.1577 - r2_score_metric: 0.6804 - val_loss: 0.3385 - val_mae: 0.1863 - val_r2_score_metric: -736.1208
# Epoch 65/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2025 - mae: 0.1599 - r2_score_metric: 0.4135 - val_loss: 0.3638 - val_mae: 0.1924 - val_r2_score_metric: -358.6820
# Epoch 66/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2034 - mae: 0.1545 - r2_score_metric: 0.7798 - val_loss: 0.3470 - val_mae: 0.1867 - val_r2_score_metric: -584.0449
# Epoch 67/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2135 - mae: 0.1593 - r2_score_metric: -6.9380 - val_loss: 0.3557 - val_mae: 0.2077 - val_r2_score_metric: -384.9443
# Epoch 68/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2126 - mae: 0.1603 - r2_score_metric: -1.8359 - val_loss: 0.3560 - val_mae: 0.1717 - val_r2_score_metric: -780.1124
# Epoch 69/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2211 - mae: 0.1658 - r2_score_metric: 0.8493 - val_loss: 0.4019 - val_mae: 0.1816 - val_r2_score_metric: -275.4059
# Epoch 70/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2271 - mae: 0.1654 - r2_score_metric: 0.6105 - val_loss: 0.3408 - val_mae: 0.1884 - val_r2_score_metric: -492.1847
# Epoch 71/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1972 - mae: 0.1590 - r2_score_metric: 0.8324 - val_loss: 0.3507 - val_mae: 0.1828 - val_r2_score_metric: -755.4432
# Epoch 72/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2377 - mae: 0.1580 - r2_score_metric: 0.8028 - val_loss: 0.3944 - val_mae: 0.1916 - val_r2_score_metric: -636.8189
# Epoch 73/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2126 - mae: 0.1614 - r2_score_metric: 0.8276 - val_loss: 0.3758 - val_mae: 0.1882 - val_r2_score_metric: -339.5212
# Epoch 74/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1853 - mae: 0.1574 - r2_score_metric: 0.7749 - val_loss: 0.3436 - val_mae: 0.1874 - val_r2_score_metric: -778.4453
# Epoch 75/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2074 - mae: 0.1615 - r2_score_metric: 0.8240 - val_loss: 0.3950 - val_mae: 0.1981 - val_r2_score_metric: -461.1519
# Epoch 76/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step - loss: 0.1972 - mae: 0.1618 - r2_score_metric: 0.8426 - val_loss: 0.3344 - val_mae: 0.1772 - val_r2_score_metric: -711.3935
# Epoch 77/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1672 - mae: 0.1507 - r2_score_metric: -1.1878 - val_loss: 0.3649 - val_mae: 0.1807 - val_r2_score_metric: -272.8497
# Epoch 78/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.1671 - mae: 0.1540 - r2_score_metric: -44.4767 - val_loss: 0.3632 - val_mae: 0.1890 - val_r2_score_metric: -1233.2993
# Epoch 79/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1689 - mae: 0.1537 - r2_score_metric: 0.8371 - val_loss: 0.3494 - val_mae: 0.1998 - val_r2_score_metric: -302.3128
# Epoch 80/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1870 - mae: 0.1526 - r2_score_metric: 0.8217 - val_loss: 0.3280 - val_mae: 0.1762 - val_r2_score_metric: -764.8970
# Epoch 81/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2038 - mae: 0.1576 - r2_score_metric: 0.5962 - val_loss: 0.3453 - val_mae: 0.1807 - val_r2_score_metric: -608.6591
# Epoch 82/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1922 - mae: 0.1524 - r2_score_metric: 0.8178 - val_loss: 0.3030 - val_mae: 0.2013 - val_r2_score_metric: -892.1160
# Epoch 83/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1924 - mae: 0.1583 - r2_score_metric: -1426.3677 - val_loss: 0.3671 - val_mae: 0.1809 - val_r2_score_metric: -606.9869
# Epoch 84/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1797 - mae: 0.1510 - r2_score_metric: -248.2675 - val_loss: 0.3726 - val_mae: 0.1815 - val_r2_score_metric: -681.3569
# Epoch 85/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1584 - mae: 0.1480 - r2_score_metric: 0.4976 - val_loss: 0.3413 - val_mae: 0.1708 - val_r2_score_metric: -808.4648
# Epoch 86/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1814 - mae: 0.1514 - r2_score_metric: -1826.1638 - val_loss: 0.3312 - val_mae: 0.1719 - val_r2_score_metric: -446.0871
# Epoch 87/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2223 - mae: 0.1532 - r2_score_metric: 0.8238 - val_loss: 0.3127 - val_mae: 0.1863 - val_r2_score_metric: -128.4964
# Epoch 88/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1985 - mae: 0.1568 - r2_score_metric: 0.8400 - val_loss: 0.3105 - val_mae: 0.1706 - val_r2_score_metric: -1342.6969
# Epoch 89/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1575 - mae: 0.1435 - r2_score_metric: -17.5085 - val_loss: 0.3258 - val_mae: 0.1730 - val_r2_score_metric: -542.4975
# Epoch 90/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.1858 - mae: 0.1517 - r2_score_metric: 0.8391 - val_loss: 0.3569 - val_mae: 0.1975 - val_r2_score_metric: -443.4567
# Epoch 91/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1721 - mae: 0.1495 - r2_score_metric: -16.2586 - val_loss: 0.3941 - val_mae: 0.2059 - val_r2_score_metric: -726.5714
# Epoch 92/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.2104 - mae: 0.1555 - r2_score_metric: -7350.0122 - val_loss: 0.3043 - val_mae: 0.1845 - val_r2_score_metric: -85.9359
# Epoch 93/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1972 - mae: 0.1525 - r2_score_metric: 0.8572 - val_loss: 0.3046 - val_mae: 0.1695 - val_r2_score_metric: -796.9987
# Epoch 94/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1772 - mae: 0.1492 - r2_score_metric: 0.5530 - val_loss: 0.3411 - val_mae: 0.1734 - val_r2_score_metric: -840.8207
# Epoch 95/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1812 - mae: 0.1553 - r2_score_metric: -24.7033 - val_loss: 0.3382 - val_mae: 0.1688 - val_r2_score_metric: -585.3652
# Epoch 96/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1560 - mae: 0.1425 - r2_score_metric: 0.6291 - val_loss: 0.3571 - val_mae: 0.1956 - val_r2_score_metric: -144.1049
# Epoch 97/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1625 - mae: 0.1483 - r2_score_metric: -1.0826 - val_loss: 0.3552 - val_mae: 0.1957 - val_r2_score_metric: -460.8263
# Epoch 98/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2235 - mae: 0.1550 - r2_score_metric: 0.1988 - val_loss: 0.2818 - val_mae: 0.1640 - val_r2_score_metric: -368.7165
# Epoch 99/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1834 - mae: 0.1483 - r2_score_metric: 0.7807 - val_loss: 0.3014 - val_mae: 0.1658 - val_r2_score_metric: -611.4977
# Epoch 100/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1707 - mae: 0.1454 - r2_score_metric: -16.9407 - val_loss: 0.3635 - val_mae: 0.2009 - val_r2_score_metric: -429.0032
# Epoch 101/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.2120 - mae: 0.1534 - r2_score_metric: 0.8572 - val_loss: 0.3673 - val_mae: 0.1845 - val_r2_score_metric: -612.8668
# Epoch 102/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1959 - mae: 0.1563 - r2_score_metric: -194.7697 - val_loss: 0.3365 - val_mae: 0.1774 - val_r2_score_metric: -531.9694
# Epoch 103/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1401 - mae: 0.1408 - r2_score_metric: 0.7301 - val_loss: 0.3484 - val_mae: 0.1713 - val_r2_score_metric: -123.4914
# Epoch 104/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1803 - mae: 0.1507 - r2_score_metric: -39.1030 - val_loss: 0.3201 - val_mae: 0.1905 - val_r2_score_metric: -324.6423
# Epoch 105/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1961 - mae: 0.1478 - r2_score_metric: 0.8698 - val_loss: 0.3146 - val_mae: 0.1682 - val_r2_score_metric: -505.2704
# Epoch 106/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1880 - mae: 0.1488 - r2_score_metric: -0.9269 - val_loss: 0.3324 - val_mae: 0.1899 - val_r2_score_metric: -784.6660
# Epoch 107/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1655 - mae: 0.1501 - r2_score_metric: 0.8387 - val_loss: 0.3446 - val_mae: 0.1763 - val_r2_score_metric: -550.2745
# Epoch 108/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1807 - mae: 0.1498 - r2_score_metric: 0.5836 - val_loss: 0.3434 - val_mae: 0.1690 - val_r2_score_metric: -540.2037
# Epoch 109/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1750 - mae: 0.1477 - r2_score_metric: 0.7473 - val_loss: 0.3682 - val_mae: 0.1771 - val_r2_score_metric: -352.8297
# Epoch 110/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1550 - mae: 0.1441 - r2_score_metric: -3239.1213 - val_loss: 0.3476 - val_mae: 0.1776 - val_r2_score_metric: -831.0027
# Epoch 111/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1733 - mae: 0.1427 - r2_score_metric: -2.4210 - val_loss: 0.3193 - val_mae: 0.1695 - val_r2_score_metric: -989.2919
# Epoch 112/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1797 - mae: 0.1460 - r2_score_metric: -8.2975 - val_loss: 0.4141 - val_mae: 0.1950 - val_r2_score_metric: -596.4932
# Epoch 113/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1809 - mae: 0.1453 - r2_score_metric: 0.8597 - val_loss: 0.3016 - val_mae: 0.1720 - val_r2_score_metric: -507.3112
# Epoch 114/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1808 - mae: 0.1422 - r2_score_metric: 0.7496 - val_loss: 0.3282 - val_mae: 0.1687 - val_r2_score_metric: -679.5005
# Epoch 115/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1774 - mae: 0.1419 - r2_score_metric: 0.7970 - val_loss: 0.3303 - val_mae: 0.1823 - val_r2_score_metric: -298.5926
# Epoch 116/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1755 - mae: 0.1411 - r2_score_metric: 0.6385 - val_loss: 0.3449 - val_mae: 0.1918 - val_r2_score_metric: -664.6202
# Epoch 117/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1790 - mae: 0.1421 - r2_score_metric: 0.8686 - val_loss: 0.3770 - val_mae: 0.1883 - val_r2_score_metric: -442.4124
# Epoch 118/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1547 - mae: 0.1361 - r2_score_metric: 0.1540 - val_loss: 0.3211 - val_mae: 0.1803 - val_r2_score_metric: -935.0648
# Epoch 119/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1906 - mae: 0.1484 - r2_score_metric: 0.9061 - val_loss: 0.3174 - val_mae: 0.1630 - val_r2_score_metric: -737.9185
# Epoch 120/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1409 - mae: 0.1365 - r2_score_metric: 0.8647 - val_loss: 0.3116 - val_mae: 0.1643 - val_r2_score_metric: -964.0949
# Epoch 121/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1485 - mae: 0.1393 - r2_score_metric: -9.3524 - val_loss: 0.3139 - val_mae: 0.1684 - val_r2_score_metric: -613.2777
# Epoch 122/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1859 - mae: 0.1455 - r2_score_metric: -173.4461 - val_loss: 0.3283 - val_mae: 0.1768 - val_r2_score_metric: -808.7051
# Epoch 123/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1753 - mae: 0.1442 - r2_score_metric: 0.8493 - val_loss: 0.3163 - val_mae: 0.1733 - val_r2_score_metric: -183.5463
# Epoch 124/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1819 - mae: 0.1419 - r2_score_metric: -2030.5300 - val_loss: 0.3448 - val_mae: 0.1643 - val_r2_score_metric: -490.1898
# Epoch 125/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1849 - mae: 0.1563 - r2_score_metric: 0.7837 - val_loss: 0.2876 - val_mae: 0.1598 - val_r2_score_metric: -612.6605
# Epoch 126/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2215 - mae: 0.1500 - r2_score_metric: -7.3542 - val_loss: 0.2989 - val_mae: 0.1723 - val_r2_score_metric: -371.5522
# Epoch 127/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1758 - mae: 0.1382 - r2_score_metric: 0.8049 - val_loss: 0.3470 - val_mae: 0.1832 - val_r2_score_metric: -589.3104
# Epoch 128/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2065 - mae: 0.1485 - r2_score_metric: 0.8780 - val_loss: 0.3069 - val_mae: 0.1648 - val_r2_score_metric: -916.6308
# Epoch 129/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1388 - mae: 0.1380 - r2_score_metric: 0.8912 - val_loss: 0.3381 - val_mae: 0.1752 - val_r2_score_metric: -588.2111
# Epoch 130/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1660 - mae: 0.1371 - r2_score_metric: 0.8958 - val_loss: 0.3259 - val_mae: 0.1834 - val_r2_score_metric: -395.6512
# Epoch 131/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1636 - mae: 0.1433 - r2_score_metric: -9.8848 - val_loss: 0.3152 - val_mae: 0.1616 - val_r2_score_metric: -295.2436
# Epoch 132/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1461 - mae: 0.1393 - r2_score_metric: 0.7614 - val_loss: 0.3034 - val_mae: 0.1578 - val_r2_score_metric: -748.0427
# Epoch 133/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1693 - mae: 0.1416 - r2_score_metric: 0.8681 - val_loss: 0.3297 - val_mae: 0.1676 - val_r2_score_metric: -348.3935
# Epoch 134/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1458 - mae: 0.1338 - r2_score_metric: -3.5665 - val_loss: 0.3584 - val_mae: 0.1927 - val_r2_score_metric: -699.1953
# Epoch 135/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1518 - mae: 0.1411 - r2_score_metric: -9169.6309 - val_loss: 0.3330 - val_mae: 0.1647 - val_r2_score_metric: -496.0077
# Epoch 136/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1457 - mae: 0.1373 - r2_score_metric: 0.9039 - val_loss: 0.3443 - val_mae: 0.1704 - val_r2_score_metric: -667.7060
# Epoch 137/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1796 - mae: 0.1415 - r2_score_metric: -191.0237 - val_loss: 0.3285 - val_mae: 0.1654 - val_r2_score_metric: -448.6360
# Epoch 138/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1513 - mae: 0.1376 - r2_score_metric: 0.8752 - val_loss: 0.3129 - val_mae: 0.1655 - val_r2_score_metric: -634.2571
# Epoch 139/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1617 - mae: 0.1429 - r2_score_metric: 0.8634 - val_loss: 0.3598 - val_mae: 0.1818 - val_r2_score_metric: -398.5065
# Epoch 140/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1613 - mae: 0.1396 - r2_score_metric: -9.6937 - val_loss: 0.3443 - val_mae: 0.1791 - val_r2_score_metric: -362.5482
# Epoch 141/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1492 - mae: 0.1388 - r2_score_metric: 0.8958 - val_loss: 0.3538 - val_mae: 0.1827 - val_r2_score_metric: -204.0205
# Epoch 142/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1453 - mae: 0.1328 - r2_score_metric: -1864.2888 - val_loss: 0.3084 - val_mae: 0.1736 - val_r2_score_metric: -225.1684
# Epoch 143/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1445 - mae: 0.1346 - r2_score_metric: 0.7928 - val_loss: 0.2910 - val_mae: 0.1620 - val_r2_score_metric: -224.7652
# Epoch 144/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1447 - mae: 0.1340 - r2_score_metric: 0.8283 - val_loss: 0.3105 - val_mae: 0.1621 - val_r2_score_metric: -508.9568
# Epoch 145/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.1546 - mae: 0.1362 - r2_score_metric: -1.4624 - val_loss: 0.3250 - val_mae: 0.1649 - val_r2_score_metric: -311.4183
# Epoch 146/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1777 - mae: 0.1325 - r2_score_metric: -5.0147 - val_loss: 0.2933 - val_mae: 0.1565 - val_r2_score_metric: -331.3561
# Epoch 147/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1339 - mae: 0.1277 - r2_score_metric: 0.9112 - val_loss: 0.3368 - val_mae: 0.1664 - val_r2_score_metric: -649.9655
# Epoch 148/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1520 - mae: 0.1368 - r2_score_metric: -8.0606 - val_loss: 0.2948 - val_mae: 0.1593 - val_r2_score_metric: -560.5813
# Epoch 149/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1300 - mae: 0.1329 - r2_score_metric: 0.8298 - val_loss: 0.3441 - val_mae: 0.1790 - val_r2_score_metric: -871.8106
# Epoch 150/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1607 - mae: 0.1383 - r2_score_metric: 0.8479 - val_loss: 0.2892 - val_mae: 0.1669 - val_r2_score_metric: -427.5085
# Epoch 151/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1374 - mae: 0.1344 - r2_score_metric: -29.2233 - val_loss: 0.2782 - val_mae: 0.1596 - val_r2_score_metric: -501.4317
# Epoch 152/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1741 - mae: 0.1363 - r2_score_metric: -0.1778 - val_loss: 0.2982 - val_mae: 0.1601 - val_r2_score_metric: -876.2479
# Epoch 153/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1788 - mae: 0.1358 - r2_score_metric: -2.6568 - val_loss: 0.3297 - val_mae: 0.1653 - val_r2_score_metric: -188.1265
# Epoch 154/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1410 - mae: 0.1290 - r2_score_metric: -109.2553 - val_loss: 0.3378 - val_mae: 0.1813 - val_r2_score_metric: -642.6187
# Epoch 155/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1492 - mae: 0.1380 - r2_score_metric: 0.8771 - val_loss: 0.3399 - val_mae: 0.1888 - val_r2_score_metric: -404.6054
# Epoch 156/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1646 - mae: 0.1424 - r2_score_metric: 0.7823 - val_loss: 0.3056 - val_mae: 0.1660 - val_r2_score_metric: -402.3232
# Epoch 157/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1335 - mae: 0.1337 - r2_score_metric: 0.7275 - val_loss: 0.2947 - val_mae: 0.1554 - val_r2_score_metric: -549.0093
# Epoch 158/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1473 - mae: 0.1312 - r2_score_metric: -300.6720 - val_loss: 0.3914 - val_mae: 0.1847 - val_r2_score_metric: -865.8948
# Epoch 159/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1856 - mae: 0.1437 - r2_score_metric: 0.8705 - val_loss: 0.3130 - val_mae: 0.1634 - val_r2_score_metric: -596.7886
# Epoch 160/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.1702 - mae: 0.1501 - r2_score_metric: -1259.6333 - val_loss: 0.3229 - val_mae: 0.1928 - val_r2_score_metric: -453.2377
# Epoch 161/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1875 - mae: 0.1496 - r2_score_metric: 0.8935 - val_loss: 0.3422 - val_mae: 0.1691 - val_r2_score_metric: -505.4583
# Epoch 162/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1418 - mae: 0.1311 - r2_score_metric: 0.8625 - val_loss: 0.3345 - val_mae: 0.1629 - val_r2_score_metric: -786.9765
# Epoch 163/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.2041 - mae: 0.1394 - r2_score_metric: 0.7337 - val_loss: 0.3717 - val_mae: 0.1712 - val_r2_score_metric: -572.4980
# Epoch 164/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.1419 - mae: 0.1378 - r2_score_metric: 0.8826 - val_loss: 0.3320 - val_mae: 0.1692 - val_r2_score_metric: -569.4003
# Epoch 165/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1585 - mae: 0.1418 - r2_score_metric: -83.0311 - val_loss: 0.3091 - val_mae: 0.1717 - val_r2_score_metric: -521.5241
# Epoch 166/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1842 - mae: 0.1377 - r2_score_metric: -71.7609 - val_loss: 0.3198 - val_mae: 0.1617 - val_r2_score_metric: -618.1267
# Epoch 167/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1934 - mae: 0.1405 - r2_score_metric: 0.7723 - val_loss: 0.2848 - val_mae: 0.1615 - val_r2_score_metric: -160.9549
# Epoch 168/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.1332 - mae: 0.1321 - r2_score_metric: 0.8638 - val_loss: 0.2937 - val_mae: 0.1577 - val_r2_score_metric: -650.8909
# Epoch 169/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1604 - mae: 0.1365 - r2_score_metric: 0.9070 - val_loss: 0.3422 - val_mae: 0.1964 - val_r2_score_metric: -1281.5529
# Epoch 170/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1178 - mae: 0.1289 - r2_score_metric: -48.9785 - val_loss: 0.2954 - val_mae: 0.1555 - val_r2_score_metric: -682.9850
# Epoch 171/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1806 - mae: 0.1396 - r2_score_metric: 0.4656 - val_loss: 0.3608 - val_mae: 0.1851 - val_r2_score_metric: -811.4932
# Epoch 172/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1168 - mae: 0.1260 - r2_score_metric: 0.9313 - val_loss: 0.3178 - val_mae: 0.1718 - val_r2_score_metric: -133.2815
# Epoch 173/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1626 - mae: 0.1352 - r2_score_metric: -0.1523 - val_loss: 0.3254 - val_mae: 0.1658 - val_r2_score_metric: -358.5034
# Epoch 174/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1410 - mae: 0.1288 - r2_score_metric: 0.9213 - val_loss: 0.3481 - val_mae: 0.1764 - val_r2_score_metric: -573.2642
# Epoch 175/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1725 - mae: 0.1372 - r2_score_metric: 0.1630 - val_loss: 0.3006 - val_mae: 0.1563 - val_r2_score_metric: -391.7574
# Epoch 176/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1351 - mae: 0.1302 - r2_score_metric: -23824.8926 - val_loss: 0.3031 - val_mae: 0.1676 - val_r2_score_metric: -478.6200
# Epoch 177/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1726 - mae: 0.1331 - r2_score_metric: 0.9198 - val_loss: 0.2860 - val_mae: 0.1649 - val_r2_score_metric: -299.7947
# Epoch 178/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1484 - mae: 0.1346 - r2_score_metric: 0.8796 - val_loss: 0.3268 - val_mae: 0.1691 - val_r2_score_metric: -256.3361
# Epoch 179/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1249 - mae: 0.1263 - r2_score_metric: -1987.9846 - val_loss: 0.2907 - val_mae: 0.1658 - val_r2_score_metric: -1076.4165
# Epoch 180/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1676 - mae: 0.1355 - r2_score_metric: -13.4521 - val_loss: 0.2983 - val_mae: 0.1649 - val_r2_score_metric: -400.0324
# Epoch 181/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1608 - mae: 0.1303 - r2_score_metric: 0.7399 - val_loss: 0.3291 - val_mae: 0.1640 - val_r2_score_metric: -594.2226
# Epoch 182/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1519 - mae: 0.1321 - r2_score_metric: 0.3420 - val_loss: 0.2849 - val_mae: 0.1593 - val_r2_score_metric: -606.2199
# Epoch 183/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1585 - mae: 0.1353 - r2_score_metric: -11329.0566 - val_loss: 0.2879 - val_mae: 0.1543 - val_r2_score_metric: -466.5585
# Epoch 184/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1174 - mae: 0.1250 - r2_score_metric: 0.8739 - val_loss: 0.3745 - val_mae: 0.1665 - val_r2_score_metric: -223.9390
# Epoch 185/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1304 - mae: 0.1269 - r2_score_metric: -4442.8057 - val_loss: 0.3071 - val_mae: 0.1600 - val_r2_score_metric: -635.2506
# Epoch 186/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1203 - mae: 0.1262 - r2_score_metric: 0.9030 - val_loss: 0.3014 - val_mae: 0.1591 - val_r2_score_metric: -583.2801
# Epoch 187/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1612 - mae: 0.1409 - r2_score_metric: 0.3124 - val_loss: 0.2943 - val_mae: 0.1504 - val_r2_score_metric: -54.9966
# Epoch 188/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1351 - mae: 0.1286 - r2_score_metric: -6864.0137 - val_loss: 0.3300 - val_mae: 0.1593 - val_r2_score_metric: -739.9767
# Epoch 189/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1516 - mae: 0.1336 - r2_score_metric: 0.9266 - val_loss: 0.2972 - val_mae: 0.1620 - val_r2_score_metric: -739.0621
# Epoch 190/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1401 - mae: 0.1292 - r2_score_metric: 0.8161 - val_loss: 0.3954 - val_mae: 0.1766 - val_r2_score_metric: -350.5383
# Epoch 191/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1592 - mae: 0.1339 - r2_score_metric: 0.9001 - val_loss: 0.3226 - val_mae: 0.1644 - val_r2_score_metric: -301.9330
# Epoch 192/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1542 - mae: 0.1352 - r2_score_metric: -88.0526 - val_loss: 0.3759 - val_mae: 0.1865 - val_r2_score_metric: -409.1298
# Epoch 193/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1601 - mae: 0.1366 - r2_score_metric: 0.8338 - val_loss: 0.3329 - val_mae: 0.1658 - val_r2_score_metric: -78.1810
# Epoch 194/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1299 - mae: 0.1290 - r2_score_metric: 0.9043 - val_loss: 0.3280 - val_mae: 0.1799 - val_r2_score_metric: -94.6331
# Epoch 195/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1619 - mae: 0.1335 - r2_score_metric: 0.8666 - val_loss: 0.3025 - val_mae: 0.1672 - val_r2_score_metric: -727.5794
# Epoch 196/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1157 - mae: 0.1243 - r2_score_metric: 0.8319 - val_loss: 0.2996 - val_mae: 0.1642 - val_r2_score_metric: -460.8929
# Epoch 197/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1499 - mae: 0.1318 - r2_score_metric: 0.7757 - val_loss: 0.3016 - val_mae: 0.1837 - val_r2_score_metric: -361.8943
# Epoch 198/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1242 - mae: 0.1266 - r2_score_metric: 0.9196 - val_loss: 0.3137 - val_mae: 0.1613 - val_r2_score_metric: -666.6161
# Epoch 199/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1165 - mae: 0.1238 - r2_score_metric: 0.8851 - val_loss: 0.2984 - val_mae: 0.1693 - val_r2_score_metric: -434.6278
# Epoch 200/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1372 - mae: 0.1259 - r2_score_metric: -11.3427 - val_loss: 0.3622 - val_mae: 0.1687 - val_r2_score_metric: -856.2050
# Epoch 201/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1597 - mae: 0.1278 - r2_score_metric: 0.8826 - val_loss: 0.3230 - val_mae: 0.1604 - val_r2_score_metric: -843.9487
# Epoch 202/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1430 - mae: 0.1271 - r2_score_metric: -16.6124 - val_loss: 0.2831 - val_mae: 0.1535 - val_r2_score_metric: -703.3502
# Epoch 203/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1304 - mae: 0.1248 - r2_score_metric: 0.8636 - val_loss: 0.3826 - val_mae: 0.1919 - val_r2_score_metric: -290.6690
# Epoch 204/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1750 - mae: 0.1413 - r2_score_metric: 0.8152 - val_loss: 0.3138 - val_mae: 0.1700 - val_r2_score_metric: -740.8955
# Epoch 205/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1267 - mae: 0.1265 - r2_score_metric: 0.8824 - val_loss: 0.2911 - val_mae: 0.1575 - val_r2_score_metric: -436.7500
# Epoch 206/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1339 - mae: 0.1282 - r2_score_metric: -0.1767 - val_loss: 0.2794 - val_mae: 0.1523 - val_r2_score_metric: -53.1934
# Epoch 207/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1235 - mae: 0.1297 - r2_score_metric: -4.2031 - val_loss: 0.3176 - val_mae: 0.1745 - val_r2_score_metric: -436.8499
# Epoch 208/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1310 - mae: 0.1266 - r2_score_metric: -902.8671 - val_loss: 0.2870 - val_mae: 0.1502 - val_r2_score_metric: -729.5145
# Epoch 209/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1299 - mae: 0.1244 - r2_score_metric: -1.7887 - val_loss: 0.2912 - val_mae: 0.1622 - val_r2_score_metric: -506.2826
# Epoch 210/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1549 - mae: 0.1262 - r2_score_metric: -1.5287 - val_loss: 0.3100 - val_mae: 0.1687 - val_r2_score_metric: -334.9238
# Epoch 211/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1444 - mae: 0.1253 - r2_score_metric: 0.8106 - val_loss: 0.3551 - val_mae: 0.1677 - val_r2_score_metric: -611.6757
# Epoch 212/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1071 - mae: 0.1216 - r2_score_metric: 0.8979 - val_loss: 0.3886 - val_mae: 0.2071 - val_r2_score_metric: -776.4246
# Epoch 213/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1217 - mae: 0.1231 - r2_score_metric: 0.9378 - val_loss: 0.2767 - val_mae: 0.1596 - val_r2_score_metric: -681.1208
# Epoch 214/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1685 - mae: 0.1335 - r2_score_metric: 0.8946 - val_loss: 0.3109 - val_mae: 0.1583 - val_r2_score_metric: -536.2643
# Epoch 215/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1101 - mae: 0.1216 - r2_score_metric: -3.7677 - val_loss: 0.3288 - val_mae: 0.1602 - val_r2_score_metric: -888.7321
# Epoch 216/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1451 - mae: 0.1233 - r2_score_metric: -99.8138 - val_loss: 0.3562 - val_mae: 0.2142 - val_r2_score_metric: -506.9261
# Epoch 217/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1611 - mae: 0.1466 - r2_score_metric: 0.8662 - val_loss: 0.3669 - val_mae: 0.1716 - val_r2_score_metric: -583.6699
# Epoch 218/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1160 - mae: 0.1213 - r2_score_metric: -74.8228 - val_loss: 0.2970 - val_mae: 0.1674 - val_r2_score_metric: -320.2423
# Epoch 219/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1272 - mae: 0.1260 - r2_score_metric: -1535.6962 - val_loss: 0.4039 - val_mae: 0.2180 - val_r2_score_metric: -745.2102
# Epoch 220/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1394 - mae: 0.1411 - r2_score_metric: -2913.8115 - val_loss: 0.3260 - val_mae: 0.1915 - val_r2_score_metric: -642.7469
# Epoch 221/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1402 - mae: 0.1492 - r2_score_metric: 0.8003 - val_loss: 0.2848 - val_mae: 0.1751 - val_r2_score_metric: -706.6160
# Epoch 222/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1132 - mae: 0.1217 - r2_score_metric: -7.1656 - val_loss: 0.3067 - val_mae: 0.1611 - val_r2_score_metric: -989.3839
# Epoch 223/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1452 - mae: 0.1303 - r2_score_metric: 0.8653 - val_loss: 0.4432 - val_mae: 0.2133 - val_r2_score_metric: -612.7601
# Epoch 224/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1732 - mae: 0.1328 - r2_score_metric: 0.8654 - val_loss: 0.3558 - val_mae: 0.1591 - val_r2_score_metric: -741.9841
# Epoch 225/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1445 - mae: 0.1243 - r2_score_metric: 0.9232 - val_loss: 0.3338 - val_mae: 0.1587 - val_r2_score_metric: -497.1188
# Epoch 226/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1036 - mae: 0.1218 - r2_score_metric: 0.8602 - val_loss: 0.3019 - val_mae: 0.1632 - val_r2_score_metric: -565.1339
# Epoch 227/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1210 - mae: 0.1189 - r2_score_metric: -28.0211 - val_loss: 0.3013 - val_mae: 0.1599 - val_r2_score_metric: -844.2910
# Epoch 228/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1357 - mae: 0.1324 - r2_score_metric: 0.9174 - val_loss: 0.2709 - val_mae: 0.1477 - val_r2_score_metric: -603.7804
# Epoch 229/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1399 - mae: 0.1304 - r2_score_metric: 0.8424 - val_loss: 0.3444 - val_mae: 0.1625 - val_r2_score_metric: -726.6927
# Epoch 230/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1198 - mae: 0.1240 - r2_score_metric: 0.8205 - val_loss: 0.3164 - val_mae: 0.1570 - val_r2_score_metric: -1054.8925
# Epoch 231/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1255 - mae: 0.1231 - r2_score_metric: 0.7988 - val_loss: 0.3031 - val_mae: 0.1568 - val_r2_score_metric: -1147.5925
# Epoch 232/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1328 - mae: 0.1218 - r2_score_metric: -108.5301 - val_loss: 0.3071 - val_mae: 0.1531 - val_r2_score_metric: -769.2403
# Epoch 233/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1576 - mae: 0.1391 - r2_score_metric: 0.8500 - val_loss: 0.3940 - val_mae: 0.2009 - val_r2_score_metric: -294.8996
# Epoch 234/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1684 - mae: 0.1368 - r2_score_metric: 0.4028 - val_loss: 0.3318 - val_mae: 0.2128 - val_r2_score_metric: -635.2021
# Epoch 235/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1385 - mae: 0.1262 - r2_score_metric: 0.6771 - val_loss: 0.3805 - val_mae: 0.1772 - val_r2_score_metric: -1439.9519
# Epoch 236/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 992us/step - loss: 0.1144 - mae: 0.1286 - r2_score_metric: 0.8427 - val_loss: 0.2620 - val_mae: 0.1579 - val_r2_score_metric: -667.4365
# Epoch 237/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1326 - mae: 0.1214 - r2_score_metric: -86.6926 - val_loss: 0.2736 - val_mae: 0.1479 - val_r2_score_metric: -481.9046
# Epoch 238/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1163 - mae: 0.1256 - r2_score_metric: 0.1831 - val_loss: 0.3261 - val_mae: 0.1573 - val_r2_score_metric: -872.1216
# Epoch 239/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1257 - mae: 0.1274 - r2_score_metric: -7.7111 - val_loss: 0.2977 - val_mae: 0.1639 - val_r2_score_metric: -730.7455
# Epoch 240/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1183 - mae: 0.1221 - r2_score_metric: -20.4919 - val_loss: 0.3044 - val_mae: 0.1664 - val_r2_score_metric: -871.6156
# Epoch 241/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1292 - mae: 0.1251 - r2_score_metric: 0.9291 - val_loss: 0.4202 - val_mae: 0.1980 - val_r2_score_metric: -564.8507
# Epoch 242/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 0.1431 - mae: 0.1370 - r2_score_metric: 0.7146 - val_loss: 0.2809 - val_mae: 0.1473 - val_r2_score_metric: -811.0198
# Epoch 243/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1133 - mae: 0.1184 - r2_score_metric: -7.0210 - val_loss: 0.3723 - val_mae: 0.1650 - val_r2_score_metric: -561.0393
# Epoch 244/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1406 - mae: 0.1243 - r2_score_metric: 0.8843 - val_loss: 0.3471 - val_mae: 0.1534 - val_r2_score_metric: -917.9357
# Epoch 245/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1120 - mae: 0.1188 - r2_score_metric: 0.9006 - val_loss: 0.2629 - val_mae: 0.1528 - val_r2_score_metric: -419.2413
# Epoch 246/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1350 - mae: 0.1264 - r2_score_metric: 0.9170 - val_loss: 0.3384 - val_mae: 0.1668 - val_r2_score_metric: -823.8177
# Epoch 247/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1121 - mae: 0.1250 - r2_score_metric: 0.8624 - val_loss: 0.2982 - val_mae: 0.1487 - val_r2_score_metric: -1063.3291
# Epoch 248/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1049 - mae: 0.1214 - r2_score_metric: 0.9155 - val_loss: 0.3208 - val_mae: 0.1913 - val_r2_score_metric: -807.5238
# Epoch 249/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1865 - mae: 0.1339 - r2_score_metric: 0.7787 - val_loss: 0.2979 - val_mae: 0.1589 - val_r2_score_metric: -622.5567
# Epoch 250/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1098 - mae: 0.1187 - r2_score_metric: 0.9143 - val_loss: 0.3461 - val_mae: 0.1609 - val_r2_score_metric: -976.3266
# Epoch 251/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.1259 - mae: 0.1267 - r2_score_metric: 0.8931 - val_loss: 0.3550 - val_mae: 0.1807 - val_r2_score_metric: -1002.1625
# Epoch 252/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1191 - mae: 0.1196 - r2_score_metric: -81.7417 - val_loss: 0.2963 - val_mae: 0.1611 - val_r2_score_metric: -746.5043
# Epoch 253/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1080 - mae: 0.1209 - r2_score_metric: -6.5443 - val_loss: 0.3047 - val_mae: 0.1570 - val_r2_score_metric: -742.8301
# Epoch 254/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1110 - mae: 0.1239 - r2_score_metric: 0.9022 - val_loss: 0.3909 - val_mae: 0.1796 - val_r2_score_metric: -450.9523
# Epoch 255/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1562 - mae: 0.1359 - r2_score_metric: 0.9050 - val_loss: 0.3235 - val_mae: 0.1609 - val_r2_score_metric: -711.9027
# Epoch 256/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1891 - mae: 0.1427 - r2_score_metric: 0.8078 - val_loss: 0.3896 - val_mae: 0.1916 - val_r2_score_metric: -937.5889
# Epoch 257/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1427 - mae: 0.1480 - r2_score_metric: 0.8443 - val_loss: 0.3394 - val_mae: 0.1768 - val_r2_score_metric: -329.0165
# Epoch 258/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1482 - mae: 0.1400 - r2_score_metric: -0.6975 - val_loss: 0.2777 - val_mae: 0.1461 - val_r2_score_metric: -571.8960
# Epoch 259/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1394 - mae: 0.1221 - r2_score_metric: 0.8513 - val_loss: 0.3121 - val_mae: 0.1550 - val_r2_score_metric: -540.3549
# Epoch 260/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1127 - mae: 0.1208 - r2_score_metric: -147.7420 - val_loss: 0.3156 - val_mae: 0.1555 - val_r2_score_metric: -559.0027
# Epoch 261/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1032 - mae: 0.1157 - r2_score_metric: 0.9342 - val_loss: 0.3279 - val_mae: 0.1631 - val_r2_score_metric: -1188.8220
# Epoch 262/300
# ...
# Epoch 221/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 214.9577 - mae: 1.7108 - r2_score_metric: -235825680.0000 - val_loss: 20.9062 - val_mae: 0.8048 - val_r2_score_metric: -15770497.0000
# Epoch 222/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 171.2026 - mae: 1.5941 - r2_score_metric: -159357984.0000 - val_loss: 21.0486 - val_mae: 0.9333 - val_r2_score_metric: -23477706.0000
# Epoch 223/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 34.8566 - mae: 1.3029 - r2_score_metric: -56380852.0000 - val_loss: 22.4386 - val_mae: 1.1089 - val_r2_score_metric: -38243276.0000
# Epoch 224/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 426.0737 - mae: 2.2238 - r2_score_metric: -382354592.0000 - val_loss: 21.5261 - val_mae: 0.8093 - val_r2_score_metric: -10569029.0000
# Epoch 225/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 194.0693 - mae: 1.4770 - r2_score_metric: -162631024.0000 - val_loss: 20.7190 - val_mae: 0.8424 - val_r2_score_metric: -16891540.0000
# Epoch 226/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 51.1975 - mae: 1.1282 - r2_score_metric: -82996672.0000 - val_loss: 20.7158 - val_mae: 1.2253 - val_r2_score_metric: -34192552.0000
# Epoch 227/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 208.2491 - mae: 1.5301 - r2_score_metric: -138295792.0000 - val_loss: 20.2204 - val_mae: 0.8053 - val_r2_score_metric: -9547841.0000
# Epoch 228/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 166.1774 - mae: 1.5975 - r2_score_metric: -160594960.0000 - val_loss: 20.4812 - val_mae: 0.8836 - val_r2_score_metric: -13831005.0000
# Epoch 229/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 22.5258 - mae: 1.1476 - r2_score_metric: -47082284.0000 - val_loss: 26.2313 - val_mae: 1.8122 - val_r2_score_metric: -80125760.0000
# Epoch 230/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 267.0721 - mae: 1.9366 - r2_score_metric: -178693440.0000 - val_loss: 21.1651 - val_mae: 0.9131 - val_r2_score_metric: -13948288.0000
# Epoch 231/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 93.1677 - mae: 1.3537 - r2_score_metric: -118916320.0000 - val_loss: 21.2025 - val_mae: 0.9648 - val_r2_score_metric: -18089038.0000
# Epoch 232/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 709.8602 - mae: 2.5982 - r2_score_metric: -436035008.0000 - val_loss: 19.9886 - val_mae: 0.7479 - val_r2_score_metric: -8384026.5000
# Epoch 233/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 121.8221 - mae: 1.5254 - r2_score_metric: -114253064.0000 - val_loss: 21.1341 - val_mae: 0.8224 - val_r2_score_metric: -11196952.0000
# Epoch 234/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 75.0870 - mae: 1.2199 - r2_score_metric: -86923872.0000 - val_loss: 20.8243 - val_mae: 0.9786 - val_r2_score_metric: -15875574.0000
# Epoch 235/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 226.6059 - mae: 1.4529 - r2_score_metric: -185229744.0000 - val_loss: 21.2918 - val_mae: 1.1711 - val_r2_score_metric: -25095436.0000
# Epoch 236/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 93.5645 - mae: 1.2487 - r2_score_metric: -106226664.0000 - val_loss: 20.5569 - val_mae: 0.8255 - val_r2_score_metric: -16448008.0000
# Epoch 237/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 200.1639 - mae: 1.5700 - r2_score_metric: -156679376.0000 - val_loss: 20.0473 - val_mae: 0.9039 - val_r2_score_metric: -17451522.0000
# Epoch 238/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 38.8173 - mae: 1.2398 - r2_score_metric: -67099012.0000 - val_loss: 22.8524 - val_mae: 1.1382 - val_r2_score_metric: -29116916.0000
# Epoch 239/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 280.4567 - mae: 1.7783 - r2_score_metric: -250982032.0000 - val_loss: 20.3268 - val_mae: 0.8386 - val_r2_score_metric: -11097650.0000
# Epoch 240/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 58.3942 - mae: 1.2302 - r2_score_metric: -78442480.0000 - val_loss: 20.6633 - val_mae: 0.9426 - val_r2_score_metric: -21605230.0000
# Epoch 241/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 46.7172 - mae: 1.0869 - r2_score_metric: -70687208.0000 - val_loss: 21.6718 - val_mae: 0.9338 - val_r2_score_metric: -20065468.0000
# Epoch 242/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 162.3244 - mae: 1.3854 - r2_score_metric: -134171000.0000 - val_loss: 21.8303 - val_mae: 0.8517 - val_r2_score_metric: -19050954.0000
# Epoch 243/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 68.0807 - mae: 1.2311 - r2_score_metric: -77096672.0000 - val_loss: 23.2475 - val_mae: 1.4264 - val_r2_score_metric: -31140868.0000
# Epoch 244/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 175.2697 - mae: 1.4993 - r2_score_metric: -190029008.0000 - val_loss: 23.0902 - val_mae: 1.4494 - val_r2_score_metric: -30260900.0000
# Epoch 245/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 25.2983 - mae: 1.0163 - r2_score_metric: -39540852.0000 - val_loss: 90.8006 - val_mae: 7.3875 - val_r2_score_metric: -1077383424.0000
# Epoch 246/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 83.9255 - mae: 1.5563 - r2_score_metric: -120485040.0000 - val_loss: 22.1107 - val_mae: 1.4951 - val_r2_score_metric: -44163452.0000
# Epoch 247/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 252.4787 - mae: 1.7385 - r2_score_metric: -209776672.0000 - val_loss: 22.2556 - val_mae: 0.9096 - val_r2_score_metric: -14279468.0000
# Epoch 248/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 232.7539 - mae: 1.6678 - r2_score_metric: -194367872.0000 - val_loss: 21.6295 - val_mae: 1.0078 - val_r2_score_metric: -16646688.0000
# Epoch 249/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 90.9076 - mae: 1.3078 - r2_score_metric: -96780032.0000 - val_loss: 20.1623 - val_mae: 0.8670 - val_r2_score_metric: -16066864.0000
# Epoch 250/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 406.8418 - mae: 2.1104 - r2_score_metric: -208567840.0000 - val_loss: 22.2015 - val_mae: 0.9786 - val_r2_score_metric: -27255330.0000
# Epoch 251/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 326.6887 - mae: 2.0587 - r2_score_metric: -266531584.0000 - val_loss: 20.1429 - val_mae: 0.8484 - val_r2_score_metric: -12080230.0000
# Epoch 252/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 367.1014 - mae: 1.9664 - r2_score_metric: -298991968.0000 - val_loss: 22.2694 - val_mae: 1.0244 - val_r2_score_metric: -14509158.0000
# Epoch 253/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 131.0337 - mae: 1.3182 - r2_score_metric: -123908352.0000 - val_loss: 20.6869 - val_mae: 0.7649 - val_r2_score_metric: -9021486.0000
# Epoch 254/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 150.6626 - mae: 1.5142 - r2_score_metric: -155067632.0000 - val_loss: 21.4440 - val_mae: 0.7603 - val_r2_score_metric: -13071302.0000
# Epoch 255/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 54.4017 - mae: 1.1721 - r2_score_metric: -76025056.0000 - val_loss: 23.3956 - val_mae: 1.3493 - val_r2_score_metric: -41568188.0000
# Epoch 256/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 107.7567 - mae: 1.2458 - r2_score_metric: -126132040.0000 - val_loss: 23.5211 - val_mae: 1.7863 - val_r2_score_metric: -76282768.0000
# Epoch 257/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 210.1398 - mae: 1.7600 - r2_score_metric: -165032960.0000 - val_loss: 22.8125 - val_mae: 1.1511 - val_r2_score_metric: -21993198.0000
# Epoch 258/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 79.4311 - mae: 1.3297 - r2_score_metric: -101471432.0000 - val_loss: 23.1390 - val_mae: 0.8320 - val_r2_score_metric: -29534246.0000
# Epoch 259/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 245.9450 - mae: 1.6893 - r2_score_metric: -212219920.0000 - val_loss: 22.3811 - val_mae: 0.9553 - val_r2_score_metric: -23574428.0000
# Epoch 260/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 56.3674 - mae: 1.2679 - r2_score_metric: -78192888.0000 - val_loss: 20.1573 - val_mae: 0.9888 - val_r2_score_metric: -16790186.0000
# Epoch 261/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 304.6880 - mae: 2.1571 - r2_score_metric: -202421696.0000 - val_loss: 20.2349 - val_mae: 0.8610 - val_r2_score_metric: -13587023.0000
# Epoch 262/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 162.4732 - mae: 1.3154 - r2_score_metric: -153134864.0000 - val_loss: 20.6280 - val_mae: 0.8538 - val_r2_score_metric: -10196398.0000
# Epoch 263/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 277.6707 - mae: 1.6680 - r2_score_metric: -207688688.0000 - val_loss: 21.0194 - val_mae: 0.8635 - val_r2_score_metric: -13669866.0000
# Epoch 264/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 64.6814 - mae: 1.3012 - r2_score_metric: -104992656.0000 - val_loss: 26.4152 - val_mae: 1.6731 - val_r2_score_metric: -99552464.0000
# Epoch 265/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 28.5442 - mae: 1.1241 - r2_score_metric: -54814228.0000 - val_loss: 43.7437 - val_mae: 3.9165 - val_r2_score_metric: -307965984.0000
# Epoch 266/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 93.5077 - mae: 1.5958 - r2_score_metric: -111294712.0000 - val_loss: 20.8747 - val_mae: 1.1695 - val_r2_score_metric: -23769696.0000
# Epoch 267/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 458.6809 - mae: 2.3125 - r2_score_metric: -303780160.0000 - val_loss: 20.5246 - val_mae: 0.7575 - val_r2_score_metric: -8095250.0000
# Epoch 268/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 53.3335 - mae: 1.2886 - r2_score_metric: -70832080.0000 - val_loss: 22.3226 - val_mae: 1.3215 - val_r2_score_metric: -37324568.0000
# Epoch 269/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 268.3555 - mae: 1.6976 - r2_score_metric: -205113072.0000 - val_loss: 21.4383 - val_mae: 1.0379 - val_r2_score_metric: -13639950.0000
# Epoch 270/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 11.1386 - mae: 1.0058 - r2_score_metric: -34188908.0000 - val_loss: 86.8910 - val_mae: 6.7456 - val_r2_score_metric: -1032072000.0000
# Epoch 271/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 974.8848 - mae: 3.4269 - r2_score_metric: -341280064.0000 - val_loss: 19.6261 - val_mae: 0.9484 - val_r2_score_metric: -21048874.0000
# Epoch 272/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 224.1835 - mae: 1.6924 - r2_score_metric: -141291888.0000 - val_loss: 20.6783 - val_mae: 0.8073 - val_r2_score_metric: -14124125.0000
# Epoch 273/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 208.0663 - mae: 1.5533 - r2_score_metric: -140336896.0000 - val_loss: 21.4616 - val_mae: 1.7374 - val_r2_score_metric: -52565600.0000
# Epoch 274/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 110.6301 - mae: 1.3743 - r2_score_metric: -126577824.0000 - val_loss: 20.8275 - val_mae: 0.9225 - val_r2_score_metric: -14588474.0000
# Epoch 275/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 102.0526 - mae: 1.2366 - r2_score_metric: -99100200.0000 - val_loss: 21.9568 - val_mae: 1.4664 - val_r2_score_metric: -54358756.0000
# Epoch 276/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 141.5283 - mae: 1.3003 - r2_score_metric: -145200048.0000 - val_loss: 21.5958 - val_mae: 1.0925 - val_r2_score_metric: -47306716.0000
# Epoch 277/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 197.4530 - mae: 1.6371 - r2_score_metric: -189243264.0000 - val_loss: 19.4389 - val_mae: 0.7392 - val_r2_score_metric: -9790896.0000
# Epoch 278/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 474.2169 - mae: 2.0936 - r2_score_metric: -234717056.0000 - val_loss: 19.9174 - val_mae: 0.8676 - val_r2_score_metric: -17984772.0000
# Epoch 279/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 122.3714 - mae: 1.2665 - r2_score_metric: -89469352.0000 - val_loss: 22.0488 - val_mae: 1.0201 - val_r2_score_metric: -20688386.0000
# Epoch 280/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 195.5991 - mae: 1.7757 - r2_score_metric: -158907232.0000 - val_loss: 23.7227 - val_mae: 1.9451 - val_r2_score_metric: -75907248.0000
# Epoch 281/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 369.1229 - mae: 2.1652 - r2_score_metric: -315219648.0000 - val_loss: 20.7017 - val_mae: 1.3879 - val_r2_score_metric: -24144418.0000
# Epoch 282/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 341.3068 - mae: 2.0534 - r2_score_metric: -341562144.0000 - val_loss: 21.3997 - val_mae: 1.4587 - val_r2_score_metric: -47132996.0000
# Epoch 283/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 275.7960 - mae: 2.0807 - r2_score_metric: -309284736.0000 - val_loss: 19.7652 - val_mae: 0.8938 - val_r2_score_metric: -10318723.0000
# Epoch 284/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 268.8858 - mae: 1.5631 - r2_score_metric: -181292704.0000 - val_loss: 20.0474 - val_mae: 0.8640 - val_r2_score_metric: -22036016.0000
# Epoch 285/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 195.5969 - mae: 1.5260 - r2_score_metric: -144468048.0000 - val_loss: 20.1792 - val_mae: 0.9164 - val_r2_score_metric: -16638271.0000
# Epoch 286/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 52.0603 - mae: 1.0504 - r2_score_metric: -58769720.0000 - val_loss: 22.4879 - val_mae: 0.9441 - val_r2_score_metric: -23391194.0000
# Epoch 287/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 139.9663 - mae: 1.3082 - r2_score_metric: -123195056.0000 - val_loss: 21.8841 - val_mae: 0.7817 - val_r2_score_metric: -11861769.0000
# Epoch 288/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 239.4841 - mae: 1.5641 - r2_score_metric: -192228112.0000 - val_loss: 21.1402 - val_mae: 0.9971 - val_r2_score_metric: -20187448.0000
# Epoch 289/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 305.8466 - mae: 1.6288 - r2_score_metric: -216883392.0000 - val_loss: 24.5892 - val_mae: 2.0836 - val_r2_score_metric: -51690232.0000
# Epoch 290/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 166.2977 - mae: 1.3024 - r2_score_metric: -140695184.0000 - val_loss: 21.9502 - val_mae: 1.1007 - val_r2_score_metric: -18777990.0000
# Epoch 291/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 82.1155 - mae: 1.3539 - r2_score_metric: -79941496.0000 - val_loss: 21.2529 - val_mae: 1.2056 - val_r2_score_metric: -30357628.0000
# Epoch 292/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 95.4463 - mae: 1.2778 - r2_score_metric: -90117032.0000 - val_loss: 22.0214 - val_mae: 0.8306 - val_r2_score_metric: -13292023.0000
# Epoch 293/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 128.5071 - mae: 1.5499 - r2_score_metric: -122606616.0000 - val_loss: 21.2963 - val_mae: 1.2643 - val_r2_score_metric: -28962516.0000
# Epoch 294/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 40.0117 - mae: 1.1358 - r2_score_metric: -55078600.0000 - val_loss: 21.2968 - val_mae: 0.9421 - val_r2_score_metric: -24429280.0000
# Epoch 295/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 253.7401 - mae: 1.6060 - r2_score_metric: -168858080.0000 - val_loss: 20.9345 - val_mae: 0.8569 - val_r2_score_metric: -15661479.0000
# Epoch 296/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 231.3804 - mae: 1.5537 - r2_score_metric: -158793536.0000 - val_loss: 21.3111 - val_mae: 0.8092 - val_r2_score_metric: -14987747.0000
# Epoch 297/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 104.0168 - mae: 1.4410 - r2_score_metric: -106973968.0000 - val_loss: 20.4399 - val_mae: 0.7842 - val_r2_score_metric: -16251812.0000
# Epoch 298/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 78.2950 - mae: 1.1861 - r2_score_metric: -104141024.0000 - val_loss: 21.5590 - val_mae: 0.8529 - val_r2_score_metric: -20537374.0000
# Epoch 299/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 182.5528 - mae: 1.5698 - r2_score_metric: -177590176.0000 - val_loss: 26.0965 - val_mae: 1.3586 - val_r2_score_metric: -106953264.0000
# Epoch 300/300
# 3989/3989 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 127.4877 - mae: 1.3717 - r2_score_metric: -90937184.0000 - val_loss: 21.4129 - val_mae: 1.0311 - val_r2_score_metric: -22518758.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
#
# Target Variable: co2 in
# MAE: 0.74
# R²: -0.88

# %%
train_and_evaluate_model('temp in', flag_train = False)

# %% [markdown]
# # Test with test datasets with trained model

# %%
# Load the datasets from separate files
file_path_test = r"test-iot-datasets.xlsx"

# Load and clean the test dataset
mgh_data_test = pd.read_excel(file_path_test)

# Display the first few rows of the cleaned training and test dataframes
print("\nTest Data Sample:")
print(mgh_data_test.head())

num_rows_test = len(mgh_data_test)
print(f'Number of rows test: {num_rows_test}')
# Out:
# Test Data Sample:
#    time  global out  global in  temp in  temp out  rh in  rh out  co2 in  \
# 0  1200    0.000000   0.000000    21.80      22.8  51.65    49.5     400
# 1  1500    0.029625   1.354850    22.15      22.7  51.05    49.7     400
# 2  1800    0.032943   1.331150    23.35      22.8  48.05    49.2     400
# 3  2100    0.032943   1.323250    24.15      23.0  46.05    48.6     400
# 4  2400    0.010981   0.439635    24.60      23.0  44.55    48.2     400
#
#    co2 out  ventilation  toplights  heater
# 0      613            0          1       1
# 1      619            0          1       1
# 2      623            0          1       1
# 3      618            0          0       1
# 4      602            0          0       1
# Number of rows test: 60

# %%
def r2_score_metric(y_true, y_pred):
    """Custom R2 score metric"""
    SS_res =  tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return (1 - SS_res/(SS_tot + tf.keras.backend.epsilon()))

def test_model(target_variable):
    features = ['time', 'global out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    X_test = mgh_data_test[features]
    y_test = mgh_data_test[target_variable]

    # Load the model using the native Keras format
    loaded_model = load_model(f'trained-nn-models/{target_variable}_model.keras', custom_objects={'r2_score_metric': r2_score_metric})
    
    # Load the scaler
    scaler = joblib.load(f'trained-nn-models/{target_variable}_scaler.pkl')
    
    # Scale the test data
    X_test_scaled = scaler.transform(X_test)
    
    y_hat_test = loaded_model.predict(X_test_scaled)
    
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")
    
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

test_model(target_variable = target_variables[1])

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

test_model(target_variable = target_variables[2])

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

# Iterate through each target variable and call the function
for target in target_variables:
    test_model(target)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E419411510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E419411510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Target Variable: global in
# MAE: 0.60
# R²: 0.90
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Target Variable: temp in
# MAE: 0.91
# R²: 0.79
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Target Variable: rh in
# MAE: 3.49
# R²: -0.44
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Target Variable: co2 in
# MAE: 9.20
# R²: 0.00

# %% [markdown]
# # AUTOMATE THE PROCESS

# %% [markdown]
# Separate between the training and test datasets

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

import seaborn as sns

# %%
import pandas as pd

# Load the datasets from separate files
file_path_training = r"train-iot-datasets.xlsx"
file_path_test = r"test-iot-datasets-compiled-2-converted.xlsx"

# Load and clean the training dataset
mgh_data_training = pd.read_excel(file_path_training)
#mgh_data_training = mgh_data_training.dropna()  # Drop rows with missing values

# Load and clean the test dataset
mgh_data_test = pd.read_excel(file_path_test)
#mgh_data_test = mgh_data_test.dropna()  # Drop rows with missing values

# Display the first few rows of the cleaned training and test dataframes
print("Training Data Sample:")
print(mgh_data_training.head())

print("\nTest Data Sample:")
print(mgh_data_test.head())

# Length of dataset
num_rows_training = len(mgh_data_training)
print(f'\nNumber of rows training: {num_rows_training}')

num_rows_test = len(mgh_data_test)
print(f'Number of rows test: {num_rows_test}')

# Show all rows and columns of the test dataframe
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns

# print("\nFull Test Data:")
# print(mgh_data_test)

# # Reset options to default
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
def train_and_evaluate_model(target_variable, _epochs=100, _batch_size=10):
    # Select features and target variable for training and test data
    features = ['time', 'global out', 'temp out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    # Training data
    X_train = mgh_data_training[features]
    y_train = mgh_data_training[target_variable]
    
    # Test data
    X_test = mgh_data_test[features]
    y_test = mgh_data_test[target_variable]

    # Normalize the features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Build the ANN model
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))  # Output layer for regression

    # Compile the model
    # model.compile(optimizer='adam', loss='mean_squared_error')
    model.compile(loss='mse', metrics=['mae', 'R2Score'], optimizer='rmsprop')

    # Train the model
    history = model.fit(X_train_scaled, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)

    # Make predictions on the test set
    y_hat_test = model.predict(X_test_scaled)

    # Calculate MAE and R² score
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    # Plot loss (MSE) for both training and validation split
    plt.figure(figsize=(6, 4))
    sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
    sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
    plt.title('Model loss during training')
    plt.ylabel('loss')
    plt.xlabel('training epoch')
    plt.legend(loc='upper right')
    
    # Plot R2 for both training and validation split
    plt.figure(figsize=(6, 4))
    sns.lineplot(x=history.epoch, y=history.history['R2Score'], color='g', label='training')
    sns.lineplot(x=history.epoch, y=history.history['val_R2Score'], color='b', label='validation')

    plt.title('R2 during training')
    plt.ylabel('R2')
    plt.xlabel('epoch')
    plt.legend(loc='lower right')

    # Print MAE and R²
    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    # Plotting the test vs predicted values
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    # Plot the test vs predicted values in order
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

# Iterate through each target variable and call the function
for target in target_variables:
    train_and_evaluate_model(target, 200, 4)
