# %% [markdown]
# # COMPLETED AUTOMATE THE PROCESS

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
import joblib

import seaborn as sns

# %%
import pandas as pd

# Load the datasets from separate files
file_path = r"completed-iot-datasets.xlsx"

# Load and clean the training dataset
mgh_data = pd.read_excel(file_path)

# Display the first few rows of the dataframe
mgh_data.head()
# Out:
#    time  global out  global in    temp in   temp out      rh in     rh out  \
# 0     0    0.032943        0.0  19.806459  22.685000  62.243682  52.775000
# 1   300    0.032943        0.0  19.806459  22.685000  62.243682  52.775000
# 2   600    0.032943        0.0  19.889053  22.745000  62.040377  52.510000
# 3   900    0.032943        0.0  20.017409  22.823333  61.694059  52.213333
# 4  1200    0.032943        0.0  20.145762  22.865000  61.322003  52.015000
#
#        co2 in  co2 out  toplights  ventilation  heater Unnamed: 12 Unnamed: 13
# 0  409.000000   1530.5          1          0.0       0    dataset3         May
# 1  409.000000   1530.5          1          0.0       0         NaN         NaN
# 2  409.000000   1506.5          1          0.0       0         NaN         NaN
# 3  408.333333   1455.0          1          0.0       0         NaN         NaN
# 4  408.000000   1413.0          1          0.0       0         NaN         NaN

# %%
def r2_score_metric(y_true, y_pred):
    """Custom R2 score metric"""
    SS_res =  tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return (1 - SS_res/(SS_tot + tf.keras.backend.epsilon()))

def train_and_evaluate_model(target_variable, flag_train, _epochs=100, _batch_size=10):
    features = ['time', 'global out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    X = mgh_data[features]
    y = mgh_data[target_variable]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.001, random_state=42)

    # Initialize and fit the scaler on the training data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    if flag_train:
        # model = Sequential()
        # model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
        # model.add(Dense(32, activation='relu'))
        # model.add(Dense(1))
        
        # model = Sequential()
        # model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))  # More neurons
        # model.add(Dense(64, activation='relu'))  # Additional hidden layer
        # model.add(Dense(32, activation='relu'))  # Additional hidden layer
        # model.add(Dense(1))
        
        model = Sequential()
        model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
        model.add(Dropout(0.2))  # Dropout after input layer
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.2))  # Dropout after first hidden layer
        model.add(Dense(32, activation='relu'))
        model.add(Dropout(0.2))  # Dropout after second hidden layer
        model.add(Dense(1))
        
        # Adam optimizer
        # https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam
        '''
        Args
        learning_rate	A float, a keras.optimizers.schedules.LearningRateSchedule instance, 
                        or a callable that takes no arguments and returns the actual value to use. 
                        The learning rate. Defaults to 0.001.
        
        use_ema	Boolean, defaults to False. If True, exponential moving average (EMA) is applied. 
                        EMA consists of computing an exponential moving average of the weights of the model 
                        (as the weight values change after each training batch), and periodically overwriting 
                        the weights with their moving average.
                        
        ema_momentum	Float, defaults to 0.99. Only used if use_ema=True. 
                        This is the momentum to use when computing the EMA of the model's weights: new_average = ema_momentum * old_average + (1 - ema_momentum) * current_variable_value.
        
        The learning rate was lifted by one order of magnitude, and the momentum was increased to 0.9. 
        These increases in the learning rate were also recommended in the original Dropout paper (https://jmlr.org/papers/v15/srivastava14a.html)
        
        '''
        adam = Adam(learning_rate=0.001, use_ema=True, ema_momentum=0.9)
        
        # changed adam compare to rmsprop
        model.compile(optimizer=adam, 
                      loss='mean_squared_error', 
                      metrics=['mae', r2_score_metric])

        history = model.fit(X_train_scaled, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)
        
        # Save the model in the recommended Keras format
        model.save(f'trained-nn-dropout-models/{target_variable}_model.keras')

        # Save the scaler
        joblib.dump(scaler, f'trained-nn-dropout-models/{target_variable}_scaler.pkl')

        y_hat_test = model.predict(X_test_scaled)
    else:
        # Load the model using the native Keras format
        loaded_model = load_model(f'trained-nn-dropout-models/{target_variable}_model.keras', custom_objects={'r2_score_metric': r2_score_metric})
        
        # Print model summary
        print("\nModel Summary:")
        loaded_model.summary()

        # Count total parameters
        total_params = loaded_model.count_params()
        print(f"Total number of parameters: {total_params}")
        
        # Load the scaler
        scaler = joblib.load(f'trained-nn-dropout-models/{target_variable}_scaler.pkl')
        
        # Scale the test data
        X_test_scaled = scaler.transform(X_test)
        
        y_hat_test = loaded_model.predict(X_test_scaled)

    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    if flag_train:
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')

        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

# Iterate through each target variable and call the function
for target in target_variables:
    train_and_evaluate_model(target, flag_train = True, _epochs = 100, _batch_size= 5)
# Out:
# Epoch 1/100
# c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 1.5701 - mae: 0.6749 - r2_score_metric: -5.7752 - val_loss: 0.5828 - val_mae: 0.3577 - val_r2_score_metric: 0.6957
# Epoch 2/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.7636 - mae: 0.4361 - r2_score_metric: 0.6196 - val_loss: 0.5155 - val_mae: 0.3104 - val_r2_score_metric: 0.7644
# Epoch 3/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.6631 - mae: 0.3925 - r2_score_metric: 0.6713 - val_loss: 0.5086 - val_mae: 0.2997 - val_r2_score_metric: 0.7636
# Epoch 4/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.6603 - mae: 0.3867 - r2_score_metric: 0.7096 - val_loss: 0.5075 - val_mae: 0.3033 - val_r2_score_metric: 0.7637
# Epoch 5/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5926 - mae: 0.3694 - r2_score_metric: 0.7594 - val_loss: 0.4795 - val_mae: 0.2918 - val_r2_score_metric: 0.7883
# Epoch 6/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5292 - mae: 0.3580 - r2_score_metric: 0.7670 - val_loss: 0.4738 - val_mae: 0.2778 - val_r2_score_metric: 0.8044
# Epoch 7/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5446 - mae: 0.3564 - r2_score_metric: 0.6878 - val_loss: 0.4868 - val_mae: 0.3024 - val_r2_score_metric: 0.8083
# Epoch 8/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.5196 - mae: 0.3533 - r2_score_metric: 0.7780 - val_loss: 0.4699 - val_mae: 0.3082 - val_r2_score_metric: 0.7739
# Epoch 9/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5701 - mae: 0.3567 - r2_score_metric: 0.7617 - val_loss: 0.4818 - val_mae: 0.3172 - val_r2_score_metric: 0.7476
# Epoch 10/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5819 - mae: 0.3653 - r2_score_metric: 0.7845 - val_loss: 0.5004 - val_mae: 0.3352 - val_r2_score_metric: 0.7431
# Epoch 11/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5015 - mae: 0.3528 - r2_score_metric: 0.7189 - val_loss: 0.4396 - val_mae: 0.2777 - val_r2_score_metric: 0.7894
# Epoch 12/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4581 - mae: 0.3445 - r2_score_metric: 0.6641 - val_loss: 0.4706 - val_mae: 0.3301 - val_r2_score_metric: 0.7269
# Epoch 13/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.5374 - mae: 0.3515 - r2_score_metric: 0.7499 - val_loss: 0.5032 - val_mae: 0.3221 - val_r2_score_metric: 0.6982
# Epoch 14/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4381 - mae: 0.3401 - r2_score_metric: 0.7257 - val_loss: 0.6831 - val_mae: 0.3949 - val_r2_score_metric: 0.6434
# Epoch 15/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5295 - mae: 0.3589 - r2_score_metric: 0.7790 - val_loss: 0.4659 - val_mae: 0.3178 - val_r2_score_metric: 0.7807
# Epoch 16/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5404 - mae: 0.3588 - r2_score_metric: 0.6860 - val_loss: 0.5205 - val_mae: 0.3357 - val_r2_score_metric: 0.7084
# Epoch 17/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5167 - mae: 0.3544 - r2_score_metric: 0.3303 - val_loss: 0.4821 - val_mae: 0.3342 - val_r2_score_metric: 0.6581
# Epoch 18/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4494 - mae: 0.3365 - r2_score_metric: 0.7647 - val_loss: 0.4743 - val_mae: 0.2666 - val_r2_score_metric: 0.7442
# Epoch 19/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4434 - mae: 0.3312 - r2_score_metric: 0.7536 - val_loss: 0.4646 - val_mae: 0.3153 - val_r2_score_metric: 0.6842
# Epoch 20/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4449 - mae: 0.3380 - r2_score_metric: 0.6195 - val_loss: 0.4902 - val_mae: 0.3402 - val_r2_score_metric: 0.6630
# Epoch 21/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4696 - mae: 0.3464 - r2_score_metric: 0.5837 - val_loss: 0.5591 - val_mae: 0.3565 - val_r2_score_metric: 0.6440
# Epoch 22/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4874 - mae: 0.3485 - r2_score_metric: 0.7514 - val_loss: 0.5431 - val_mae: 0.2997 - val_r2_score_metric: 0.7406
# Epoch 23/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4695 - mae: 0.3401 - r2_score_metric: 0.7381 - val_loss: 0.4243 - val_mae: 0.2903 - val_r2_score_metric: 0.7558
# Epoch 24/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4111 - mae: 0.3327 - r2_score_metric: 0.7668 - val_loss: 0.5250 - val_mae: 0.3641 - val_r2_score_metric: 0.6694
# Epoch 25/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4785 - mae: 0.3428 - r2_score_metric: 0.7724 - val_loss: 0.4588 - val_mae: 0.3237 - val_r2_score_metric: 0.7084
# Epoch 26/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4460 - mae: 0.3415 - r2_score_metric: 0.7531 - val_loss: 0.4445 - val_mae: 0.3031 - val_r2_score_metric: 0.7339
# Epoch 27/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4214 - mae: 0.3308 - r2_score_metric: 0.5533 - val_loss: 0.5160 - val_mae: 0.3481 - val_r2_score_metric: 0.7391
# Epoch 28/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5013 - mae: 0.3450 - r2_score_metric: 0.7966 - val_loss: 0.5194 - val_mae: 0.3265 - val_r2_score_metric: 0.7710
# Epoch 29/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5051 - mae: 0.3460 - r2_score_metric: -6168.2627 - val_loss: 0.4397 - val_mae: 0.2808 - val_r2_score_metric: 0.7080
# Epoch 30/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4431 - mae: 0.3329 - r2_score_metric: 0.7825 - val_loss: 0.4671 - val_mae: 0.3288 - val_r2_score_metric: 0.5859
# Epoch 31/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4443 - mae: 0.3326 - r2_score_metric: 0.7022 - val_loss: 0.4496 - val_mae: 0.2998 - val_r2_score_metric: 0.7091
# Epoch 32/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4609 - mae: 0.3320 - r2_score_metric: 0.7213 - val_loss: 0.5405 - val_mae: 0.3991 - val_r2_score_metric: 0.6274
# Epoch 33/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.4619 - mae: 0.3352 - r2_score_metric: 0.7552 - val_loss: 0.4413 - val_mae: 0.3066 - val_r2_score_metric: 0.6557
# Epoch 34/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4742 - mae: 0.3345 - r2_score_metric: 0.7699 - val_loss: 0.5757 - val_mae: 0.3032 - val_r2_score_metric: 0.7821
# Epoch 35/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4498 - mae: 0.3350 - r2_score_metric: 0.7415 - val_loss: 0.4452 - val_mae: 0.3121 - val_r2_score_metric: 0.7270
# Epoch 36/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.4336 - mae: 0.3319 - r2_score_metric: 0.7537 - val_loss: 0.4415 - val_mae: 0.2782 - val_r2_score_metric: 0.7865
# Epoch 37/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4763 - mae: 0.3400 - r2_score_metric: 0.7982 - val_loss: 0.4452 - val_mae: 0.3353 - val_r2_score_metric: 0.6660
# Epoch 38/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4323 - mae: 0.3349 - r2_score_metric: 0.5068 - val_loss: 0.4899 - val_mae: 0.3160 - val_r2_score_metric: 0.6230
# Epoch 39/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4427 - mae: 0.3328 - r2_score_metric: 0.6325 - val_loss: 0.4130 - val_mae: 0.2857 - val_r2_score_metric: 0.7978
# Epoch 40/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4256 - mae: 0.3323 - r2_score_metric: 0.7727 - val_loss: 0.4364 - val_mae: 0.3181 - val_r2_score_metric: 0.6330
# Epoch 41/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4209 - mae: 0.3314 - r2_score_metric: 0.7957 - val_loss: 0.4541 - val_mae: 0.3239 - val_r2_score_metric: 0.7198
# Epoch 42/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4372 - mae: 0.3313 - r2_score_metric: 0.7542 - val_loss: 0.4288 - val_mae: 0.2807 - val_r2_score_metric: 0.5699
# Epoch 43/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4684 - mae: 0.3331 - r2_score_metric: 0.7354 - val_loss: 0.4915 - val_mae: 0.2626 - val_r2_score_metric: 0.5827
# Epoch 44/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4733 - mae: 0.3368 - r2_score_metric: 0.7823 - val_loss: 0.4340 - val_mae: 0.3148 - val_r2_score_metric: 0.6814
# Epoch 45/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4655 - mae: 0.3396 - r2_score_metric: 0.7985 - val_loss: 0.4262 - val_mae: 0.3092 - val_r2_score_metric: 0.7415
# Epoch 46/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3967 - mae: 0.3214 - r2_score_metric: 0.7264 - val_loss: 0.4511 - val_mae: 0.3201 - val_r2_score_metric: 0.6389
# Epoch 47/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4197 - mae: 0.3258 - r2_score_metric: 0.7620 - val_loss: 0.4140 - val_mae: 0.2980 - val_r2_score_metric: 0.6952
# Epoch 48/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4238 - mae: 0.3320 - r2_score_metric: 0.6668 - val_loss: 0.4633 - val_mae: 0.3308 - val_r2_score_metric: 0.6606
# Epoch 49/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4562 - mae: 0.3315 - r2_score_metric: -0.5271 - val_loss: 0.5212 - val_mae: 0.3315 - val_r2_score_metric: 0.5818
# Epoch 50/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4672 - mae: 0.3315 - r2_score_metric: 0.6769 - val_loss: 0.4830 - val_mae: 0.3289 - val_r2_score_metric: 0.6430
# Epoch 51/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4295 - mae: 0.3315 - r2_score_metric: 0.7812 - val_loss: 0.4934 - val_mae: 0.3020 - val_r2_score_metric: 0.5419
# Epoch 52/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4580 - mae: 0.3358 - r2_score_metric: 0.7807 - val_loss: 0.4496 - val_mae: 0.3004 - val_r2_score_metric: 0.6964
# Epoch 53/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4046 - mae: 0.3224 - r2_score_metric: 0.6701 - val_loss: 0.4591 - val_mae: 0.3459 - val_r2_score_metric: 0.6215
# Epoch 54/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4191 - mae: 0.3259 - r2_score_metric: 0.6771 - val_loss: 0.4844 - val_mae: 0.3360 - val_r2_score_metric: 0.6938
# Epoch 55/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4343 - mae: 0.3313 - r2_score_metric: 0.6942 - val_loss: 0.4601 - val_mae: 0.3117 - val_r2_score_metric: 0.7127
# Epoch 56/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4084 - mae: 0.3251 - r2_score_metric: 0.7685 - val_loss: 0.5058 - val_mae: 0.3763 - val_r2_score_metric: 0.4516
# Epoch 57/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4072 - mae: 0.3251 - r2_score_metric: 0.8071 - val_loss: 0.4800 - val_mae: 0.3187 - val_r2_score_metric: 0.7451
# Epoch 58/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4302 - mae: 0.3233 - r2_score_metric: 0.7167 - val_loss: 0.4401 - val_mae: 0.3067 - val_r2_score_metric: 0.7444
# Epoch 59/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.3935 - mae: 0.3209 - r2_score_metric: 0.7535 - val_loss: 0.4316 - val_mae: 0.2759 - val_r2_score_metric: 0.7784
# Epoch 60/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4210 - mae: 0.3241 - r2_score_metric: 0.6985 - val_loss: 0.4476 - val_mae: 0.2858 - val_r2_score_metric: 0.6058
# Epoch 61/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4104 - mae: 0.3251 - r2_score_metric: 0.7363 - val_loss: 0.4502 - val_mae: 0.2743 - val_r2_score_metric: 0.7963
# Epoch 62/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4273 - mae: 0.3342 - r2_score_metric: 0.6728 - val_loss: 0.4974 - val_mae: 0.3193 - val_r2_score_metric: 0.6234
# Epoch 63/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.4794 - mae: 0.3349 - r2_score_metric: 0.7442 - val_loss: 0.4162 - val_mae: 0.2832 - val_r2_score_metric: 0.7443
# Epoch 64/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.4491 - mae: 0.3277 - r2_score_metric: 0.4613 - val_loss: 0.4299 - val_mae: 0.2797 - val_r2_score_metric: 0.7425
# Epoch 65/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4208 - mae: 0.3222 - r2_score_metric: 0.7405 - val_loss: 0.4587 - val_mae: 0.3166 - val_r2_score_metric: 0.7411
# Epoch 66/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.4750 - mae: 0.3286 - r2_score_metric: 0.7932 - val_loss: 0.4117 - val_mae: 0.3076 - val_r2_score_metric: 0.7218
# Epoch 67/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.3854 - mae: 0.3263 - r2_score_metric: 0.7623 - val_loss: 0.4606 - val_mae: 0.2983 - val_r2_score_metric: 0.7385
# Epoch 68/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4448 - mae: 0.3321 - r2_score_metric: 0.7370 - val_loss: 0.4674 - val_mae: 0.3096 - val_r2_score_metric: 0.7549
# Epoch 69/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4324 - mae: 0.3268 - r2_score_metric: 0.7674 - val_loss: 0.4027 - val_mae: 0.2886 - val_r2_score_metric: 0.7464
# Epoch 70/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3831 - mae: 0.3164 - r2_score_metric: 0.2978 - val_loss: 0.4541 - val_mae: 0.2986 - val_r2_score_metric: 0.6411
# Epoch 71/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4632 - mae: 0.3316 - r2_score_metric: 0.7323 - val_loss: 0.4883 - val_mae: 0.3004 - val_r2_score_metric: 0.7443
# Epoch 72/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4477 - mae: 0.3240 - r2_score_metric: 0.7480 - val_loss: 0.5316 - val_mae: 0.3269 - val_r2_score_metric: 0.7456
# Epoch 73/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4181 - mae: 0.3185 - r2_score_metric: 0.7944 - val_loss: 0.4935 - val_mae: 0.3235 - val_r2_score_metric: 0.7449
# Epoch 74/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4233 - mae: 0.3212 - r2_score_metric: -22.9096 - val_loss: 0.4202 - val_mae: 0.2907 - val_r2_score_metric: 0.7606
# Epoch 75/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3980 - mae: 0.3222 - r2_score_metric: 0.7835 - val_loss: 0.4398 - val_mae: 0.2714 - val_r2_score_metric: 0.7616
# Epoch 76/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4150 - mae: 0.3266 - r2_score_metric: 0.7992 - val_loss: 0.4516 - val_mae: 0.2967 - val_r2_score_metric: 0.7573
# Epoch 77/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4362 - mae: 0.3275 - r2_score_metric: 0.7586 - val_loss: 0.4200 - val_mae: 0.2868 - val_r2_score_metric: 0.7463
# Epoch 78/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4092 - mae: 0.3203 - r2_score_metric: 0.7803 - val_loss: 0.4208 - val_mae: 0.2897 - val_r2_score_metric: 0.5647
# Epoch 79/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3817 - mae: 0.3179 - r2_score_metric: 0.7628 - val_loss: 0.4373 - val_mae: 0.2436 - val_r2_score_metric: 0.8346
# Epoch 80/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4002 - mae: 0.3226 - r2_score_metric: 0.7465 - val_loss: 0.4091 - val_mae: 0.2978 - val_r2_score_metric: 0.7605
# Epoch 81/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4617 - mae: 0.3292 - r2_score_metric: -14.2448 - val_loss: 0.4904 - val_mae: 0.3545 - val_r2_score_metric: 0.6711
# Epoch 82/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3466 - mae: 0.3138 - r2_score_metric: 0.7596 - val_loss: 0.4720 - val_mae: 0.2905 - val_r2_score_metric: 0.7998
# Epoch 83/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4095 - mae: 0.3217 - r2_score_metric: 0.8076 - val_loss: 0.4820 - val_mae: 0.3112 - val_r2_score_metric: 0.6831
# Epoch 84/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3834 - mae: 0.3162 - r2_score_metric: -12.1127 - val_loss: 0.4301 - val_mae: 0.2627 - val_r2_score_metric: 0.8348
# Epoch 85/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4304 - mae: 0.3264 - r2_score_metric: 0.7881 - val_loss: 0.4276 - val_mae: 0.3003 - val_r2_score_metric: 0.7643
# Epoch 86/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4117 - mae: 0.3157 - r2_score_metric: 0.7539 - val_loss: 0.4149 - val_mae: 0.2757 - val_r2_score_metric: 0.7678
# Epoch 87/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4297 - mae: 0.3228 - r2_score_metric: 0.7409 - val_loss: 0.4405 - val_mae: 0.2971 - val_r2_score_metric: 0.7348
# Epoch 88/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3800 - mae: 0.3241 - r2_score_metric: 0.7787 - val_loss: 0.4297 - val_mae: 0.2937 - val_r2_score_metric: 0.7193
# Epoch 89/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4575 - mae: 0.3291 - r2_score_metric: 0.6905 - val_loss: 0.4362 - val_mae: 0.2824 - val_r2_score_metric: 0.3584
# Epoch 90/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3921 - mae: 0.3145 - r2_score_metric: 0.6489 - val_loss: 0.4425 - val_mae: 0.2632 - val_r2_score_metric: 0.8098
# Epoch 91/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4320 - mae: 0.3265 - r2_score_metric: 0.7215 - val_loss: 0.4394 - val_mae: 0.2991 - val_r2_score_metric: 0.7257
# Epoch 92/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4403 - mae: 0.3248 - r2_score_metric: 0.7403 - val_loss: 0.4021 - val_mae: 0.2398 - val_r2_score_metric: 0.7818
# Epoch 93/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4446 - mae: 0.3211 - r2_score_metric: -846.3207 - val_loss: 0.4332 - val_mae: 0.2906 - val_r2_score_metric: 0.7501
# Epoch 94/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4236 - mae: 0.3198 - r2_score_metric: -1709.8761 - val_loss: 0.4800 - val_mae: 0.3166 - val_r2_score_metric: 0.7283
# Epoch 95/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4426 - mae: 0.3193 - r2_score_metric: 0.7354 - val_loss: 0.4348 - val_mae: 0.2515 - val_r2_score_metric: 0.7709
# Epoch 96/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4301 - mae: 0.3263 - r2_score_metric: 0.7727 - val_loss: 0.4152 - val_mae: 0.2738 - val_r2_score_metric: 0.8010
# Epoch 97/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4110 - mae: 0.3194 - r2_score_metric: 0.3103 - val_loss: 0.4437 - val_mae: 0.2728 - val_r2_score_metric: 0.4519
# Epoch 98/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.3660 - mae: 0.3114 - r2_score_metric: 0.7620 - val_loss: 0.4271 - val_mae: 0.3147 - val_r2_score_metric: 0.7253
# Epoch 99/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3908 - mae: 0.3188 - r2_score_metric: 0.7946 - val_loss: 0.4750 - val_mae: 0.3235 - val_r2_score_metric: 0.7340
# Epoch 100/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3848 - mae: 0.3155 - r2_score_metric: 0.7079 - val_loss: 0.4502 - val_mae: 0.3147 - val_r2_score_metric: 0.7455
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Target Variable: global in
# MAE: 0.30
# R²: 0.93
# Epoch 1/100
# c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 63.2308 - mae: 5.4768 - r2_score_metric: -73.8013 - val_loss: 0.6212 - val_mae: 0.6049 - val_r2_score_metric: 0.2388
# Epoch 2/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 13.5270 - mae: 2.9261 - r2_score_metric: -13.2189 - val_loss: 0.5068 - val_mae: 0.5837 - val_r2_score_metric: 0.4252
# Epoch 3/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 10.9935 - mae: 2.6380 - r2_score_metric: -12.6775 - val_loss: 0.8525 - val_mae: 0.7540 - val_r2_score_metric: 0.1216
# Epoch 4/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 10.0313 - mae: 2.5028 - r2_score_metric: -11.5184 - val_loss: 1.2476 - val_mae: 1.0044 - val_r2_score_metric: -0.5164
# Epoch 5/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 8.3195 - mae: 2.2798 - r2_score_metric: -9.1337 - val_loss: 0.3305 - val_mae: 0.4237 - val_r2_score_metric: 0.6978
# Epoch 6/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.1345 - mae: 2.1246 - r2_score_metric: -8.1079 - val_loss: 0.4286 - val_mae: 0.5369 - val_r2_score_metric: 0.5700
# Epoch 7/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.2165 - mae: 1.9866 - r2_score_metric: -5.9759 - val_loss: 0.1985 - val_mae: 0.3192 - val_r2_score_metric: 0.8267
# Epoch 8/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 5.5442 - mae: 1.8745 - r2_score_metric: -6.2410 - val_loss: 0.2507 - val_mae: 0.3623 - val_r2_score_metric: 0.7674
# Epoch 9/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 4.7509 - mae: 1.7291 - r2_score_metric: -4.8001 - val_loss: 0.2044 - val_mae: 0.3600 - val_r2_score_metric: 0.7868
# Epoch 10/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 4.2011 - mae: 1.6150 - r2_score_metric: -4.3597 - val_loss: 0.3237 - val_mae: 0.4532 - val_r2_score_metric: 0.6745
# Epoch 11/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.4220 - mae: 1.4596 - r2_score_metric: -3.0975 - val_loss: 0.1988 - val_mae: 0.2892 - val_r2_score_metric: 0.8456
# Epoch 12/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2.9725 - mae: 1.3609 - r2_score_metric: -2.7044 - val_loss: 0.3677 - val_mae: 0.4969 - val_r2_score_metric: 0.5899
# Epoch 13/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2.6730 - mae: 1.2920 - r2_score_metric: -2.0776 - val_loss: 0.1692 - val_mae: 0.2967 - val_r2_score_metric: 0.8361
# Epoch 14/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2.3619 - mae: 1.2116 - r2_score_metric: -2.0350 - val_loss: 0.2292 - val_mae: 0.3756 - val_r2_score_metric: 0.7769
# Epoch 15/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1.9964 - mae: 1.1152 - r2_score_metric: -1.1599 - val_loss: 0.1164 - val_mae: 0.2403 - val_r2_score_metric: 0.8926
# Epoch 16/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1.6939 - mae: 1.0253 - r2_score_metric: -0.9086 - val_loss: 0.1718 - val_mae: 0.2744 - val_r2_score_metric: 0.8743
# Epoch 17/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1.4113 - mae: 0.9349 - r2_score_metric: -0.6807 - val_loss: 0.1443 - val_mae: 0.2720 - val_r2_score_metric: 0.8691
# Epoch 18/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1.2051 - mae: 0.8590 - r2_score_metric: -0.3985 - val_loss: 0.1178 - val_mae: 0.2528 - val_r2_score_metric: 0.8885
# Epoch 19/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1.0185 - mae: 0.7833 - r2_score_metric: -0.2812 - val_loss: 0.1374 - val_mae: 0.2641 - val_r2_score_metric: 0.8704
# Epoch 20/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.8202 - mae: 0.7005 - r2_score_metric: 0.0724 - val_loss: 0.1228 - val_mae: 0.2285 - val_r2_score_metric: 0.8946
# Epoch 21/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.6946 - mae: 0.6304 - r2_score_metric: 0.3207 - val_loss: 0.2042 - val_mae: 0.3243 - val_r2_score_metric: 0.8469
# Epoch 22/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.5622 - mae: 0.5666 - r2_score_metric: 0.3720 - val_loss: 0.1197 - val_mae: 0.2538 - val_r2_score_metric: 0.8866
# Epoch 23/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.4465 - mae: 0.4993 - r2_score_metric: 0.5396 - val_loss: 0.1785 - val_mae: 0.2848 - val_r2_score_metric: 0.8764
# Epoch 24/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.3625 - mae: 0.4442 - r2_score_metric: 0.6539 - val_loss: 0.0916 - val_mae: 0.2077 - val_r2_score_metric: 0.9149
# Epoch 25/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2978 - mae: 0.3957 - r2_score_metric: 0.7066 - val_loss: 0.1253 - val_mae: 0.2457 - val_r2_score_metric: 0.8977
# Epoch 26/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.2388 - mae: 0.3552 - r2_score_metric: 0.7593 - val_loss: 0.1222 - val_mae: 0.2417 - val_r2_score_metric: 0.8970
# Epoch 27/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.2144 - mae: 0.3320 - r2_score_metric: 0.7910 - val_loss: 0.1185 - val_mae: 0.2249 - val_r2_score_metric: 0.9083
# Epoch 28/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.2027 - mae: 0.3222 - r2_score_metric: 0.8229 - val_loss: 0.1136 - val_mae: 0.2358 - val_r2_score_metric: 0.9067
# Epoch 29/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1819 - mae: 0.3050 - r2_score_metric: 0.8457 - val_loss: 0.1772 - val_mae: 0.2636 - val_r2_score_metric: 0.8888
# Epoch 30/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1935 - mae: 0.3032 - r2_score_metric: 0.8317 - val_loss: 0.1163 - val_mae: 0.2315 - val_r2_score_metric: 0.9073
# Epoch 31/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1800 - mae: 0.2993 - r2_score_metric: 0.8378 - val_loss: 0.2038 - val_mae: 0.3250 - val_r2_score_metric: 0.8602
# Epoch 32/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1701 - mae: 0.2935 - r2_score_metric: 0.8185 - val_loss: 0.1242 - val_mae: 0.2359 - val_r2_score_metric: 0.9020
# Epoch 33/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1713 - mae: 0.2909 - r2_score_metric: 0.8553 - val_loss: 0.1208 - val_mae: 0.2501 - val_r2_score_metric: 0.8955
# Epoch 34/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1601 - mae: 0.2862 - r2_score_metric: 0.8549 - val_loss: 0.0955 - val_mae: 0.2085 - val_r2_score_metric: 0.9176
# Epoch 35/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1611 - mae: 0.2839 - r2_score_metric: 0.8469 - val_loss: 0.1074 - val_mae: 0.2299 - val_r2_score_metric: 0.9066
# Epoch 36/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1573 - mae: 0.2797 - r2_score_metric: 0.8742 - val_loss: 0.1514 - val_mae: 0.2710 - val_r2_score_metric: 0.8868
# Epoch 37/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1647 - mae: 0.2816 - r2_score_metric: 0.8611 - val_loss: 0.1069 - val_mae: 0.2204 - val_r2_score_metric: 0.9160
# Epoch 38/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1495 - mae: 0.2725 - r2_score_metric: 0.8811 - val_loss: 0.0965 - val_mae: 0.2192 - val_r2_score_metric: 0.9134
# Epoch 39/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1524 - mae: 0.2763 - r2_score_metric: 0.8676 - val_loss: 0.1079 - val_mae: 0.2380 - val_r2_score_metric: 0.9021
# Epoch 40/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1539 - mae: 0.2757 - r2_score_metric: 0.8475 - val_loss: 0.1121 - val_mae: 0.2275 - val_r2_score_metric: 0.9113
# Epoch 41/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1507 - mae: 0.2763 - r2_score_metric: 0.8788 - val_loss: 0.1160 - val_mae: 0.2500 - val_r2_score_metric: 0.9002
# Epoch 42/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1500 - mae: 0.2731 - r2_score_metric: 0.8758 - val_loss: 0.1017 - val_mae: 0.2161 - val_r2_score_metric: 0.9148
# Epoch 43/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1526 - mae: 0.2748 - r2_score_metric: 0.8706 - val_loss: 0.1379 - val_mae: 0.2479 - val_r2_score_metric: 0.9042
# Epoch 44/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1525 - mae: 0.2771 - r2_score_metric: 0.8599 - val_loss: 0.1095 - val_mae: 0.2246 - val_r2_score_metric: 0.9100
# Epoch 45/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1516 - mae: 0.2747 - r2_score_metric: 0.8688 - val_loss: 0.1239 - val_mae: 0.2490 - val_r2_score_metric: 0.9056
# Epoch 46/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1548 - mae: 0.2746 - r2_score_metric: 0.8696 - val_loss: 0.0900 - val_mae: 0.2080 - val_r2_score_metric: 0.9212
# Epoch 47/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1543 - mae: 0.2740 - r2_score_metric: 0.8668 - val_loss: 0.1058 - val_mae: 0.2262 - val_r2_score_metric: 0.9123
# Epoch 48/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1516 - mae: 0.2714 - r2_score_metric: 0.8549 - val_loss: 0.1364 - val_mae: 0.2674 - val_r2_score_metric: 0.8960
# Epoch 49/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1438 - mae: 0.2688 - r2_score_metric: 0.8772 - val_loss: 0.0861 - val_mae: 0.1967 - val_r2_score_metric: 0.9276
# Epoch 50/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1473 - mae: 0.2689 - r2_score_metric: 0.8745 - val_loss: 0.0997 - val_mae: 0.2226 - val_r2_score_metric: 0.9131
# Epoch 51/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1485 - mae: 0.2720 - r2_score_metric: 0.8770 - val_loss: 0.0842 - val_mae: 0.1885 - val_r2_score_metric: 0.9292
# Epoch 52/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1476 - mae: 0.2717 - r2_score_metric: 0.8720 - val_loss: 0.1080 - val_mae: 0.2099 - val_r2_score_metric: 0.9182
# Epoch 53/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1451 - mae: 0.2721 - r2_score_metric: 0.8787 - val_loss: 0.1136 - val_mae: 0.2409 - val_r2_score_metric: 0.9085
# Epoch 54/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1624 - mae: 0.2724 - r2_score_metric: 0.8602 - val_loss: 0.1182 - val_mae: 0.2446 - val_r2_score_metric: 0.9002
# Epoch 55/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1522 - mae: 0.2752 - r2_score_metric: 0.8694 - val_loss: 0.0767 - val_mae: 0.1907 - val_r2_score_metric: 0.9308
# Epoch 56/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1497 - mae: 0.2713 - r2_score_metric: 0.8594 - val_loss: 0.0972 - val_mae: 0.2078 - val_r2_score_metric: 0.9206
# Epoch 57/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1473 - mae: 0.2714 - r2_score_metric: 0.8661 - val_loss: 0.1092 - val_mae: 0.2178 - val_r2_score_metric: 0.9159
# Epoch 58/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1619 - mae: 0.2749 - r2_score_metric: 0.8695 - val_loss: 0.0980 - val_mae: 0.2195 - val_r2_score_metric: 0.9167
# Epoch 59/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1462 - mae: 0.2717 - r2_score_metric: 0.8765 - val_loss: 0.1097 - val_mae: 0.2306 - val_r2_score_metric: 0.9138
# Epoch 60/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1470 - mae: 0.2676 - r2_score_metric: 0.8731 - val_loss: 0.0889 - val_mae: 0.1897 - val_r2_score_metric: 0.9262
# Epoch 61/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1492 - mae: 0.2679 - r2_score_metric: 0.8781 - val_loss: 0.0960 - val_mae: 0.2097 - val_r2_score_metric: 0.9193
# Epoch 62/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1485 - mae: 0.2689 - r2_score_metric: 0.8770 - val_loss: 0.1178 - val_mae: 0.2447 - val_r2_score_metric: 0.9057
# Epoch 63/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1477 - mae: 0.2682 - r2_score_metric: 0.8730 - val_loss: 0.1159 - val_mae: 0.2513 - val_r2_score_metric: 0.9035
# Epoch 64/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1477 - mae: 0.2691 - r2_score_metric: 0.8766 - val_loss: 0.1029 - val_mae: 0.2293 - val_r2_score_metric: 0.9106
# Epoch 65/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1437 - mae: 0.2676 - r2_score_metric: 0.8797 - val_loss: 0.1051 - val_mae: 0.2164 - val_r2_score_metric: 0.9184
# Epoch 66/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1416 - mae: 0.2671 - r2_score_metric: 0.8739 - val_loss: 0.1007 - val_mae: 0.2163 - val_r2_score_metric: 0.9207
# Epoch 67/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1397 - mae: 0.2672 - r2_score_metric: 0.8776 - val_loss: 0.0988 - val_mae: 0.2143 - val_r2_score_metric: 0.9160
# Epoch 68/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1483 - mae: 0.2706 - r2_score_metric: 0.8727 - val_loss: 0.0891 - val_mae: 0.2025 - val_r2_score_metric: 0.9239
# Epoch 69/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1387 - mae: 0.2647 - r2_score_metric: 0.8717 - val_loss: 0.0971 - val_mae: 0.2170 - val_r2_score_metric: 0.9181
# Epoch 70/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1385 - mae: 0.2632 - r2_score_metric: 0.8784 - val_loss: 0.1138 - val_mae: 0.2263 - val_r2_score_metric: 0.9198
# Epoch 71/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1374 - mae: 0.2666 - r2_score_metric: 0.8753 - val_loss: 0.1158 - val_mae: 0.2218 - val_r2_score_metric: 0.9166
# Epoch 72/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1447 - mae: 0.2666 - r2_score_metric: 0.8695 - val_loss: 0.1068 - val_mae: 0.2263 - val_r2_score_metric: 0.9088
# Epoch 73/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1528 - mae: 0.2697 - r2_score_metric: 0.8721 - val_loss: 0.1050 - val_mae: 0.2257 - val_r2_score_metric: 0.9195
# Epoch 74/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1423 - mae: 0.2671 - r2_score_metric: 0.8842 - val_loss: 0.0969 - val_mae: 0.2133 - val_r2_score_metric: 0.9193
# Epoch 75/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1405 - mae: 0.2670 - r2_score_metric: 0.8756 - val_loss: 0.1040 - val_mae: 0.2127 - val_r2_score_metric: 0.9174
# Epoch 76/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1428 - mae: 0.2644 - r2_score_metric: 0.8824 - val_loss: 0.0959 - val_mae: 0.2089 - val_r2_score_metric: 0.9192
# Epoch 77/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1499 - mae: 0.2650 - r2_score_metric: 0.8756 - val_loss: 0.1056 - val_mae: 0.2234 - val_r2_score_metric: 0.9142
# Epoch 78/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1432 - mae: 0.2650 - r2_score_metric: 0.8772 - val_loss: 0.1349 - val_mae: 0.2658 - val_r2_score_metric: 0.8963
# Epoch 79/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1426 - mae: 0.2660 - r2_score_metric: 0.8895 - val_loss: 0.1000 - val_mae: 0.2216 - val_r2_score_metric: 0.9129
# Epoch 80/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1379 - mae: 0.2644 - r2_score_metric: 0.8452 - val_loss: 0.0992 - val_mae: 0.2153 - val_r2_score_metric: 0.9166
# Epoch 81/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1344 - mae: 0.2592 - r2_score_metric: 0.8777 - val_loss: 0.0915 - val_mae: 0.2020 - val_r2_score_metric: 0.9232
# Epoch 82/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1381 - mae: 0.2624 - r2_score_metric: 0.8793 - val_loss: 0.1049 - val_mae: 0.2268 - val_r2_score_metric: 0.9130
# Epoch 83/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1362 - mae: 0.2644 - r2_score_metric: 0.8794 - val_loss: 0.0948 - val_mae: 0.2051 - val_r2_score_metric: 0.9255
# Epoch 84/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1345 - mae: 0.2630 - r2_score_metric: 0.8755 - val_loss: 0.0937 - val_mae: 0.2103 - val_r2_score_metric: 0.9222
# Epoch 85/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1510 - mae: 0.2692 - r2_score_metric: 0.8786 - val_loss: 0.0820 - val_mae: 0.1846 - val_r2_score_metric: 0.9334
# Epoch 86/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1443 - mae: 0.2684 - r2_score_metric: 0.8628 - val_loss: 0.1074 - val_mae: 0.2350 - val_r2_score_metric: 0.9136
# Epoch 87/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1463 - mae: 0.2676 - r2_score_metric: 0.8772 - val_loss: 0.1006 - val_mae: 0.2219 - val_r2_score_metric: 0.9154
# Epoch 88/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1430 - mae: 0.2654 - r2_score_metric: 0.8753 - val_loss: 0.1025 - val_mae: 0.2199 - val_r2_score_metric: 0.9213
# Epoch 89/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1439 - mae: 0.2673 - r2_score_metric: 0.8693 - val_loss: 0.0960 - val_mae: 0.2059 - val_r2_score_metric: 0.9246
# Epoch 90/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1452 - mae: 0.2657 - r2_score_metric: 0.8730 - val_loss: 0.1928 - val_mae: 0.3112 - val_r2_score_metric: 0.8745
# Epoch 91/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1443 - mae: 0.2687 - r2_score_metric: 0.8807 - val_loss: 0.1092 - val_mae: 0.2172 - val_r2_score_metric: 0.9182
# Epoch 92/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1405 - mae: 0.2630 - r2_score_metric: 0.8713 - val_loss: 0.1043 - val_mae: 0.2240 - val_r2_score_metric: 0.9167
# Epoch 93/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1375 - mae: 0.2600 - r2_score_metric: 0.8747 - val_loss: 0.1005 - val_mae: 0.2130 - val_r2_score_metric: 0.9192
# Epoch 94/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1397 - mae: 0.2632 - r2_score_metric: 0.8761 - val_loss: 0.0852 - val_mae: 0.1790 - val_r2_score_metric: 0.9384
# Epoch 95/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1353 - mae: 0.2603 - r2_score_metric: 0.8724 - val_loss: 0.0846 - val_mae: 0.2044 - val_r2_score_metric: 0.9267
# Epoch 96/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1406 - mae: 0.2642 - r2_score_metric: 0.8795 - val_loss: 0.0806 - val_mae: 0.1957 - val_r2_score_metric: 0.9300
# Epoch 97/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1343 - mae: 0.2604 - r2_score_metric: 0.8744 - val_loss: 0.0940 - val_mae: 0.2041 - val_r2_score_metric: 0.9266
# Epoch 98/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1323 - mae: 0.2590 - r2_score_metric: 0.8776 - val_loss: 0.0990 - val_mae: 0.2165 - val_r2_score_metric: 0.9231
# Epoch 99/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1397 - mae: 0.2627 - r2_score_metric: 0.8749 - val_loss: 0.1053 - val_mae: 0.2300 - val_r2_score_metric: 0.9158
# Epoch 100/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1480 - mae: 0.2657 - r2_score_metric: 0.8781 - val_loss: 0.1080 - val_mae: 0.2343 - val_r2_score_metric: 0.9133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
#
# Target Variable: temp in
# MAE: 0.22
# R²: 0.96
# Epoch 1/100
# c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 421.8002 - mae: 13.7575 - r2_score_metric: -32.1335 - val_loss: 6.6204 - val_mae: 1.9011 - val_r2_score_metric: -0.0239
# Epoch 2/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 77.5291 - mae: 6.9938 - r2_score_metric: -5.2770 - val_loss: 10.7682 - val_mae: 2.6038 - val_r2_score_metric: -0.7992
# Epoch 3/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 70.0343 - mae: 6.6362 - r2_score_metric: -4.9693 - val_loss: 6.2269 - val_mae: 1.9764 - val_r2_score_metric: 0.3113
# Epoch 4/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 64.6662 - mae: 6.3394 - r2_score_metric: -4.6917 - val_loss: 6.4977 - val_mae: 2.2311 - val_r2_score_metric: -0.0357
# Epoch 5/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 60.6405 - mae: 6.1980 - r2_score_metric: -4.1548 - val_loss: 7.1614 - val_mae: 2.1950 - val_r2_score_metric: 0.1600
# Epoch 6/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 55.4053 - mae: 5.9053 - r2_score_metric: -3.9340 - val_loss: 2.8136 - val_mae: 1.3519 - val_r2_score_metric: 0.6003
# Epoch 7/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 52.0064 - mae: 5.7264 - r2_score_metric: -3.5413 - val_loss: 2.4460 - val_mae: 1.1864 - val_r2_score_metric: 0.4416
# Epoch 8/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 49.0424 - mae: 5.5315 - r2_score_metric: -3.1240 - val_loss: 3.8653 - val_mae: 1.6125 - val_r2_score_metric: 0.5000
# Epoch 9/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 43.0478 - mae: 5.1934 - r2_score_metric: -2.4457 - val_loss: 2.5736 - val_mae: 1.1244 - val_r2_score_metric: 0.6226
# Epoch 10/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 40.8271 - mae: 5.0619 - r2_score_metric: -2.1796 - val_loss: 2.5810 - val_mae: 1.2515 - val_r2_score_metric: 0.7107
# Epoch 11/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 38.8945 - mae: 4.9253 - r2_score_metric: -2.1851 - val_loss: 1.8154 - val_mae: 0.9877 - val_r2_score_metric: 0.6567
# Epoch 12/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 35.1904 - mae: 4.6942 - r2_score_metric: -1.8599 - val_loss: 2.7844 - val_mae: 1.2362 - val_r2_score_metric: 0.4169
# Epoch 13/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 33.4990 - mae: 4.5960 - r2_score_metric: -1.6777 - val_loss: 2.1339 - val_mae: 1.1006 - val_r2_score_metric: 0.6095
# Epoch 14/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 33.2989 - mae: 4.5458 - r2_score_metric: -1.6466 - val_loss: 2.1192 - val_mae: 1.0521 - val_r2_score_metric: 0.7603
# Epoch 15/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 30.4413 - mae: 4.3596 - r2_score_metric: -1.5017 - val_loss: 2.3067 - val_mae: 1.0890 - val_r2_score_metric: 0.6854
# Epoch 16/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 29.2531 - mae: 4.2542 - r2_score_metric: -1.3567 - val_loss: 2.1726 - val_mae: 1.1171 - val_r2_score_metric: 0.6535
# Epoch 17/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 28.2877 - mae: 4.2293 - r2_score_metric: -1.2797 - val_loss: 3.3363 - val_mae: 1.4834 - val_r2_score_metric: 0.6328
# Epoch 18/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 26.8401 - mae: 4.1074 - r2_score_metric: -1.2592 - val_loss: 1.9324 - val_mae: 1.0463 - val_r2_score_metric: 0.7449
# Epoch 19/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 25.9524 - mae: 4.0348 - r2_score_metric: -1.0456 - val_loss: 2.1799 - val_mae: 1.1654 - val_r2_score_metric: 0.6949
# Epoch 20/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 25.8736 - mae: 4.0271 - r2_score_metric: -1.1433 - val_loss: 1.8648 - val_mae: 1.0000 - val_r2_score_metric: 0.7885
# Epoch 21/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 24.0523 - mae: 3.8775 - r2_score_metric: -0.8929 - val_loss: 1.8083 - val_mae: 0.9426 - val_r2_score_metric: 0.7588
# Epoch 22/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 22.2700 - mae: 3.7203 - r2_score_metric: -0.9424 - val_loss: 1.7400 - val_mae: 0.9325 - val_r2_score_metric: 0.8320
# Epoch 23/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 21.8567 - mae: 3.6963 - r2_score_metric: -0.8369 - val_loss: 1.8475 - val_mae: 1.0031 - val_r2_score_metric: 0.6821
# Epoch 24/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 20.8681 - mae: 3.6227 - r2_score_metric: -0.6213 - val_loss: 2.4872 - val_mae: 1.2609 - val_r2_score_metric: 0.7011
# Epoch 25/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 20.3480 - mae: 3.5741 - r2_score_metric: -0.7998 - val_loss: 1.6222 - val_mae: 0.9547 - val_r2_score_metric: 0.6913
# Epoch 26/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 19.8653 - mae: 3.5066 - r2_score_metric: -0.6241 - val_loss: 2.0660 - val_mae: 1.0863 - val_r2_score_metric: 0.7678
# Epoch 27/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 18.4845 - mae: 3.3740 - r2_score_metric: -0.5991 - val_loss: 1.6566 - val_mae: 0.9728 - val_r2_score_metric: 0.7617
# Epoch 28/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 17.7643 - mae: 3.3154 - r2_score_metric: -0.4568 - val_loss: 1.8333 - val_mae: 1.0058 - val_r2_score_metric: 0.8017
# Epoch 29/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 16.9102 - mae: 3.2410 - r2_score_metric: -0.3963 - val_loss: 1.7319 - val_mae: 0.9743 - val_r2_score_metric: 0.7718
# Epoch 30/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 16.6436 - mae: 3.2105 - r2_score_metric: -0.6022 - val_loss: 3.0125 - val_mae: 1.3276 - val_r2_score_metric: 0.4531
# Epoch 31/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 15.1073 - mae: 3.0715 - r2_score_metric: -0.1797 - val_loss: 1.7838 - val_mae: 1.0307 - val_r2_score_metric: 0.8105
# Epoch 32/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 14.7050 - mae: 3.0236 - r2_score_metric: -0.2633 - val_loss: 2.2806 - val_mae: 1.1618 - val_r2_score_metric: 0.7745
# Epoch 33/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 14.3297 - mae: 2.9735 - r2_score_metric: -0.1793 - val_loss: 1.5929 - val_mae: 0.9552 - val_r2_score_metric: 0.7871
# Epoch 34/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 13.4656 - mae: 2.8833 - r2_score_metric: -0.1278 - val_loss: 1.6080 - val_mae: 0.9779 - val_r2_score_metric: 0.7100
# Epoch 35/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 12.3368 - mae: 2.7816 - r2_score_metric: -0.0133 - val_loss: 2.7642 - val_mae: 1.3211 - val_r2_score_metric: 0.6233
# Epoch 36/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 12.1236 - mae: 2.7565 - r2_score_metric: -0.0748 - val_loss: 2.1301 - val_mae: 1.1257 - val_r2_score_metric: 0.7329
# Epoch 37/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 11.6370 - mae: 2.6699 - r2_score_metric: 0.0722 - val_loss: 1.4376 - val_mae: 0.8678 - val_r2_score_metric: 0.7736
# Epoch 38/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 10.9203 - mae: 2.6036 - r2_score_metric: 0.0839 - val_loss: 1.9320 - val_mae: 1.0650 - val_r2_score_metric: 0.7976
# Epoch 39/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 10.5186 - mae: 2.5532 - r2_score_metric: 0.1168 - val_loss: 1.9558 - val_mae: 1.0107 - val_r2_score_metric: 0.8086
# Epoch 40/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 9.9982 - mae: 2.4685 - r2_score_metric: 0.2188 - val_loss: 1.8932 - val_mae: 0.9529 - val_r2_score_metric: 0.6945
# Epoch 41/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 9.5363 - mae: 2.4171 - r2_score_metric: 0.2249 - val_loss: 1.5271 - val_mae: 0.9076 - val_r2_score_metric: 0.7841
# Epoch 42/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 8.8747 - mae: 2.3262 - r2_score_metric: 0.1771 - val_loss: 1.8249 - val_mae: 1.0322 - val_r2_score_metric: 0.7846
# Epoch 43/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 8.1956 - mae: 2.2389 - r2_score_metric: 0.3328 - val_loss: 1.3435 - val_mae: 0.8579 - val_r2_score_metric: 0.8332
# Epoch 44/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 8.3288 - mae: 2.2476 - r2_score_metric: 0.2728 - val_loss: 1.6436 - val_mae: 0.9428 - val_r2_score_metric: 0.8337
# Epoch 45/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.4818 - mae: 2.1283 - r2_score_metric: 0.4092 - val_loss: 1.5657 - val_mae: 0.8754 - val_r2_score_metric: 0.8290
# Epoch 46/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.1350 - mae: 2.0673 - r2_score_metric: 0.4215 - val_loss: 1.4458 - val_mae: 0.8567 - val_r2_score_metric: 0.7637
# Epoch 47/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6451 - mae: 2.0017 - r2_score_metric: 0.3989 - val_loss: 1.7902 - val_mae: 1.0204 - val_r2_score_metric: 0.7497
# Epoch 48/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.2512 - mae: 1.9386 - r2_score_metric: 0.3629 - val_loss: 1.6448 - val_mae: 0.8997 - val_r2_score_metric: 0.8516
# Epoch 49/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 5.8021 - mae: 1.8787 - r2_score_metric: 0.4973 - val_loss: 1.5365 - val_mae: 0.9082 - val_r2_score_metric: 0.7883
# Epoch 50/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 5.7065 - mae: 1.8521 - r2_score_metric: 0.5180 - val_loss: 1.7902 - val_mae: 1.0046 - val_r2_score_metric: 0.8366
# Epoch 51/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 5.4029 - mae: 1.8010 - r2_score_metric: 0.5624 - val_loss: 1.6741 - val_mae: 0.9611 - val_r2_score_metric: 0.7959
# Epoch 52/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 5.0679 - mae: 1.7415 - r2_score_metric: 0.5913 - val_loss: 1.5547 - val_mae: 0.8734 - val_r2_score_metric: 0.8108
# Epoch 53/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 4.8197 - mae: 1.6896 - r2_score_metric: 0.5977 - val_loss: 1.5144 - val_mae: 0.8606 - val_r2_score_metric: 0.8284
# Epoch 54/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 4.4659 - mae: 1.6270 - r2_score_metric: 0.6237 - val_loss: 1.6196 - val_mae: 0.8948 - val_r2_score_metric: 0.8513
# Epoch 55/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 4.3216 - mae: 1.5884 - r2_score_metric: 0.6513 - val_loss: 1.4740 - val_mae: 0.8179 - val_r2_score_metric: 0.8275
# Epoch 56/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 4.0488 - mae: 1.5445 - r2_score_metric: 0.6785 - val_loss: 1.5501 - val_mae: 0.8868 - val_r2_score_metric: 0.8340
# Epoch 57/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.8780 - mae: 1.5100 - r2_score_metric: 0.6974 - val_loss: 1.5650 - val_mae: 0.8673 - val_r2_score_metric: 0.8230
# Epoch 58/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.6349 - mae: 1.4498 - r2_score_metric: 0.7331 - val_loss: 1.5554 - val_mae: 0.8927 - val_r2_score_metric: 0.8629
# Epoch 59/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.6048 - mae: 1.4336 - r2_score_metric: 0.7143 - val_loss: 1.4774 - val_mae: 0.8296 - val_r2_score_metric: 0.8582
# Epoch 60/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.3901 - mae: 1.4021 - r2_score_metric: 0.6631 - val_loss: 1.3353 - val_mae: 0.7917 - val_r2_score_metric: 0.8177
# Epoch 61/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.3911 - mae: 1.3910 - r2_score_metric: 0.7689 - val_loss: 1.5281 - val_mae: 0.8715 - val_r2_score_metric: 0.8299
# Epoch 62/100
# ...
# Epoch 23/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 3720.2031 - mae: 48.2912 - r2_score_metric: -55530659840.0000 - val_loss: 98.3025 - val_mae: 6.7294 - val_r2_score_metric: -1177926784.0000
# Epoch 24/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 3743.1543 - mae: 48.1451 - r2_score_metric: -53270429696.0000 - val_loss: 587.2625 - val_mae: 23.3782 - val_r2_score_metric: -7371495936.0000
# Epoch 25/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 3582.4270 - mae: 47.4168 - r2_score_metric: -56303648768.0000 - val_loss: 304.8820 - val_mae: 16.2769 - val_r2_score_metric: -3666510848.0000
# Epoch 26/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3705.6550 - mae: 47.7583 - r2_score_metric: -53804941312.0000 - val_loss: 312.6584 - val_mae: 16.3189 - val_r2_score_metric: -3568730624.0000
# Epoch 27/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3385.8135 - mae: 46.4938 - r2_score_metric: -50714783744.0000 - val_loss: 167.4032 - val_mae: 10.8612 - val_r2_score_metric: -2038631936.0000
# Epoch 28/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3444.8445 - mae: 46.2941 - r2_score_metric: -50311229440.0000 - val_loss: 76.8676 - val_mae: 6.0228 - val_r2_score_metric: -467159328.0000
# Epoch 29/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3385.7307 - mae: 46.0295 - r2_score_metric: -53429035008.0000 - val_loss: 191.2473 - val_mae: 12.5483 - val_r2_score_metric: -1996210432.0000
# Epoch 30/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3299.0498 - mae: 45.2323 - r2_score_metric: -52738519040.0000 - val_loss: 66.1543 - val_mae: 5.3761 - val_r2_score_metric: -405500768.0000
# Epoch 31/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3501.4534 - mae: 45.4407 - r2_score_metric: -48034877440.0000 - val_loss: 48.8288 - val_mae: 4.5513 - val_r2_score_metric: -324907296.0000
# Epoch 32/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 3292.7009 - mae: 45.1640 - r2_score_metric: -48682004480.0000 - val_loss: 208.2144 - val_mae: 13.2419 - val_r2_score_metric: -2512506112.0000
# Epoch 33/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 3186.6968 - mae: 45.0800 - r2_score_metric: -47740268544.0000 - val_loss: 59.3627 - val_mae: 5.6516 - val_r2_score_metric: -440425280.0000
# Epoch 34/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3686.5115 - mae: 45.8728 - r2_score_metric: -53392232448.0000 - val_loss: 292.9440 - val_mae: 16.0952 - val_r2_score_metric: -3682089728.0000
# Epoch 35/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 3423.1133 - mae: 45.5749 - r2_score_metric: -49749864448.0000 - val_loss: 72.2498 - val_mae: 6.5312 - val_r2_score_metric: -529137952.0000
# Epoch 36/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3201.6064 - mae: 44.2911 - r2_score_metric: -49265242112.0000 - val_loss: 150.2426 - val_mae: 10.7195 - val_r2_score_metric: -1825463936.0000
# Epoch 37/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3163.3672 - mae: 44.3469 - r2_score_metric: -48704126976.0000 - val_loss: 226.6945 - val_mae: 14.0270 - val_r2_score_metric: -2752159232.0000
# Epoch 38/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3175.9790 - mae: 44.0365 - r2_score_metric: -47110205440.0000 - val_loss: 111.2276 - val_mae: 9.2271 - val_r2_score_metric: -1101239936.0000
# Epoch 39/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3134.9622 - mae: 44.0088 - r2_score_metric: -44455235584.0000 - val_loss: 88.4527 - val_mae: 7.7422 - val_r2_score_metric: -753167168.0000
# Epoch 40/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2998.4604 - mae: 42.8850 - r2_score_metric: -45209055232.0000 - val_loss: 57.7851 - val_mae: 5.5281 - val_r2_score_metric: -416350336.0000
# Epoch 41/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3412.1094 - mae: 43.2905 - r2_score_metric: -44605825024.0000 - val_loss: 143.2496 - val_mae: 11.0001 - val_r2_score_metric: -1622775552.0000
# Epoch 42/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3282.6133 - mae: 42.9189 - r2_score_metric: -42026819584.0000 - val_loss: 294.4320 - val_mae: 16.2785 - val_r2_score_metric: -3679988224.0000
# Epoch 43/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3172.4905 - mae: 42.7442 - r2_score_metric: -41866756096.0000 - val_loss: 359.5230 - val_mae: 18.3418 - val_r2_score_metric: -4440452096.0000
# Epoch 44/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2972.1292 - mae: 42.6406 - r2_score_metric: -43530108928.0000 - val_loss: 45.3561 - val_mae: 4.6353 - val_r2_score_metric: -225737728.0000
# Epoch 45/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3364.2087 - mae: 43.4914 - r2_score_metric: -45082755072.0000 - val_loss: 170.5197 - val_mae: 12.1211 - val_r2_score_metric: -1955104384.0000
# Epoch 46/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2996.9321 - mae: 42.4733 - r2_score_metric: -43688644608.0000 - val_loss: 207.9382 - val_mae: 13.6152 - val_r2_score_metric: -2382238208.0000
# Epoch 47/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3021.1736 - mae: 41.8112 - r2_score_metric: -44056129536.0000 - val_loss: 27.9096 - val_mae: 2.0886 - val_r2_score_metric: -33966248.0000
# Epoch 48/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3306.7212 - mae: 42.3921 - r2_score_metric: -40712011776.0000 - val_loss: 44.9494 - val_mae: 4.8638 - val_r2_score_metric: -268448320.0000
# Epoch 49/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2811.6492 - mae: 41.6521 - r2_score_metric: -40600043520.0000 - val_loss: 57.9970 - val_mae: 6.0002 - val_r2_score_metric: -393073600.0000
# Epoch 50/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2999.9700 - mae: 41.2689 - r2_score_metric: -37527625728.0000 - val_loss: 104.6682 - val_mae: 8.9351 - val_r2_score_metric: -1234018688.0000
# Epoch 51/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2748.1240 - mae: 40.6539 - r2_score_metric: -39318188032.0000 - val_loss: 24.6501 - val_mae: 1.3212 - val_r2_score_metric: -45466312.0000
# Epoch 52/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 3000.9187 - mae: 40.9174 - r2_score_metric: -40977154048.0000 - val_loss: 57.4015 - val_mae: 5.9401 - val_r2_score_metric: -392769696.0000
# Epoch 53/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2713.3252 - mae: 41.1086 - r2_score_metric: -44552593408.0000 - val_loss: 79.6589 - val_mae: 7.3538 - val_r2_score_metric: -695714560.0000
# Epoch 54/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2843.6301 - mae: 40.0217 - r2_score_metric: -37851095040.0000 - val_loss: 106.4153 - val_mae: 9.2094 - val_r2_score_metric: -1058677824.0000
# Epoch 55/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2603.1965 - mae: 40.4075 - r2_score_metric: -39385735168.0000 - val_loss: 27.5567 - val_mae: 1.9807 - val_r2_score_metric: -46450440.0000
# Epoch 56/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2691.0945 - mae: 40.1507 - r2_score_metric: -40366723072.0000 - val_loss: 243.8901 - val_mae: 14.9437 - val_r2_score_metric: -2965323776.0000
# Epoch 57/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 3038.8479 - mae: 40.2116 - r2_score_metric: -40398344192.0000 - val_loss: 36.3340 - val_mae: 3.5077 - val_r2_score_metric: -120448200.0000
# Epoch 58/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2656.3794 - mae: 39.8166 - r2_score_metric: -38210990080.0000 - val_loss: 108.3026 - val_mae: 9.2956 - val_r2_score_metric: -1035942912.0000
# Epoch 59/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2702.6411 - mae: 39.3761 - r2_score_metric: -36258426880.0000 - val_loss: 37.1987 - val_mae: 3.5689 - val_r2_score_metric: -110837264.0000
# Epoch 60/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2732.8047 - mae: 39.1555 - r2_score_metric: -35626926080.0000 - val_loss: 126.8315 - val_mae: 10.2792 - val_r2_score_metric: -1297089920.0000
# Epoch 61/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2554.5198 - mae: 38.2049 - r2_score_metric: -32043104256.0000 - val_loss: 27.3318 - val_mae: 2.5125 - val_r2_score_metric: -55363316.0000
# Epoch 62/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2504.1497 - mae: 39.5133 - r2_score_metric: -35849109504.0000 - val_loss: 87.7509 - val_mae: 8.0268 - val_r2_score_metric: -838856256.0000
# Epoch 63/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2561.9893 - mae: 39.0623 - r2_score_metric: -38127251456.0000 - val_loss: 55.0476 - val_mae: 5.8278 - val_r2_score_metric: -381803328.0000
# Epoch 64/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2392.0801 - mae: 38.3158 - r2_score_metric: -33272883200.0000 - val_loss: 34.3511 - val_mae: 3.5485 - val_r2_score_metric: -114483768.0000
# Epoch 65/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - loss: 2454.0776 - mae: 38.2300 - r2_score_metric: -36710174720.0000 - val_loss: 33.2754 - val_mae: 2.3847 - val_r2_score_metric: -95991248.0000
# Epoch 66/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 2503.2166 - mae: 38.0741 - r2_score_metric: -35341668352.0000 - val_loss: 91.3390 - val_mae: 8.1644 - val_r2_score_metric: -791838400.0000
# Epoch 67/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 2382.5046 - mae: 37.6872 - r2_score_metric: -33338888192.0000 - val_loss: 51.5620 - val_mae: 5.5773 - val_r2_score_metric: -378982464.0000
# Epoch 68/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2324.7788 - mae: 38.1139 - r2_score_metric: -36513619968.0000 - val_loss: 189.6391 - val_mae: 12.9876 - val_r2_score_metric: -2170112512.0000
# Epoch 69/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2611.8503 - mae: 37.7911 - r2_score_metric: -34655649792.0000 - val_loss: 30.0304 - val_mae: 1.5916 - val_r2_score_metric: -44258028.0000
# Epoch 70/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2303.2585 - mae: 37.5409 - r2_score_metric: -33914396672.0000 - val_loss: 90.7336 - val_mae: 8.3345 - val_r2_score_metric: -842387648.0000
# Epoch 71/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2358.1462 - mae: 37.8718 - r2_score_metric: -33945034752.0000 - val_loss: 85.9749 - val_mae: 7.8054 - val_r2_score_metric: -894545792.0000
# Epoch 72/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2368.2942 - mae: 37.6659 - r2_score_metric: -32971311104.0000 - val_loss: 60.1203 - val_mae: 6.2292 - val_r2_score_metric: -416200832.0000
# Epoch 73/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2354.6250 - mae: 37.5191 - r2_score_metric: -34686521344.0000 - val_loss: 102.8784 - val_mae: 8.9336 - val_r2_score_metric: -958593152.0000
# Epoch 74/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2395.2288 - mae: 37.0224 - r2_score_metric: -32504999936.0000 - val_loss: 164.9186 - val_mae: 11.9586 - val_r2_score_metric: -1772142080.0000
# Epoch 75/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2237.8672 - mae: 36.7799 - r2_score_metric: -34129854464.0000 - val_loss: 72.5444 - val_mae: 7.1251 - val_r2_score_metric: -584446976.0000
# Epoch 76/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2231.1982 - mae: 36.8945 - r2_score_metric: -30984966144.0000 - val_loss: 75.5031 - val_mae: 7.2888 - val_r2_score_metric: -602914752.0000
# Epoch 77/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2242.5149 - mae: 36.7685 - r2_score_metric: -32670273536.0000 - val_loss: 108.7237 - val_mae: 9.3397 - val_r2_score_metric: -1033869568.0000
# Epoch 78/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2224.6167 - mae: 36.6438 - r2_score_metric: -32239788032.0000 - val_loss: 88.4264 - val_mae: 8.1892 - val_r2_score_metric: -790923200.0000
# Epoch 79/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2714.4871 - mae: 36.6581 - r2_score_metric: -32272680960.0000 - val_loss: 67.8146 - val_mae: 6.8146 - val_r2_score_metric: -596753472.0000
# Epoch 80/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2198.9297 - mae: 36.9819 - r2_score_metric: -33048057856.0000 - val_loss: 24.7030 - val_mae: 1.6516 - val_r2_score_metric: -37034648.0000
# Epoch 81/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2165.5737 - mae: 36.6064 - r2_score_metric: -33529450496.0000 - val_loss: 51.4573 - val_mae: 5.5637 - val_r2_score_metric: -441975328.0000
# Epoch 82/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 2130.7810 - mae: 35.8337 - r2_score_metric: -32000589824.0000 - val_loss: 54.6886 - val_mae: 5.6687 - val_r2_score_metric: -348877952.0000
# Epoch 83/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2181.0649 - mae: 35.6566 - r2_score_metric: -31682838528.0000 - val_loss: 94.4208 - val_mae: 8.5888 - val_r2_score_metric: -910604480.0000
# Epoch 84/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2341.7166 - mae: 36.1369 - r2_score_metric: -30035748864.0000 - val_loss: 86.6023 - val_mae: 8.1618 - val_r2_score_metric: -808789376.0000
# Epoch 85/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2596.6531 - mae: 35.9454 - r2_score_metric: -31162312704.0000 - val_loss: 73.5510 - val_mae: 7.1605 - val_r2_score_metric: -566383872.0000
# Epoch 86/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2089.2136 - mae: 35.7741 - r2_score_metric: -30432079872.0000 - val_loss: 50.6416 - val_mae: 5.4394 - val_r2_score_metric: -306966304.0000
# Epoch 87/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 2092.0417 - mae: 35.6438 - r2_score_metric: -29932122112.0000 - val_loss: 70.7887 - val_mae: 7.0741 - val_r2_score_metric: -625873536.0000
# Epoch 88/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2145.4392 - mae: 35.7340 - r2_score_metric: -30136182784.0000 - val_loss: 52.7993 - val_mae: 5.7344 - val_r2_score_metric: -374365824.0000
# Epoch 89/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2082.5920 - mae: 35.7801 - r2_score_metric: -31494021120.0000 - val_loss: 46.3043 - val_mae: 5.1454 - val_r2_score_metric: -287726272.0000
# Epoch 90/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2104.1304 - mae: 35.5172 - r2_score_metric: -30206605312.0000 - val_loss: 85.8770 - val_mae: 8.0095 - val_r2_score_metric: -767346752.0000
# Epoch 91/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2168.2446 - mae: 35.7357 - r2_score_metric: -31872299008.0000 - val_loss: 63.4160 - val_mae: 6.5247 - val_r2_score_metric: -503809888.0000
# Epoch 92/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1946.9058 - mae: 34.9280 - r2_score_metric: -29498886144.0000 - val_loss: 54.8607 - val_mae: 5.8845 - val_r2_score_metric: -387406336.0000
# Epoch 93/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2142.6917 - mae: 35.6320 - r2_score_metric: -30204016640.0000 - val_loss: 58.8813 - val_mae: 6.0941 - val_r2_score_metric: -414012096.0000
# Epoch 94/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2159.6267 - mae: 35.4146 - r2_score_metric: -28967370752.0000 - val_loss: 54.3606 - val_mae: 5.5168 - val_r2_score_metric: -323740608.0000
# Epoch 95/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 1983.1139 - mae: 35.2560 - r2_score_metric: -30368808960.0000 - val_loss: 34.4357 - val_mae: 3.4415 - val_r2_score_metric: -102302024.0000
# Epoch 96/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2142.3062 - mae: 34.9303 - r2_score_metric: -26810294272.0000 - val_loss: 65.8537 - val_mae: 6.7733 - val_r2_score_metric: -532299104.0000
# Epoch 97/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2056.3701 - mae: 34.2999 - r2_score_metric: -27993151488.0000 - val_loss: 48.9964 - val_mae: 5.3467 - val_r2_score_metric: -347365120.0000
# Epoch 98/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2144.8230 - mae: 34.9122 - r2_score_metric: -29271205888.0000 - val_loss: 71.7359 - val_mae: 7.1566 - val_r2_score_metric: -576224832.0000
# Epoch 99/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 2076.5032 - mae: 34.6193 - r2_score_metric: -30182744064.0000 - val_loss: 41.0155 - val_mae: 4.6030 - val_r2_score_metric: -227202864.0000
# Epoch 100/100
# 3191/3191 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 2260.9231 - mae: 34.5300 - r2_score_metric: -28642682880.0000 - val_loss: 67.6301 - val_mae: 6.8258 - val_r2_score_metric: -535670496.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# Target Variable: co2 in
# MAE: 6.47
# R²: -85.43

# %%
train_and_evaluate_model('temp in', flag_train = False)

# %% [markdown]
# # Test with test datasets with trained model

# %%
# Load the datasets from separate files
file_path_test = r"test-iot-datasets.xlsx"

# Load and clean the test dataset
mgh_data_test = pd.read_excel(file_path_test)

# Display the first few rows of the cleaned training and test dataframes
print("\nTest Data Sample:")
print(mgh_data_test.head())

num_rows_test = len(mgh_data_test)
print(f'Number of rows test: {num_rows_test}')
# Out:
# Test Data Sample:
#    time  global out  global in  temp in  temp out  rh in  rh out  co2 in  \
# 0  1200    0.000000   0.000000    21.80      22.8  51.65    49.5     400
# 1  1500    0.029625   1.354850    22.15      22.7  51.05    49.7     400
# 2  1800    0.032943   1.331150    23.35      22.8  48.05    49.2     400
# 3  2100    0.032943   1.323250    24.15      23.0  46.05    48.6     400
# 4  2400    0.010981   0.439635    24.60      23.0  44.55    48.2     400
#
#    co2 out  ventilation  toplights  heater
# 0      613            0          1       1
# 1      619            0          1       1
# 2      623            0          1       1
# 3      618            0          0       1
# 4      602            0          0       1
# Number of rows test: 60

# %%
def r2_score_metric(y_true, y_pred):
    """Custom R2 score metric"""
    SS_res =  tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return (1 - SS_res/(SS_tot + tf.keras.backend.epsilon()))

def test_model(target_variable):
    features = ['time', 'global out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    X_test = mgh_data_test[features]
    y_test = mgh_data_test[target_variable]

    # Load the model using the native Keras format
    loaded_model = load_model(f'trained-nn-dropout-models/{target_variable}_model.keras', custom_objects={'r2_score_metric': r2_score_metric})
    
    # Load the scaler
    scaler = joblib.load(f'trained-nn-dropout-models/{target_variable}_scaler.pkl')
    
    # Scale the test data
    X_test_scaled = scaler.transform(X_test)
    
    y_hat_test = loaded_model.predict(X_test_scaled)
    
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")
    
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

test_model(target_variable = target_variables[1])

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

test_model(target_variable = target_variables[2])

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

# Iterate through each target variable and call the function
for target in target_variables:
    test_model(target)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
#
# Target Variable: global in
# MAE: 1.00
# R²: 0.74
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Target Variable: temp in
# MAE: 0.94
# R²: 0.81
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Target Variable: rh in
# MAE: 2.68
# R²: 0.14
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Target Variable: co2 in
# MAE: 5.59
# R²: 0.00

# %% [markdown]
# # AUTOMATE THE PROCESS

# %% [markdown]
# Separate between the training and test datasets

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

import seaborn as sns

# %%
import pandas as pd

# Load the datasets from separate files
file_path_training = r"train-iot-datasets.xlsx"
file_path_test = r"test-iot-datasets-compiled-2-converted.xlsx"

# Load and clean the training dataset
mgh_data_training = pd.read_excel(file_path_training)
#mgh_data_training = mgh_data_training.dropna()  # Drop rows with missing values

# Load and clean the test dataset
mgh_data_test = pd.read_excel(file_path_test)
#mgh_data_test = mgh_data_test.dropna()  # Drop rows with missing values

# Display the first few rows of the cleaned training and test dataframes
print("Training Data Sample:")
print(mgh_data_training.head())

print("\nTest Data Sample:")
print(mgh_data_test.head())

# Length of dataset
num_rows_training = len(mgh_data_training)
print(f'\nNumber of rows training: {num_rows_training}')

num_rows_test = len(mgh_data_test)
print(f'Number of rows test: {num_rows_test}')

# Show all rows and columns of the test dataframe
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns

# print("\nFull Test Data:")
# print(mgh_data_test)

# # Reset options to default
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
def train_and_evaluate_model(target_variable, _epochs=100, _batch_size=10):
    # Select features and target variable for training and test data
    features = ['time', 'global out', 'temp out', 'temp out', 'rh out', 'co2 out', 'ventilation', 'toplights', 'heater']
    
    # Training data
    X_train = mgh_data_training[features]
    y_train = mgh_data_training[target_variable]
    
    # Test data
    X_test = mgh_data_test[features]
    y_test = mgh_data_test[target_variable]

    # Normalize the features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Build the ANN model
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))  # Output layer for regression

    # Compile the model
    # model.compile(optimizer='adam', loss='mean_squared_error')
    model.compile(loss='mse', metrics=['mae', 'R2Score'], optimizer='rmsprop')

    # Train the model
    history = model.fit(X_train_scaled, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)

    # Make predictions on the test set
    y_hat_test = model.predict(X_test_scaled)

    # Calculate MAE and R² score
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)
    
    # Plot loss (MSE) for both training and validation split
    plt.figure(figsize=(6, 4))
    sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
    sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
    plt.title('Model loss during training')
    plt.ylabel('loss')
    plt.xlabel('training epoch')
    plt.legend(loc='upper right')
    
    # Plot R2 for both training and validation split
    plt.figure(figsize=(6, 4))
    sns.lineplot(x=history.epoch, y=history.history['R2Score'], color='g', label='training')
    sns.lineplot(x=history.epoch, y=history.history['val_R2Score'], color='b', label='validation')

    plt.title('R2 during training')
    plt.ylabel('R2')
    plt.xlabel('epoch')
    plt.legend(loc='lower right')

    # Print MAE and R²
    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    # Plotting the test vs predicted values
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()
    
    # Plot the test vs predicted values in order
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
# List of target variables
target_variables = ['global in', 'temp in', 'rh in', 'co2 in']

# Iterate through each target variable and call the function
for target in target_variables:
    train_and_evaluate_model(target, 200, 4)
