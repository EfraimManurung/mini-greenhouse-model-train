# %%
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, GRU, Dense, Multiply, Add, Concatenate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tensorflow.keras.layers import Lambda

def r2_score_metric(y_true, y_pred):
    """Custom R2 score metric"""
    SS_res = tf.reduce_sum(tf.square(y_true - y_pred)) 
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true))) 
    return (1 - SS_res / (SS_tot + tf.keras.backend.epsilon()))

# %%
def train_and_evaluate_gru_model(target_variable, flag_train=True, _epochs=100, _batch_size=10):
    # Load your data from the Excel file
    mgh_data = pd.read_excel("gru-datasets.xlsx")

    # Select relevant features
    features = ['timesteps', f'{target_variable} (Predicted GL)', f'{target_variable} (Predicted NN)']
    
    X = mgh_data[features]
    y = mgh_data[f'{target_variable} (Actual)']
    
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01, random_state=42)

    # Reshape data for GRU input (samples, timesteps, features)
    X_train_reshaped = X_train.values.reshape((X_train.shape[0], -1, X_train.shape[1]))
    X_test_reshaped = X_test.values.reshape((X_test.shape[0], -1, X_test.shape[1]))

    if flag_train:
        # Define the input shapes
        time_steps = X_train_reshaped.shape[1]
        features_count = X_train_reshaped.shape[2]

        # Inputs
        input_layer = Input(shape=(time_steps, features_count), name='input_layer')

        # GRU Layer to process the time series data
        gru_output = GRU(units=64, return_sequences=False)(input_layer)

        # Dense layers to predict w_physics and w_nn
        w_physics = Dense(1, activation='sigmoid')(gru_output)
        w_nn = Lambda(lambda x: 1.0 - x)(w_physics)  # w_nn = 1 - w_physics

        # y_hat calculation based on the predicted weights
        # Extract the q_physics and q_nn inputs from the reshaped input
        q_physics_input = Lambda(lambda x: x[:, :, 1], name='q_physics_input')(input_layer)
        q_nn_input = Lambda(lambda x: x[:, :, 2], name='q_nn_input')(input_layer)

        q_physics_flatten = Lambda(lambda x: tf.squeeze(x, axis=-1))(q_physics_input)
        q_nn_flatten = Lambda(lambda x: tf.squeeze(x, axis=-1))(q_nn_input)

        # y_hat calculation
        y_hat_physics = Multiply()([q_physics_flatten, w_physics])
        y_hat_nn = Multiply()([q_nn_flatten, w_nn])
        y_hat = Add()([y_hat_physics, y_hat_nn])

        # Define the model
        model = Model(inputs=input_layer, outputs=y_hat)

        # Compile the model
        model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_metric])

        # Train the model
        history = model.fit(X_train_reshaped, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)

        # Save the model
        model.save(f'gru-models/{target_variable}_gru_model.keras')

        # Predict the test set
        y_hat_test = model.predict(X_test_reshaped)

    else:
        # Load the model
        loaded_model = load_model(f'gru-models/{target_variable}_gru_model.keras', custom_objects={'r2_score_metric': r2_score_metric})

        # Predict using the loaded model
        y_hat_test = loaded_model.predict(X_test_reshaped)

    # Evaluate the model
    mae = mean_absolute_error(y_test, y_hat_test)
    r2 = r2_score(y_test, y_hat_test)

    if flag_train:
        # Plot training history
        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['loss'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='b', label='validation')
        plt.title('Model loss during training')
        plt.ylabel('loss')
        plt.xlabel('training epoch')
        plt.legend(loc='upper right')

        plt.figure(figsize=(6, 4))
        sns.lineplot(x=history.epoch, y=history.history['r2_score_metric'], color='g', label='training')
        sns.lineplot(x=history.epoch, y=history.history['val_r2_score_metric'], color='b', label='validation')
        plt.title('R2 during training')
        plt.ylabel('R2')
        plt.xlabel('epoch')
        plt.legend(loc='lower right')

    print(f"\nTarget Variable: {target_variable}")
    print(f"MAE: {mae:.2f}")
    print(f"R²: {r2:.2f}")

    # Scatter plot of actual vs. predicted values
    plt.figure(figsize=(6, 4))
    plt.scatter(y_test, y_hat_test, label='Predicted vs Actual')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(f'Actual vs Predicted Values for {target_variable}\nMAE: {mae:.2f}, R²: {r2:.2f}')
    plt.legend()

    # Plot of actual vs. predicted over time
    plt.figure(figsize=(6, 4))
    plt.plot(range(len(y_test)), y_test, marker='o', linestyle='-', color='blue', label='Actual')
    plt.plot(range(len(y_hat_test)), y_hat_test, marker='x', linestyle='--', color='red', label='Predicted')
    plt.title(f'Actual vs Predicted Values for {target_variable}')
    plt.xlabel('Index')
    plt.ylabel(target_variable)
    plt.legend()
    plt.show()

# %%
train_and_evaluate_gru_model(target_variable='Temperature In', flag_train=True, _epochs=100, _batch_size=4)
# Out:
# Epoch 1/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1031 - mae: 0.2454 - r2_score_metric: -13.9265 - val_loss: 0.0878 - val_mae: 0.2263 - val_r2_score_metric: 0.4331
# Epoch 2/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0866 - mae: 0.2301 - r2_score_metric: 0.5289 - val_loss: 0.0868 - val_mae: 0.2236 - val_r2_score_metric: 0.4492
# Epoch 3/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0791 - mae: 0.2190 - r2_score_metric: 0.5338 - val_loss: 0.0857 - val_mae: 0.2244 - val_r2_score_metric: 0.4470
# Epoch 4/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0836 - mae: 0.2236 - r2_score_metric: 0.5231 - val_loss: 0.0855 - val_mae: 0.2227 - val_r2_score_metric: 0.4607
# Epoch 5/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0836 - mae: 0.2213 - r2_score_metric: 0.6037 - val_loss: 0.0861 - val_mae: 0.2238 - val_r2_score_metric: 0.4506
# Epoch 6/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0849 - mae: 0.2225 - r2_score_metric: 0.1193 - val_loss: 0.0846 - val_mae: 0.2229 - val_r2_score_metric: 0.4471
# Epoch 7/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0850 - mae: 0.2271 - r2_score_metric: 0.1580 - val_loss: 0.0850 - val_mae: 0.2217 - val_r2_score_metric: 0.4564
# Epoch 8/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0811 - mae: 0.2230 - r2_score_metric: 0.4901 - val_loss: 0.0856 - val_mae: 0.2253 - val_r2_score_metric: 0.4425
# Epoch 9/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0757 - mae: 0.2090 - r2_score_metric: 0.1587 - val_loss: 0.0861 - val_mae: 0.2225 - val_r2_score_metric: 0.4682
# Epoch 10/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0830 - mae: 0.2207 - r2_score_metric: 0.4057 - val_loss: 0.0847 - val_mae: 0.2214 - val_r2_score_metric: 0.4660
# Epoch 11/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0810 - mae: 0.2152 - r2_score_metric: 0.5354 - val_loss: 0.0851 - val_mae: 0.2266 - val_r2_score_metric: 0.4256
# Epoch 12/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0813 - mae: 0.2222 - r2_score_metric: 0.2605 - val_loss: 0.0865 - val_mae: 0.2238 - val_r2_score_metric: 0.4527
# Epoch 13/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0853 - mae: 0.2292 - r2_score_metric: 0.4945 - val_loss: 0.0851 - val_mae: 0.2226 - val_r2_score_metric: 0.4543
# Epoch 14/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0843 - mae: 0.2247 - r2_score_metric: 0.3292 - val_loss: 0.0842 - val_mae: 0.2246 - val_r2_score_metric: 0.4340
# Epoch 15/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0814 - mae: 0.2181 - r2_score_metric: 0.5632 - val_loss: 0.0851 - val_mae: 0.2267 - val_r2_score_metric: 0.4165
# Epoch 16/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0817 - mae: 0.2232 - r2_score_metric: 0.1159 - val_loss: 0.0849 - val_mae: 0.2224 - val_r2_score_metric: 0.4539
# Epoch 17/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0797 - mae: 0.2167 - r2_score_metric: 0.5680 - val_loss: 0.0844 - val_mae: 0.2261 - val_r2_score_metric: 0.4165
# Epoch 18/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0921 - mae: 0.2331 - r2_score_metric: -0.1771 - val_loss: 0.0843 - val_mae: 0.2222 - val_r2_score_metric: 0.4501
# Epoch 19/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0873 - mae: 0.2301 - r2_score_metric: 0.3526 - val_loss: 0.0844 - val_mae: 0.2206 - val_r2_score_metric: 0.4645
# Epoch 20/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0801 - mae: 0.2201 - r2_score_metric: 0.4231 - val_loss: 0.0868 - val_mae: 0.2275 - val_r2_score_metric: 0.4325
# Epoch 21/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0827 - mae: 0.2190 - r2_score_metric: 0.3074 - val_loss: 0.0844 - val_mae: 0.2221 - val_r2_score_metric: 0.4522
# Epoch 22/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0813 - mae: 0.2219 - r2_score_metric: 0.3697 - val_loss: 0.0840 - val_mae: 0.2224 - val_r2_score_metric: 0.4573
# Epoch 23/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0744 - mae: 0.2115 - r2_score_metric: 0.2540 - val_loss: 0.0850 - val_mae: 0.2289 - val_r2_score_metric: 0.4006
# Epoch 24/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0779 - mae: 0.2171 - r2_score_metric: 0.5625 - val_loss: 0.0837 - val_mae: 0.2242 - val_r2_score_metric: 0.4299
# Epoch 25/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0823 - mae: 0.2262 - r2_score_metric: 0.5225 - val_loss: 0.0839 - val_mae: 0.2206 - val_r2_score_metric: 0.4616
# Epoch 26/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0821 - mae: 0.2192 - r2_score_metric: 0.6398 - val_loss: 0.0840 - val_mae: 0.2224 - val_r2_score_metric: 0.4540
# Epoch 27/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0816 - mae: 0.2217 - r2_score_metric: -0.0761 - val_loss: 0.0834 - val_mae: 0.2207 - val_r2_score_metric: 0.4600
# Epoch 28/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0850 - mae: 0.2231 - r2_score_metric: 0.5359 - val_loss: 0.0841 - val_mae: 0.2253 - val_r2_score_metric: 0.4200
# Epoch 29/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0892 - mae: 0.2289 - r2_score_metric: 0.4192 - val_loss: 0.0843 - val_mae: 0.2228 - val_r2_score_metric: 0.4437
# Epoch 30/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0800 - mae: 0.2178 - r2_score_metric: 0.5373 - val_loss: 0.0832 - val_mae: 0.2214 - val_r2_score_metric: 0.4495
# Epoch 31/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0802 - mae: 0.2192 - r2_score_metric: 0.6164 - val_loss: 0.0839 - val_mae: 0.2221 - val_r2_score_metric: 0.4569
# Epoch 32/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0830 - mae: 0.2206 - r2_score_metric: 0.5598 - val_loss: 0.0842 - val_mae: 0.2266 - val_r2_score_metric: 0.4170
# Epoch 33/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0822 - mae: 0.2238 - r2_score_metric: 0.5650 - val_loss: 0.0836 - val_mae: 0.2242 - val_r2_score_metric: 0.4317
# Epoch 34/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0866 - mae: 0.2297 - r2_score_metric: 0.3753 - val_loss: 0.0839 - val_mae: 0.2228 - val_r2_score_metric: 0.4417
# Epoch 35/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0816 - mae: 0.2205 - r2_score_metric: 0.4837 - val_loss: 0.0856 - val_mae: 0.2243 - val_r2_score_metric: 0.4359
# Epoch 36/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0778 - mae: 0.2190 - r2_score_metric: 0.1878 - val_loss: 0.0834 - val_mae: 0.2221 - val_r2_score_metric: 0.4491
# Epoch 37/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0842 - mae: 0.2211 - r2_score_metric: 0.3822 - val_loss: 0.0832 - val_mae: 0.2205 - val_r2_score_metric: 0.4573
# Epoch 38/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0802 - mae: 0.2137 - r2_score_metric: 0.5300 - val_loss: 0.0850 - val_mae: 0.2238 - val_r2_score_metric: 0.4391
# Epoch 39/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0794 - mae: 0.2150 - r2_score_metric: 0.2030 - val_loss: 0.0835 - val_mae: 0.2243 - val_r2_score_metric: 0.4246
# Epoch 40/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0831 - mae: 0.2226 - r2_score_metric: 0.6251 - val_loss: 0.0859 - val_mae: 0.2219 - val_r2_score_metric: 0.4549
# Epoch 41/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0846 - mae: 0.2229 - r2_score_metric: -0.1279 - val_loss: 0.0846 - val_mae: 0.2210 - val_r2_score_metric: 0.4585
# Epoch 42/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0780 - mae: 0.2115 - r2_score_metric: 0.5480 - val_loss: 0.0836 - val_mae: 0.2200 - val_r2_score_metric: 0.4590
# Epoch 43/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0857 - mae: 0.2279 - r2_score_metric: -1.8103 - val_loss: 0.0844 - val_mae: 0.2221 - val_r2_score_metric: 0.4473
# Epoch 44/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0838 - mae: 0.2255 - r2_score_metric: 0.6086 - val_loss: 0.0848 - val_mae: 0.2224 - val_r2_score_metric: 0.4494
# Epoch 45/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0810 - mae: 0.2206 - r2_score_metric: 0.5596 - val_loss: 0.0832 - val_mae: 0.2190 - val_r2_score_metric: 0.4668
# Epoch 46/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0837 - mae: 0.2225 - r2_score_metric: 0.2621 - val_loss: 0.0837 - val_mae: 0.2237 - val_r2_score_metric: 0.4269
# Epoch 47/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0783 - mae: 0.2167 - r2_score_metric: 0.2121 - val_loss: 0.0829 - val_mae: 0.2219 - val_r2_score_metric: 0.4443
# Epoch 48/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0797 - mae: 0.2203 - r2_score_metric: 0.3362 - val_loss: 0.0835 - val_mae: 0.2191 - val_r2_score_metric: 0.4645
# Epoch 49/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0765 - mae: 0.2131 - r2_score_metric: 0.5628 - val_loss: 0.0861 - val_mae: 0.2198 - val_r2_score_metric: 0.4726
# Epoch 50/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0806 - mae: 0.2148 - r2_score_metric: 0.5335 - val_loss: 0.0830 - val_mae: 0.2202 - val_r2_score_metric: 0.4548
# Epoch 51/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0790 - mae: 0.2114 - r2_score_metric: 0.3679 - val_loss: 0.0838 - val_mae: 0.2212 - val_r2_score_metric: 0.4472
# Epoch 52/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0771 - mae: 0.2126 - r2_score_metric: -0.9298 - val_loss: 0.0831 - val_mae: 0.2229 - val_r2_score_metric: 0.4320
# Epoch 53/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0773 - mae: 0.2130 - r2_score_metric: 0.6028 - val_loss: 0.0852 - val_mae: 0.2246 - val_r2_score_metric: 0.4301
# Epoch 54/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0783 - mae: 0.2132 - r2_score_metric: 0.4302 - val_loss: 0.0833 - val_mae: 0.2244 - val_r2_score_metric: 0.4288
# Epoch 55/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0843 - mae: 0.2231 - r2_score_metric: 0.4210 - val_loss: 0.0842 - val_mae: 0.2193 - val_r2_score_metric: 0.4667
# Epoch 56/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0839 - mae: 0.2245 - r2_score_metric: -0.5382 - val_loss: 0.0847 - val_mae: 0.2226 - val_r2_score_metric: 0.4396
# Epoch 57/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0794 - mae: 0.2174 - r2_score_metric: 0.3141 - val_loss: 0.0827 - val_mae: 0.2203 - val_r2_score_metric: 0.4575
# Epoch 58/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0810 - mae: 0.2165 - r2_score_metric: 0.4611 - val_loss: 0.0832 - val_mae: 0.2203 - val_r2_score_metric: 0.4581
# Epoch 59/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0787 - mae: 0.2158 - r2_score_metric: 0.5035 - val_loss: 0.0827 - val_mae: 0.2204 - val_r2_score_metric: 0.4554
# Epoch 60/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0821 - mae: 0.2204 - r2_score_metric: 0.5202 - val_loss: 0.0835 - val_mae: 0.2216 - val_r2_score_metric: 0.4575
# Epoch 61/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0792 - mae: 0.2170 - r2_score_metric: 0.5648 - val_loss: 0.0839 - val_mae: 0.2198 - val_r2_score_metric: 0.4578
# Epoch 62/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0756 - mae: 0.2076 - r2_score_metric: 0.3788 - val_loss: 0.0859 - val_mae: 0.2241 - val_r2_score_metric: 0.4389
# Epoch 63/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0854 - mae: 0.2252 - r2_score_metric: 0.6955 - val_loss: 0.0831 - val_mae: 0.2196 - val_r2_score_metric: 0.4589
# Epoch 64/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0813 - mae: 0.2199 - r2_score_metric: -0.0547 - val_loss: 0.0828 - val_mae: 0.2232 - val_r2_score_metric: 0.4382
# Epoch 65/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0736 - mae: 0.2089 - r2_score_metric: 0.6107 - val_loss: 0.0837 - val_mae: 0.2221 - val_r2_score_metric: 0.4318
# Epoch 66/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0791 - mae: 0.2153 - r2_score_metric: 0.5407 - val_loss: 0.0824 - val_mae: 0.2194 - val_r2_score_metric: 0.4615
# Epoch 67/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0791 - mae: 0.2190 - r2_score_metric: 0.6196 - val_loss: 0.0825 - val_mae: 0.2215 - val_r2_score_metric: 0.4490
# Epoch 68/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0800 - mae: 0.2177 - r2_score_metric: 0.5662 - val_loss: 0.0833 - val_mae: 0.2233 - val_r2_score_metric: 0.4280
# Epoch 69/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0772 - mae: 0.2104 - r2_score_metric: 0.3477 - val_loss: 0.0837 - val_mae: 0.2192 - val_r2_score_metric: 0.4560
# Epoch 70/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0800 - mae: 0.2148 - r2_score_metric: 0.3730 - val_loss: 0.0825 - val_mae: 0.2217 - val_r2_score_metric: 0.4438
# Epoch 71/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0816 - mae: 0.2214 - r2_score_metric: 0.6158 - val_loss: 0.0882 - val_mae: 0.2217 - val_r2_score_metric: 0.4682
# Epoch 72/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0788 - mae: 0.2099 - r2_score_metric: 0.3839 - val_loss: 0.0835 - val_mae: 0.2220 - val_r2_score_metric: 0.4365
# Epoch 73/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0817 - mae: 0.2234 - r2_score_metric: 0.6538 - val_loss: 0.0824 - val_mae: 0.2210 - val_r2_score_metric: 0.4452
# Epoch 74/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0805 - mae: 0.2157 - r2_score_metric: 0.5809 - val_loss: 0.0831 - val_mae: 0.2188 - val_r2_score_metric: 0.4630
# Epoch 75/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0779 - mae: 0.2095 - r2_score_metric: 0.3702 - val_loss: 0.0852 - val_mae: 0.2273 - val_r2_score_metric: 0.3919
# Epoch 76/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0823 - mae: 0.2243 - r2_score_metric: 0.4065 - val_loss: 0.0853 - val_mae: 0.2195 - val_r2_score_metric: 0.4620
# Epoch 77/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0844 - mae: 0.2245 - r2_score_metric: 0.5262 - val_loss: 0.0823 - val_mae: 0.2190 - val_r2_score_metric: 0.4568
# Epoch 78/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0767 - mae: 0.2120 - r2_score_metric: 0.5103 - val_loss: 0.0851 - val_mae: 0.2198 - val_r2_score_metric: 0.4525
# Epoch 79/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0824 - mae: 0.2217 - r2_score_metric: 0.6197 - val_loss: 0.0833 - val_mae: 0.2248 - val_r2_score_metric: 0.4166
# Epoch 80/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0856 - mae: 0.2287 - r2_score_metric: 0.1469 - val_loss: 0.0850 - val_mae: 0.2205 - val_r2_score_metric: 0.4644
# Epoch 81/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0839 - mae: 0.2225 - r2_score_metric: -0.5701 - val_loss: 0.0840 - val_mae: 0.2207 - val_r2_score_metric: 0.4423
# Epoch 82/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0802 - mae: 0.2208 - r2_score_metric: 0.5155 - val_loss: 0.0826 - val_mae: 0.2226 - val_r2_score_metric: 0.4300
# Epoch 83/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0769 - mae: 0.2138 - r2_score_metric: 0.6486 - val_loss: 0.0823 - val_mae: 0.2186 - val_r2_score_metric: 0.4631
# Epoch 84/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0845 - mae: 0.2228 - r2_score_metric: 0.4817 - val_loss: 0.0821 - val_mae: 0.2197 - val_r2_score_metric: 0.4557
# Epoch 85/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0751 - mae: 0.2098 - r2_score_metric: 0.5794 - val_loss: 0.0834 - val_mae: 0.2220 - val_r2_score_metric: 0.4316
# Epoch 86/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0820 - mae: 0.2203 - r2_score_metric: 0.4146 - val_loss: 0.0835 - val_mae: 0.2178 - val_r2_score_metric: 0.4618
# Epoch 87/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0743 - mae: 0.2097 - r2_score_metric: 0.5241 - val_loss: 0.0834 - val_mae: 0.2243 - val_r2_score_metric: 0.4201
# Epoch 88/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0802 - mae: 0.2180 - r2_score_metric: 0.2126 - val_loss: 0.0828 - val_mae: 0.2222 - val_r2_score_metric: 0.4292
# Epoch 89/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0863 - mae: 0.2309 - r2_score_metric: 0.2211 - val_loss: 0.0852 - val_mae: 0.2211 - val_r2_score_metric: 0.4428
# Epoch 90/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0712 - mae: 0.2000 - r2_score_metric: 0.2331 - val_loss: 0.0832 - val_mae: 0.2198 - val_r2_score_metric: 0.4640
# Epoch 91/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0837 - mae: 0.2223 - r2_score_metric: 0.6090 - val_loss: 0.0828 - val_mae: 0.2201 - val_r2_score_metric: 0.4570
# Epoch 92/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0897 - mae: 0.2263 - r2_score_metric: 0.2929 - val_loss: 0.0831 - val_mae: 0.2215 - val_r2_score_metric: 0.4408
# Epoch 93/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0808 - mae: 0.2177 - r2_score_metric: 0.6058 - val_loss: 0.0827 - val_mae: 0.2205 - val_r2_score_metric: 0.4433
# Epoch 94/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0748 - mae: 0.2089 - r2_score_metric: 0.3411 - val_loss: 0.0854 - val_mae: 0.2224 - val_r2_score_metric: 0.4371
# Epoch 95/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0793 - mae: 0.2149 - r2_score_metric: -0.1035 - val_loss: 0.0825 - val_mae: 0.2219 - val_r2_score_metric: 0.4347
# Epoch 96/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0852 - mae: 0.2259 - r2_score_metric: 0.6579 - val_loss: 0.0845 - val_mae: 0.2211 - val_r2_score_metric: 0.4393
# Epoch 97/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0807 - mae: 0.2135 - r2_score_metric: -0.2363 - val_loss: 0.0841 - val_mae: 0.2178 - val_r2_score_metric: 0.4680
# Epoch 98/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0799 - mae: 0.2166 - r2_score_metric: 0.2575 - val_loss: 0.0823 - val_mae: 0.2198 - val_r2_score_metric: 0.4579
# Epoch 99/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0795 - mae: 0.2114 - r2_score_metric: 0.6533 - val_loss: 0.0822 - val_mae: 0.2201 - val_r2_score_metric: 0.4463
# Epoch 100/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0746 - mae: 0.2091 - r2_score_metric: 0.3978 - val_loss: 0.0824 - val_mae: 0.2206 - val_r2_score_metric: 0.4519
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Target Variable: Temperature In
# MAE: 0.22
# R²: 0.87

# %%
train_and_evaluate_gru_model(target_variable='PAR In', flag_train=True, _epochs=100, _batch_size=4)
# Out:
# Epoch 1/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.7993 - mae: 0.6865 - r2_score_metric: -4.8811 - val_loss: 0.4176 - val_mae: 0.3716 - val_r2_score_metric: 0.5221
# Epoch 2/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2297 - mae: 0.3322 - r2_score_metric: -20.9805 - val_loss: 0.4160 - val_mae: 0.3668 - val_r2_score_metric: 0.5305
# Epoch 3/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2413 - mae: 0.3313 - r2_score_metric: 0.5532 - val_loss: 0.4153 - val_mae: 0.3649 - val_r2_score_metric: 0.5356
# Epoch 4/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2762 - mae: 0.3436 - r2_score_metric: 0.8146 - val_loss: 0.4149 - val_mae: 0.3637 - val_r2_score_metric: 0.5387
# Epoch 5/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2808 - mae: 0.3547 - r2_score_metric: -33.2653 - val_loss: 0.4146 - val_mae: 0.3631 - val_r2_score_metric: 0.5405
# Epoch 6/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3366 - mae: 0.3748 - r2_score_metric: 0.6411 - val_loss: 0.4145 - val_mae: 0.3626 - val_r2_score_metric: 0.5418
# Epoch 7/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2429 - mae: 0.3421 - r2_score_metric: -0.8810 - val_loss: 0.4144 - val_mae: 0.3623 - val_r2_score_metric: 0.5426
# Epoch 8/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2711 - mae: 0.3426 - r2_score_metric: -0.5913 - val_loss: 0.4143 - val_mae: 0.3621 - val_r2_score_metric: 0.5432
# Epoch 9/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2469 - mae: 0.3322 - r2_score_metric: -12.9771 - val_loss: 0.4143 - val_mae: 0.3618 - val_r2_score_metric: 0.5437
# Epoch 10/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2606 - mae: 0.3449 - r2_score_metric: 0.4432 - val_loss: 0.4142 - val_mae: 0.3616 - val_r2_score_metric: 0.5440
# Epoch 11/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2787 - mae: 0.3563 - r2_score_metric: 0.3589 - val_loss: 0.4142 - val_mae: 0.3615 - val_r2_score_metric: 0.5442
# Epoch 12/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2817 - mae: 0.3373 - r2_score_metric: -8.8068 - val_loss: 0.4142 - val_mae: 0.3613 - val_r2_score_metric: 0.5444
# Epoch 13/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2526 - mae: 0.3403 - r2_score_metric: 0.1435 - val_loss: 0.4141 - val_mae: 0.3609 - val_r2_score_metric: 0.5446
# Epoch 14/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2415 - mae: 0.3346 - r2_score_metric: 0.5187 - val_loss: 0.4141 - val_mae: 0.3605 - val_r2_score_metric: 0.5448
# Epoch 15/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2824 - mae: 0.3446 - r2_score_metric: -1.4211 - val_loss: 0.4140 - val_mae: 0.3602 - val_r2_score_metric: 0.5449
# Epoch 16/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2662 - mae: 0.3357 - r2_score_metric: 0.7205 - val_loss: 0.4140 - val_mae: 0.3600 - val_r2_score_metric: 0.5451
# Epoch 17/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2552 - mae: 0.3431 - r2_score_metric: -3.0166 - val_loss: 0.4140 - val_mae: 0.3601 - val_r2_score_metric: 0.5452
# Epoch 18/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2757 - mae: 0.3434 - r2_score_metric: -0.8864 - val_loss: 0.4140 - val_mae: 0.3599 - val_r2_score_metric: 0.5452
# Epoch 19/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2337 - mae: 0.3267 - r2_score_metric: -353.3435 - val_loss: 0.4140 - val_mae: 0.3600 - val_r2_score_metric: 0.5453
# Epoch 20/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2877 - mae: 0.3499 - r2_score_metric: -5.3507 - val_loss: 0.4140 - val_mae: 0.3599 - val_r2_score_metric: 0.5453
# Epoch 21/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2664 - mae: 0.3415 - r2_score_metric: 0.8090 - val_loss: 0.4140 - val_mae: 0.3598 - val_r2_score_metric: 0.5454
# Epoch 22/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2737 - mae: 0.3370 - r2_score_metric: -19.1945 - val_loss: 0.4140 - val_mae: 0.3595 - val_r2_score_metric: 0.5454
# Epoch 23/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2464 - mae: 0.3217 - r2_score_metric: 0.7186 - val_loss: 0.4140 - val_mae: 0.3596 - val_r2_score_metric: 0.5455
# Epoch 24/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2511 - mae: 0.3254 - r2_score_metric: 0.5764 - val_loss: 0.4140 - val_mae: 0.3598 - val_r2_score_metric: 0.5454
# Epoch 25/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2675 - mae: 0.3472 - r2_score_metric: 0.4694 - val_loss: 0.4140 - val_mae: 0.3597 - val_r2_score_metric: 0.5455
# Epoch 26/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2632 - mae: 0.3339 - r2_score_metric: -0.0185 - val_loss: 0.4139 - val_mae: 0.3595 - val_r2_score_metric: 0.5455
# Epoch 27/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2420 - mae: 0.3380 - r2_score_metric: -3.7470 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5455
# Epoch 28/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2401 - mae: 0.3257 - r2_score_metric: -223.1144 - val_loss: 0.4140 - val_mae: 0.3598 - val_r2_score_metric: 0.5455
# Epoch 29/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2645 - mae: 0.3453 - r2_score_metric: -1.3326 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5455
# Epoch 30/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2875 - mae: 0.3435 - r2_score_metric: -0.2739 - val_loss: 0.4140 - val_mae: 0.3596 - val_r2_score_metric: 0.5455
# Epoch 31/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2577 - mae: 0.3390 - r2_score_metric: 0.7638 - val_loss: 0.4139 - val_mae: 0.3595 - val_r2_score_metric: 0.5456
# Epoch 32/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2509 - mae: 0.3430 - r2_score_metric: -2.9762 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 33/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2807 - mae: 0.3510 - r2_score_metric: 0.3201 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 34/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2729 - mae: 0.3415 - r2_score_metric: 0.8270 - val_loss: 0.4140 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 35/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2547 - mae: 0.3321 - r2_score_metric: -1.3161 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 36/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2675 - mae: 0.3368 - r2_score_metric: 0.7619 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 37/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2665 - mae: 0.3475 - r2_score_metric: -0.1022 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 38/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2713 - mae: 0.3428 - r2_score_metric: 0.4934 - val_loss: 0.4140 - val_mae: 0.3605 - val_r2_score_metric: 0.5455
# Epoch 39/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2758 - mae: 0.3387 - r2_score_metric: -179.1861 - val_loss: 0.4139 - val_mae: 0.3594 - val_r2_score_metric: 0.5456
# Epoch 40/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3052 - mae: 0.3552 - r2_score_metric: -12.2614 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 41/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2420 - mae: 0.3342 - r2_score_metric: 0.7225 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 42/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2556 - mae: 0.3308 - r2_score_metric: -0.2339 - val_loss: 0.4140 - val_mae: 0.3606 - val_r2_score_metric: 0.5455
# Epoch 43/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2932 - mae: 0.3559 - r2_score_metric: 0.6804 - val_loss: 0.4139 - val_mae: 0.3592 - val_r2_score_metric: 0.5456
# Epoch 44/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2556 - mae: 0.3470 - r2_score_metric: 0.8253 - val_loss: 0.4139 - val_mae: 0.3594 - val_r2_score_metric: 0.5456
# Epoch 45/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2657 - mae: 0.3402 - r2_score_metric: 0.6731 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 46/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2817 - mae: 0.3468 - r2_score_metric: 0.0458 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 47/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2887 - mae: 0.3480 - r2_score_metric: -4.1623 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 48/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - mae: 0.3361 - r2_score_metric: -0.5385 - val_loss: 0.4139 - val_mae: 0.3592 - val_r2_score_metric: 0.5456
# Epoch 49/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2448 - mae: 0.3446 - r2_score_metric: -3.0357 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 50/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2496 - mae: 0.3356 - r2_score_metric: -5.2756 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 51/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2394 - mae: 0.3319 - r2_score_metric: 0.1869 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 52/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2657 - mae: 0.3487 - r2_score_metric: -1.4861 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 53/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2589 - mae: 0.3424 - r2_score_metric: -1.5684 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 54/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2247 - mae: 0.3152 - r2_score_metric: -2.0930 - val_loss: 0.4140 - val_mae: 0.3601 - val_r2_score_metric: 0.5456
# Epoch 55/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2853 - mae: 0.3465 - r2_score_metric: 0.7626 - val_loss: 0.4139 - val_mae: 0.3600 - val_r2_score_metric: 0.5456
# Epoch 56/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2751 - mae: 0.3447 - r2_score_metric: 0.6639 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 57/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2572 - mae: 0.3417 - r2_score_metric: -4.0941 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 58/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2481 - mae: 0.3276 - r2_score_metric: 0.4328 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 59/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2831 - mae: 0.3525 - r2_score_metric: -1323.1012 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 60/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2477 - mae: 0.3420 - r2_score_metric: -32.5427 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 61/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2739 - mae: 0.3415 - r2_score_metric: -2101.5713 - val_loss: 0.4139 - val_mae: 0.3592 - val_r2_score_metric: 0.5456
# Epoch 62/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2649 - mae: 0.3387 - r2_score_metric: 0.4248 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# Epoch 63/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3308 - mae: 0.3717 - r2_score_metric: -0.1412 - val_loss: 0.4141 - val_mae: 0.3612 - val_r2_score_metric: 0.5454
# Epoch 64/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2555 - mae: 0.3310 - r2_score_metric: -13.5245 - val_loss: 0.4139 - val_mae: 0.3597 - val_r2_score_metric: 0.5456
# Epoch 65/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3153 - mae: 0.3677 - r2_score_metric: 0.5136 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 66/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2869 - mae: 0.3574 - r2_score_metric: -0.0074 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# Epoch 67/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2477 - mae: 0.3277 - r2_score_metric: -17.7084 - val_loss: 0.4139 - val_mae: 0.3594 - val_r2_score_metric: 0.5456
# Epoch 68/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2960 - mae: 0.3528 - r2_score_metric: 0.7716 - val_loss: 0.4139 - val_mae: 0.3592 - val_r2_score_metric: 0.5456
# Epoch 69/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2145 - mae: 0.3199 - r2_score_metric: -1.1513 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# Epoch 70/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2384 - mae: 0.3216 - r2_score_metric: -5.1822 - val_loss: 0.4140 - val_mae: 0.3603 - val_r2_score_metric: 0.5456
# Epoch 71/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2507 - mae: 0.3370 - r2_score_metric: -2.5132 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 72/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - mae: 0.3321 - r2_score_metric: 0.7150 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 73/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3396 - mae: 0.3619 - r2_score_metric: -9.5477 - val_loss: 0.4139 - val_mae: 0.3599 - val_r2_score_metric: 0.5456
# Epoch 74/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - mae: 0.3454 - r2_score_metric: 0.7287 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 75/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2338 - mae: 0.3277 - r2_score_metric: 0.4528 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# Epoch 76/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2632 - mae: 0.3530 - r2_score_metric: 0.6451 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 77/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2498 - mae: 0.3287 - r2_score_metric: -1.7361 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 78/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3187 - mae: 0.3567 - r2_score_metric: -1.3540 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 79/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2666 - mae: 0.3435 - r2_score_metric: 0.5161 - val_loss: 0.4140 - val_mae: 0.3606 - val_r2_score_metric: 0.5456
# Epoch 80/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2542 - mae: 0.3352 - r2_score_metric: 0.5816 - val_loss: 0.4139 - val_mae: 0.3597 - val_r2_score_metric: 0.5456
# Epoch 81/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2389 - mae: 0.3327 - r2_score_metric: -5.7821 - val_loss: 0.4139 - val_mae: 0.3597 - val_r2_score_metric: 0.5456
# Epoch 82/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2661 - mae: 0.3476 - r2_score_metric: -0.2938 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 83/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2419 - mae: 0.3389 - r2_score_metric: 0.6094 - val_loss: 0.4139 - val_mae: 0.3592 - val_r2_score_metric: 0.5456
# Epoch 84/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2469 - mae: 0.3260 - r2_score_metric: 0.3260 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 85/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2462 - mae: 0.3294 - r2_score_metric: -20.6763 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# Epoch 86/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2511 - mae: 0.3290 - r2_score_metric: 0.6729 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 87/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2494 - mae: 0.3432 - r2_score_metric: 0.3208 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 88/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2545 - mae: 0.3320 - r2_score_metric: -0.1293 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 89/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2456 - mae: 0.3270 - r2_score_metric: -1.2830 - val_loss: 0.4139 - val_mae: 0.3596 - val_r2_score_metric: 0.5456
# Epoch 90/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2507 - mae: 0.3342 - r2_score_metric: -2180.4407 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# Epoch 91/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2347 - mae: 0.3235 - r2_score_metric: -3.6639 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 92/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2528 - mae: 0.3408 - r2_score_metric: 0.7185 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 93/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - mae: 0.3398 - r2_score_metric: -0.0295 - val_loss: 0.4139 - val_mae: 0.3599 - val_r2_score_metric: 0.5456
# Epoch 94/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2553 - mae: 0.3227 - r2_score_metric: 0.3755 - val_loss: 0.4140 - val_mae: 0.3605 - val_r2_score_metric: 0.5456
# Epoch 95/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2993 - mae: 0.3623 - r2_score_metric: -8.9272 - val_loss: 0.4139 - val_mae: 0.3593 - val_r2_score_metric: 0.5456
# Epoch 96/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2591 - mae: 0.3421 - r2_score_metric: -2.8811 - val_loss: 0.4139 - val_mae: 0.3591 - val_r2_score_metric: 0.5456
# Epoch 97/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2733 - mae: 0.3517 - r2_score_metric: -1.5783 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 98/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2459 - mae: 0.3320 - r2_score_metric: 0.3327 - val_loss: 0.4139 - val_mae: 0.3592 - val_r2_score_metric: 0.5456
# Epoch 99/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2985 - mae: 0.3530 - r2_score_metric: -3.0078 - val_loss: 0.4139 - val_mae: 0.3590 - val_r2_score_metric: 0.5456
# Epoch 100/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2422 - mae: 0.3244 - r2_score_metric: 0.3233 - val_loss: 0.4139 - val_mae: 0.3589 - val_r2_score_metric: 0.5456
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Target Variable: PAR In
# MAE: 0.32
# R²: 0.95

# %%
train_and_evaluate_gru_model(target_variable='RH In', flag_train=True, _epochs=100, _batch_size=4)
# Out:
# Epoch 1/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 145.3647 - mae: 9.8040 - r2_score_metric: -27.6741 - val_loss: 15.3636 - val_mae: 3.5164 - val_r2_score_metric: -8.2235
# Epoch 2/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.0890 - mae: 3.5033 - r2_score_metric: -2.7112 - val_loss: 14.9564 - val_mae: 3.4609 - val_r2_score_metric: -8.0083
# Epoch 3/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.5387 - mae: 3.4152 - r2_score_metric: -4.0849 - val_loss: 14.8685 - val_mae: 3.4488 - val_r2_score_metric: -7.9586
# Epoch 4/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.4634 - mae: 3.4045 - r2_score_metric: -2.6112 - val_loss: 14.8234 - val_mae: 3.4425 - val_r2_score_metric: -7.9334
# Epoch 5/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9996 - mae: 3.3346 - r2_score_metric: -3.5836 - val_loss: 14.7782 - val_mae: 3.4362 - val_r2_score_metric: -7.9092
# Epoch 6/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.3730 - mae: 3.4081 - r2_score_metric: -1.9096 - val_loss: 14.7690 - val_mae: 3.4350 - val_r2_score_metric: -7.9038
# Epoch 7/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9391 - mae: 3.3428 - r2_score_metric: -1.9509 - val_loss: 14.7620 - val_mae: 3.4340 - val_r2_score_metric: -7.8995
# Epoch 8/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.5772 - mae: 3.3188 - r2_score_metric: -2.0328 - val_loss: 14.7492 - val_mae: 3.4322 - val_r2_score_metric: -7.8937
# Epoch 9/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9338 - mae: 3.3488 - r2_score_metric: -1.6240 - val_loss: 14.7460 - val_mae: 3.4318 - val_r2_score_metric: -7.8917
# Epoch 10/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.0938 - mae: 3.3432 - r2_score_metric: -2.7277 - val_loss: 14.7434 - val_mae: 3.4314 - val_r2_score_metric: -7.8902
# Epoch 11/100
# 189/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.5350 - mae: 3.4159 - r2_score_metric: -2.8691
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_and_evaluate_gru_model(target_variable='RH In', flag_train=True, _epochs=100, _batch_size=4)
#
# Cell In[5], line 53, in train_and_evaluate_gru_model(target_variable, flag_train, _epochs, _batch_size)
#      50 model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_metric])
#      52 # Train the model
# ---> 53 history = model.fit(X_train_reshaped, y_train, epochs=_epochs, batch_size=_batch_size, validation_split=0.2, verbose=1)
#      55 # Save the model
#      56 model.save(f'gru-models/{target_variable}_gru_model.keras')
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\frm19\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
